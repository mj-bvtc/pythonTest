# %%
import pandas as pd

file = r"C:\Users\mkreidler\Desktop\shell_find_duplicates.xlsx"

df = pd.read_excel(file)
df = df.loc[df["Count"]>0, :]
# Out:
#           trc    bv                 ship color  Level  Count
# 0      E-AE07   J2E  2019-04-05 00:00:00     B   10.0    1.0
# 1      E-AG08   CS5  2019-05-31 00:00:00     F   10.0    1.0
# 2     E-AG08b   CS3  2019-05-31 00:00:00     A   10.0    1.0
# 3      E-AG09   J2E  2019-04-19 00:00:00     A   10.0    1.0
# 4       N-B02  A10C                  NaN     A   12.0    1.0
# 5      E-AM10   A1J  2019-04-19 00:00:00     A    9.0    1.0
# 6      E-AV09   A3F  2019-07-19 00:00:00     A    9.0    1.0
# 8      E-AX01   B6G  2019-04-19 00:00:00     C    7.0    1.0
# 9      E-AX02   B6A  2019-05-31 00:00:00     F    7.0    1.0
# 10     E-AX03   B6B           Shipment 9     A    7.0    1.0
# 11     E-AX04   B6C  2019-05-31 00:00:00     A    7.0    1.0
# 12     E-AX05   B6C  2019-05-31 00:00:00     C    7.0    1.0
# 13     E-AX06   B6B  2019-07-19 00:00:00     F    7.0    1.0
# 14     E-AX07   B6A  2019-05-31 00:00:00     A    7.0    1.0
# ...
