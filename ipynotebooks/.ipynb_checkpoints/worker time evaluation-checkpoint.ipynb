# %%
import pandas as pd
import matplotlib.pyplot as plt


data = r"C:\Users\mkreidler\Desktop\time eval.xlsx"
df = pd.read_excel(data)
df.head()
# Out:
#        start        end  hrs emp
# 0 2018-01-01 2018-01-14  NaN  cw
# 1 2018-01-15 2018-01-28  NaN  cw
# 2 2018-01-29 2018-02-11  NaN  cw
# 3 2018-02-12 2018-02-25  NaN  cw
# 4 2018-02-26 2018-03-11  NaN  cw

# %%
plt.plot(df.end, df.hrs)
#plt.axis(['2018-02', '2018-12', 0,125])
plt.legend()
plt.show()
