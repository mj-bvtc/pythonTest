# %%
import pandas as pd
import numpy as np
import re

###
###
### IMPORT RAW DATA
###
###


# import the excel file
rh = r"C:\Users\mkreidler\Desktop\35w\rhino.xlsx"


# convert files to dataframes
rhino = pd.read_excel(rh)

# %%
df = rhino

for x in df:
    print(x, type(x))
# Out:
# layer <class 'str'>
# name <class 'str'>
# zones <class 'str'>
# guid <class 'str'>
# x <class 'str'>
# y <class 'str'>
# z <class 'str'>

# %%
# clean data
df.x = pd.to_numeric(df.x)
df.y = pd.to_numeric(df.y)
df.z = pd.to_numeric(df.z)

# creating the framework
df["new"] = ""
df["co"] = ""
df["priority_ctrac"] = ""
df["swing_drop"] = ""
df["faulty"] = ""
df["remediation"] = ""
df["deduct"] = ""
df["floor"] = ""
df["elevation"] = ""
df["project"] = ""
rhino["bv_survey"] = ""
rhino["co11_12"] = ""
rhino["mk_priority"] = ""
rhino["ct_val"] = 1
rhino["ct_order"] = ""

# creating definitions
df.new = df.layer.apply(lambda x: "NEW" in str(x))   #this defines and executes at once
def find_co(x):
    pat = r"CO[\s]*([0-9]+)"
    result = re.search(pat, str(x))
    if result:
        return int(result.group(1))
    
def find_priority(x):
    pat = r"P([0-9]+)"
    result = re.search(pat, str(x))
    if result:
        return int(result.group(1))  

def get_drop(x):

    pat = r"drop\s*([a-z]*\d*)"
    match = re.search(pat, str(x), flags=re.IGNORECASE)

    if match:
        #print("Found Match")
        return match.group(1)
    else:
        #print("Not Found")
        return None

def find_faulty(x):
    pat = r"faulty"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return "faulty"
    
def find_remediation(x):
    pat = r"remediation"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return "re"

def find_deduct(x):
    pat = r"deduct"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return "deduct"
    
def find_floor(x):
    pat = r"floor\s*(\d*)"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return int(result.group(1))
    
def find_elevation(x):
    pat = r"([a-zA-Z]*)\s*ELEVATION"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)

    
def find_project(x):
    pat = r"'project\s+(.*)'"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)
    else:
        print("not in project")
        
        
def check_survey(x):
    if x not in ["S2", "S3", "S4"]:
        return "bv_surveyed"
    else:
        return "survey required"

    
def find_co11_12(x):
    if x in [11, 12]:
        return "in scope"
    else:
        return "NIS"

# executing the functions to parse/assign data
df.co = df.layer.apply(find_co)
df.priority_ctrac = df.layer.apply(find_priority)
df.swing_drop = df.zones.apply(get_drop)
df.faulty = df.layer.apply(find_faulty)
df.remediation = df.layer.apply(find_remediation)
df.deduct = df.layer.apply(find_deduct)
df.floor = df.zones.apply(find_floor)
df.elevation = df.zones.apply(find_elevation)
df.project = df.zones.apply(find_project)
df.bv_survey = df.swing_drop.apply(check_survey)
df.co11_12 = df.co.apply(find_co11_12)


# assign the mk method of sorting drops
df.loc[df.swing_drop == "E1", "mk_priority"] = 1
df.loc[df.swing_drop == "S1", "mk_priority"] = 2
df.loc[df.swing_drop == "S5", "mk_priority"] = 3
df.loc[df.swing_drop == "W1", "mk_priority"] = 4
df.loc[df.swing_drop == "W2", "mk_priority"] = 5
df.loc[df.swing_drop == "W3", "mk_priority"] = 6
df.loc[df.swing_drop == "S4", "mk_priority"] = 7
df.loc[df.swing_drop == "S3", "mk_priority"] = 8
df.loc[df.swing_drop == "S2", "mk_priority"] = 9

#sort values and hold that order with cumsum()
df = df.sort_values(["bv_survey", "co11_12", "mk_priority","z", "new"], ascending=[True, False, True, True, True])
df["ct_order"] = df.ct_val.cumsum()
df
# Out:
#                                     layer   name  \
# 392   Model::CHANGE ORDER 11::CO11 P1 NEW     E1
# 391   Model::CHANGE ORDER 11::CO11 P1 NEW     E1
# 87    Model::CHANGE ORDER 11::CO11 P1 NEW    S3-
# 88    Model::CHANGE ORDER 11::CO11 P1 NEW    S3-
# 222   Model::CHANGE ORDER 11::CO11 P1 NEW    B12
# 394   Model::CHANGE ORDER 11::CO11 P1 NEW     A?
# 393   Model::CHANGE ORDER 11::CO11 P1 NEW  PA100
# 395   Model::CHANGE ORDER 11::CO11 P1 NEW   5A6L
# 382   Model::CHANGE ORDER 11::CO11 P1 NEW   Q111
# 90    Model::CHANGE ORDER 11::CO11 P2 NEW   Q108
# 91    Model::CHANGE ORDER 11::CO11 P2 NEW   Q108
# 381   Model::CHANGE ORDER 11::CO11 P2 NEW   Q109
# 86    Model::CHANGE ORDER 11::CO11 P2 NEW  A102A
# 390   Model::CHANGE ORDER 11::CO11 P2 NEW   Q105
# 94    Model::CHANGE ORDER 11::CO11 P3 NEW   A110
# 93    Model::CHANGE ORDER 11::CO11 P3 NEW   A110
# 92    Model::CHANGE ORDER 11::CO11 P3 NEW   A110
# 69    Model::CHANGE ORDER 11::CO11 P3 NEW   4B4F
# 389   Model::CHANGE ORDER 11::CO11 P3 NEW    4A1
# 388   Model::CHANGE ORDER 11::CO11 P3 NEW   B103
# 387   Model::CHANGE ORDER 11::CO11 P3 NEW     D1
# 3538      Model::CHANGE ORDER 11::CO11 P3    3C9
# 386   Model::CHANGE ORDER 11::CO11 P3 NEW     W2
# 377   Model::CHANGE ORDER 11::CO11 P3 NEW   3C10
# 378   Model::CHANGE ORDER 11::CO11 P3 NEW   3C10
# 72    Model::CHANGE ORDER 11::CO11 P3 NEW    9F?
# 70    Model::CHANGE ORDER 11::CO11 P3 NEW    9E7
# 380   Model::CHANGE ORDER 11::CO11 P3 NEW   Q121
# 379   Model::CHANGE ORDER 11::CO11 P3 NEW     J1
# 125   Model::CHANGE ORDER 11::CO11 P1 NEW    B45
# ...                                   ...    ...
# 2557       Model::CHANGE ORDER 9::CO9 P13    AG2
# 2300                 Model::BASE BID::P13    B35
# 2424       Model::CHANGE ORDER 9::CO9 P13    AG3
# 19                   Model::BASE BID::P13    B34
# 18                   Model::BASE BID::P13    B30
# 17                   Model::BASE BID::P13    B34
# 2370                 Model::BASE BID::P13   4B1H
# 2366                 Model::BASE BID::P13   4B2D
# 2369                 Model::BASE BID::P13   4B1H
# 2368                 Model::BASE BID::P13   4B1G
# 2367                 Model::BASE BID::P13   4B1G
# 2371                 Model::BASE BID::P13    3C8
# 721              Model::BASE BID::P13 NEW      ?
# 174                  Model::BASE BID::P13    B35
# 172                  Model::BASE BID::P13    B35
# 173                  Model::BASE BID::P13    B35
# 171                  Model::BASE BID::P13    B35
# 2375                 Model::BASE BID::P13   9F1B
# 2374                 Model::BASE BID::P13   9F2B
# 2490       Model::CHANGE ORDER 9::CO9 P13    B39
# 2372       Model::CHANGE ORDER 5::CO5 P13   9E2B
# 2373       Model::CHANGE ORDER 5::CO5 P13   9E1B
# 2485                 Model::BASE BID::P13    B35
# 2486                 Model::BASE BID::P13    B35
# 2487                 Model::BASE BID::P13    B35
# 2488                 Model::BASE BID::P13    B35
# 2489                 Model::BASE BID::P13    B35
# 2378       Model::CHANGE ORDER 5::CO5 P13    9G2
# 2379                 Model::BASE BID::P13    9G2
# 2317       Model::CHANGE ORDER 9::CO9 P13    9G2
#
#                                                   zones  \
# 392   ['FLOOR 4'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 391   ['FLOOR 4'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 87    ['FLOOR 4'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 88    ['FLOOR 4'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 222   ['FLOOR 4'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 394   ['FLOOR 5'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 393   ['FLOOR 5'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 395   ['FLOOR 6'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 382   ['FLOOR 7'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 90    ['FLOOR 10'// 'EAST ELEVATION'// 'DROP E1'// '...
# 91    ['FLOOR 10'// 'EAST ELEVATION'// 'DROP E1'// '...
# 381   ['FLOOR 10'// 'EAST ELEVATION'// 'DROP E1'// '...
# 86    ['FLOOR 15'// 'EAST ELEVATION'// 'DROP E1'// '...
# 390   ['FLOOR 16'// 'EAST ELEVATION'// 'DROP E1'// '...
# 94    ['FLOOR 19'// 'EAST ELEVATION'// 'DROP E1'// '...
# 93    ['FLOOR 19'// 'EAST ELEVATION'// 'DROP E1'// '...
# 92    ['FLOOR 19'// 'EAST ELEVATION'// 'DROP E1'// '...
# 69    ['FLOOR 19'// 'EAST ELEVATION'// 'DROP E1'// '...
# 389   ['FLOOR 19'// 'EAST ELEVATION'// 'DROP E1'// '...
# 388   ['FLOOR 19'// 'EAST ELEVATION'// 'DROP E1'// '...
# 387   ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3538  ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 386   ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 377   ['FLOOR 21'// 'EAST ELEVATION'// 'DROP E1'// '...
# 378   ['FLOOR 21'// 'EAST ELEVATION'// 'DROP E1'// '...
# 72    ['FLOOR 21'// 'EAST ELEVATION'// 'DROP E1'// '...
# 70    ['FLOOR 21'// 'EAST ELEVATION'// 'DROP E1'// '...
# 380   ['FLOOR 23'// 'EAST ELEVATION'// 'DROP E1'// '...
# 379   ['FLOOR 23'// 'EAST ELEVATION'// 'DROP E1'// '...
# 125   ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# ...                                                 ...
# 2557  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2300  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2424  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 19    ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 18    ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 17    ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2370  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2366  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2369  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2368  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2367  ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2371  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 721   ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 174   ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 172   ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 173   ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 171   ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2375  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2374  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2490  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2372  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2373  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2485  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2486  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2487  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2488  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2489  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2378  ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2379  ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 2317  ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S2'// ...
#
#                                       guid            x      y            z  \
# 392   086bf3ee-9ef8-4515-8ce1-1b43d2106aeb  6134.587733  -88.5 -1691.734700
# 391   732e5e38-7039-4e8e-8ee0-7b6a275afa44  6155.878160  -88.5 -1691.624702
# 87    481849ca-cb8f-4cab-b200-f104d1d897a7  6163.827108  -88.5 -1682.640950
# 88    759476ce-fbbb-47e1-a804-0eedd927f6fa  6127.415000  -88.5 -1682.640950
# 222   bdd09a5f-ffbb-476a-a414-faeb4ca20069  5900.770945    0.0 -1622.683733
# 394   4d3edb63-6586-4cce-99d2-479a36f71f5c  6097.958312  -88.5 -1576.043529
# 393   06e5df60-5c9d-4374-afe0-dbb00c4760fc  6117.356506  -88.5 -1575.819704
# 395   fa467f63-f557-43ec-a3fa-19e2e3342872  6104.296694  -88.5 -1411.533821
# 382   2bee232c-d34e-4357-ad43-47ab24076b2f  6190.985534  -88.5 -1312.908338
# 90    8386d3db-7b62-45f6-b481-b40f5576b5d7  6098.149504  -88.5  -893.960666
# 91    23becfc8-df42-4b5a-8930-c75949ec543d  6098.377852  -88.5  -882.999957
# 381   eee53c58-e1f4-4d7c-bfe3-84e24cef4241  6167.142048  -88.5  -882.371616
# 86    8ac26c44-30d8-4795-b1fe-31a0824e4805  6172.419530    0.0  -288.159991
# 390   385203bf-2af0-4c13-8e58-5fd9e11c3b77  6098.791908  -88.5  -147.764922
# 94    3c77bc1c-760b-46c3-aa68-9c6400567f50  6155.567110    0.0   223.948837
# 93    5aefd386-3f03-4bdb-85f0-146d1ca9be20  6173.212918    0.0   224.052642
# 92    1bc4b0fe-de86-4b0b-84f9-1540f5f8199a  6190.235932    0.0   224.364054
# 69    9651e887-eb5f-4c38-a3a4-81bc42aa9ec4  6172.567276    0.0   234.035132
# 389   dfa9fb1b-212f-4f6f-a6a2-a2c241e673e2  5843.206264  -88.5   244.772537
# 388   f486ca88-3bfa-4f3d-8039-952f7156e872  5843.574701  -88.5   255.365093
# 387   18820023-cedc-4d71-9e1d-60a1ff8c58f8  5843.717177  -88.5   357.201147
# 3538  b7080702-7501-4abf-82e4-4273f91a8518  5899.749825  -88.5   372.972471
# 386   7d646b35-3d00-430a-b93d-ebae6de1325f  5841.452539  -88.5   372.972471
# 377   52b3c443-0d14-4a7c-b535-e76e79a8e583  6153.812174  -88.5   496.496196
# 378   dfda9d59-3296-4aa2-8ff6-7897f4b90cef  6193.319164  -88.5   496.496196
# 72    57d8277a-a9c2-4627-b1fd-c6724e94ec35  5950.556319    0.0   600.965253
# 70    d079907c-e14b-44f3-9aca-433359e710c6  5950.275723    0.0   612.470062
# 380   ade7cd1f-0538-49b9-822a-5ce32f938ad7  6059.860877  -88.5   778.142875
# 379   fe065c91-dba2-4e90-a48d-40ee8c4b3932  6040.676607  -88.5   778.229451
# 125   38768b72-9549-4c61-9388-6a3fb18fdff6   -79.583675 -100.0 -1964.018919
# ...                                    ...          ...    ...          ...
# 2557  81ac36dc-3f80-40dd-b5a3-e4f6f1d75ed4  -315.731226  -88.5   270.759275
# 2300  2cd6c171-3555-4b6b-b6ca-e8173c928fe7  -355.908769  -88.5   270.841406
# 2424  34f23806-2ed7-4563-b96e-35e34e54eb86  -332.227406  -88.5   274.678604
# 19    4c8aad3b-179d-4e92-b0d5-9991a538916c  -465.552515  -88.5   305.384637
# 18    0d0b5b4b-5e07-49dd-85fe-449f7e253b3b  -465.589258  -88.5   316.662109
# 17    985bc3f4-ffb9-4fc0-8871-357258e4044c  -465.758580  -88.5   327.877901
# 2370  f64dff99-60d9-4c6b-b8f7-ffbffabb193f  -376.229216  -88.5   340.003739
# 2366  bdd89c5b-c53c-47eb-a08f-2953cb6bfbb1  -210.750210  -88.5   340.026913
# 2369  b36db3de-6bcf-462e-9fd2-ac741619720b  -355.896151  -88.5   340.208620
# 2368  604b3928-879d-4a65-8d39-326372a99b97  -314.832101  -88.5   340.228278
# 2367  f9c74c76-309d-4e36-8e22-1cef28882fa2  -294.492789  -88.5   340.312282
# 2371  5559d011-6f41-45cd-8ed9-b8ce16b4e93d  -397.033789  -88.5   368.921413
# 721   ac8e5317-bbd5-4177-a983-217d2bf606e8  -397.803755  -88.5   382.167622
# 174   19470635-58d1-462c-acb2-00a3d7cd8eef  -199.089926  -88.5   389.977936
# 172   b331a9c2-8b3b-4d4c-82e3-b551557dabdf  -198.979879  -88.5   401.153118
# 173   023d3f81-2e44-4219-b04b-eb0b15dfe9c5  -198.869833  -88.5   413.019848
# 171   0ca7c4be-8ac7-4f34-ba64-703121cc4294  -199.037842  -88.5   435.952702
# 2375  7cb3397a-79ad-424f-998e-3afd8afbff8b  -338.637360  -88.5   470.434701
# 2374  73c0bcff-9566-4631-8b4d-44abfc30ae12  -317.714879  -88.5   470.570561
# 2490  1620a5aa-c7e9-409d-9386-063472a88f5a  -358.027276  -88.5   470.761772
# 2372  86041201-4b99-41bc-b51e-a70e1ef811b2  -318.509913  -88.5   488.717132
# 2373  ce8b6030-f42a-437d-92d6-377c6431ebd3  -340.146918  -88.5   488.884860
# 2485  caa8b71c-ad72-400f-a417-12f4ba7ecf49  -196.743537  -88.5   530.749315
# 2486  fa967e98-ba6c-4b49-9913-9f239e494950  -196.795902  -88.5   542.024359
# 2487  bd9a4845-2510-44f7-b522-b690cf7db9d8  -196.516100  -88.5   565.460935
# 2488  0b30f009-c8e0-4bcd-9414-02aeebd5e3b4  -196.380240  -88.5   576.873197
# 2489  dc57b86f-5bde-4dc3-82cc-54a93b91f28b  -196.380240  -88.5   588.285459
# 2378  18466123-6c95-4056-8b64-a36d12bb060f  -274.305084  -88.5   647.130384
# 2379  9c5873f3-04ba-4953-aaa8-68e64e6bf98f  -273.897504  -88.5   658.542646
# 2317  456ca0d6-3388-4bb7-91aa-844d0e35598b  -273.897504  -88.5   670.873393
#
#         new    co  priority_ctrac   ...    remediation deduct floor elevation  \
# 392    True  11.0             1.0   ...           None   None     4      EAST
# 391    True  11.0             1.0   ...           None   None     4      EAST
# 87     True  11.0             1.0   ...           None   None     4      EAST
# 88     True  11.0             1.0   ...           None   None     4      EAST
# 222    True  11.0             1.0   ...           None   None     4      EAST
# 394    True  11.0             1.0   ...           None   None     5      EAST
# 393    True  11.0             1.0   ...           None   None     5      EAST
# 395    True  11.0             1.0   ...           None   None     6      EAST
# 382    True  11.0             1.0   ...           None   None     7      EAST
# 90     True  11.0             2.0   ...           None   None    10      EAST
# 91     True  11.0             2.0   ...           None   None    10      EAST
# 381    True  11.0             2.0   ...           None   None    10      EAST
# 86     True  11.0             2.0   ...           None   None    15      EAST
# 390    True  11.0             2.0   ...           None   None    16      EAST
# 94     True  11.0             3.0   ...           None   None    19      EAST
# 93     True  11.0             3.0   ...           None   None    19      EAST
# 92     True  11.0             3.0   ...           None   None    19      EAST
# 69     True  11.0             3.0   ...           None   None    19      EAST
# 389    True  11.0             3.0   ...           None   None    19      EAST
# 388    True  11.0             3.0   ...           None   None    19      EAST
# 387    True  11.0             3.0   ...           None   None    20      EAST
# 3538  False  11.0             3.0   ...           None   None    20      EAST
# 386    True  11.0             3.0   ...           None   None    20      EAST
# 377    True  11.0             3.0   ...           None   None    21      EAST
# 378    True  11.0             3.0   ...           None   None    21      EAST
# 72     True  11.0             3.0   ...           None   None    21      EAST
# 70     True  11.0             3.0   ...           None   None    21      EAST
# 380    True  11.0             3.0   ...           None   None    23      EAST
# 379    True  11.0             3.0   ...           None   None    23      EAST
# 125    True  11.0             1.0   ...           None   None     2     SOUTH
# ...     ...   ...             ...   ...            ...    ...   ...       ...
# 2557  False   9.0            13.0   ...           None   None    19     SOUTH
# 2300  False   NaN            13.0   ...           None   None    19     SOUTH
# 2424  False   9.0            13.0   ...           None   None    19     SOUTH
# 19    False   NaN            13.0   ...           None   None    19     SOUTH
# 18    False   NaN            13.0   ...           None   None    19     SOUTH
# 17    False   NaN            13.0   ...           None   None    19     SOUTH
# 2370  False   NaN            13.0   ...           None   None    19     SOUTH
# 2366  False   NaN            13.0   ...           None   None    19     SOUTH
# 2369  False   NaN            13.0   ...           None   None    19     SOUTH
# 2368  False   NaN            13.0   ...           None   None    19     SOUTH
# 2367  False   NaN            13.0   ...           None   None    19     SOUTH
# 2371  False   NaN            13.0   ...           None   None    20     SOUTH
# 721    True   NaN            13.0   ...           None   None    20     SOUTH
# 174   False   NaN            13.0   ...           None   None    20     SOUTH
# 172   False   NaN            13.0   ...           None   None    20     SOUTH
# 173   False   NaN            13.0   ...           None   None    20     SOUTH
# 171   False   NaN            13.0   ...           None   None    20     SOUTH
# 2375  False   NaN            13.0   ...           None   None    20     SOUTH
# 2374  False   NaN            13.0   ...           None   None    20     SOUTH
# 2490  False   9.0            13.0   ...           None   None    20     SOUTH
# 2372  False   5.0            13.0   ...           None   None    21     SOUTH
# 2373  False   5.0            13.0   ...           None   None    21     SOUTH
# 2485  False   NaN            13.0   ...           None   None    21     SOUTH
# 2486  False   NaN            13.0   ...           None   None    21     SOUTH
# 2487  False   NaN            13.0   ...           None   None    21     SOUTH
# 2488  False   NaN            13.0   ...           None   None    21     SOUTH
# 2489  False   NaN            13.0   ...           None   None    21     SOUTH
# 2378  False   5.0            13.0   ...           None   None    22     SOUTH
# 2379  False   NaN            13.0   ...           None   None    22     SOUTH
# 2317  False   9.0            13.0   ...           None   None    22     SOUTH
#
#           project        bv_survey   co11_12 mk_priority ct_val ct_order
# 392   35 E WACKER      bv_surveyed  in scope           1      1        1
# 391   35 E WACKER      bv_surveyed  in scope           1      1        2
# 87    35 E WACKER      bv_surveyed  in scope           1      1        3
# 88    35 E WACKER      bv_surveyed  in scope           1      1        4
# 222   35 E WACKER      bv_surveyed  in scope           1      1        5
# 394   35 E WACKER      bv_surveyed  in scope           1      1        6
# 393   35 E WACKER      bv_surveyed  in scope           1      1        7
# 395   35 E WACKER      bv_surveyed  in scope           1      1        8
# 382   35 E WACKER      bv_surveyed  in scope           1      1        9
# 90    35 E WACKER      bv_surveyed  in scope           1      1       10
# 91    35 E WACKER      bv_surveyed  in scope           1      1       11
# 381   35 E WACKER      bv_surveyed  in scope           1      1       12
# 86    35 E WACKER      bv_surveyed  in scope           1      1       13
# 390   35 E WACKER      bv_surveyed  in scope           1      1       14
# 94    35 E WACKER      bv_surveyed  in scope           1      1       15
# 93    35 E WACKER      bv_surveyed  in scope           1      1       16
# 92    35 E WACKER      bv_surveyed  in scope           1      1       17
# 69    35 E WACKER      bv_surveyed  in scope           1      1       18
# 389   35 E WACKER      bv_surveyed  in scope           1      1       19
# 388   35 E WACKER      bv_surveyed  in scope           1      1       20
# 387   35 E WACKER      bv_surveyed  in scope           1      1       21
# 3538  35 E WACKER      bv_surveyed  in scope           1      1       22
# 386   35 E WACKER      bv_surveyed  in scope           1      1       23
# 377   35 E WACKER      bv_surveyed  in scope           1      1       24
# 378   35 E WACKER      bv_surveyed  in scope           1      1       25
# 72    35 E WACKER      bv_surveyed  in scope           1      1       26
# 70    35 E WACKER      bv_surveyed  in scope           1      1       27
# 380   35 E WACKER      bv_surveyed  in scope           1      1       28
# 379   35 E WACKER      bv_surveyed  in scope           1      1       29
# 125   35 E WACKER      bv_surveyed  in scope           2      1       30
# ...           ...              ...       ...         ...    ...      ...
# 2557  35 E WACKER  survey required       NIS           9      1     3718
# 2300  35 E WACKER  survey required       NIS           9      1     3719
# 2424  35 E WACKER  survey required       NIS           9      1     3720
# 19    35 E WACKER  survey required       NIS           9      1     3721
# 18    35 E WACKER  survey required       NIS           9      1     3722
# 17    35 E WACKER  survey required       NIS           9      1     3723
# 2370  35 E WACKER  survey required       NIS           9      1     3724
# 2366  35 E WACKER  survey required       NIS           9      1     3725
# 2369  35 E WACKER  survey required       NIS           9      1     3726
# 2368  35 E WACKER  survey required       NIS           9      1     3727
# 2367  35 E WACKER  survey required       NIS           9      1     3728
# 2371  35 E WACKER  survey required       NIS           9      1     3729
# 721   35 E WACKER  survey required       NIS           9      1     3730
# 174   35 E WACKER  survey required       NIS           9      1     3731
# 172   35 E WACKER  survey required       NIS           9      1     3732
# 173   35 E WACKER  survey required       NIS           9      1     3733
# 171   35 E WACKER  survey required       NIS           9      1     3734
# 2375  35 E WACKER  survey required       NIS           9      1     3735
# 2374  35 E WACKER  survey required       NIS           9      1     3736
# 2490  35 E WACKER  survey required       NIS           9      1     3737
# 2372  35 E WACKER  survey required       NIS           9      1     3738
# 2373  35 E WACKER  survey required       NIS           9      1     3739
# 2485  35 E WACKER  survey required       NIS           9      1     3740
# 2486  35 E WACKER  survey required       NIS           9      1     3741
# 2487  35 E WACKER  survey required       NIS           9      1     3742
# 2488  35 E WACKER  survey required       NIS           9      1     3743
# 2489  35 E WACKER  survey required       NIS           9      1     3744
# 2378  35 E WACKER  survey required       NIS           9      1     3745
# 2379  35 E WACKER  survey required       NIS           9      1     3746
# 2317  35 E WACKER  survey required       NIS           9      1     3747
#
# [3747 rows x 22 columns]

# %%
df.dtypes
# Out:
# layer              object
# name               object
# zones              object
# guid               object
# x                 float64
# y                 float64
# z                 float64
# new                  bool
# co                float64
# priority_ctrac    float64
# swing_drop         object
# faulty             object
# remediation        object
# deduct             object
# floor               int64
# elevation          object
# project            object
# bv_survey          object
# co11_12            object
# mk_priority        object
# ct_val              int64
# ct_order            int64
# dtype: object
