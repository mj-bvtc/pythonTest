# %%
import uuid
import datetime
import os
import platform
import datetime
import time
import pandas as pd

def get_data(excel):
    df = pd.DataFrame.from_csv(excel)
    return df

def get_user():
    return os.getenv('username')


def get_machine():
    return platform.node()


class Common:
    def __init__(self):
        self.id = uuid.uuid4()
        self.created = datetime.datetime.now()
        self.user = get_user()
        self.machine = get_machine()
        

class Block(Common):
    def __init__(self,
                 ctrac_style=None, 
                 est_style=None, 
                 description=None, 
                 quantity=None, 
                 instance=None):
        super().__init__()
        self.ctrac_style = ctrac_style
        self.est_style = est_style
        self.description = description
        self.quantity = quantity
        self.instance = instance
        
    def declare_instance(self):
        print(f"Instance {self.instance} of {self.quantity}")
        
        
    
    
def main():    
    t = Block()

    t.__dict__
    
    data = r"C:\Users\mkreidler\Desktop\Moynihan PHII 3-6-17 Cornice ALT.csv"
    df = get_data(data)
    
    
    
if __name__ == "__main__":
    # main()
    pass
    

#compile and 
data = r"C:\Users\mkreidler\Desktop\Moynihan PHII 3-6-17 Cornice ALT.csv"
df = get_data(data)
#df[["Style", "Description", "Qty of Units"]].reset_index()
df.reset_index(inplace=True)
df = df[["Style", "Description", "Qty of Units"]]
df.rename(index=str, 
          columns={"Style":"est_style", 
                   "Description":"desc", 
                   "Qty of Units":"qty"}, inplace=True)


df["ctrac_style"] = ["CN1", "CN2","CN3"]

df
# Out:
#   est_style                desc  qty ctrac_style
# 0        CT         Cornice Top   58         CN1
# 1        CB      Cornice Bottom    2         CN2
# 2      CT-C  Cornice Top Corner    4         CN3

# %%
#select a row
df.iloc[[1]]
# Out:
#   est_style            desc  qty ctrac_style
# 1        CB  Cornice Bottom    2         CN2

# %%
#select like 'where' in SQL
#show me the dataframe where CN1 is in the ctrac_style column
df[df["ctrac_style"]=="CN1"]
# Out:
#   est_style         desc  qty ctrac_style
# 0        CT  Cornice Top   58         CN1

# %%
#get the sum of a column
df["qty"].sum()
# Out:
# 64

# %%
df["est_style"]
# Out:
# 0      CT
# 1      CB
# 2    CT-C
# Name: est_style, dtype: object

# %%
df.iloc[[1]]["est_style"]
# Out:
# 1    CB
# Name: est_style, dtype: object

# %%
df["qty"].values.tolist()
# Out:
# [58, 2, 4]

# %%
df
# Out:
#   est_style                desc  qty ctrac_style
# 0        CT         Cornice Top   58         CN1
# 1        CB      Cornice Bottom    2         CN2
# 2      CT-C  Cornice Top Corner    4         CN3

# %%
blocks = []

for line in range(len(df)):
    #print(line)
    
    qty = int(df.iloc[[line]]["qty"].to_string(index=False))
    
    if qty > 0:
        
        #print("Quantity greater than zero")
        
        for i in range(qty):
            ctrac = df.iloc[[line]]["ctrac_style"].to_string(index=False)
            est = df.iloc[[line]]["est_style"].to_string(index=False)
            desc = df.iloc[[line]]["desc"].to_string(index=False)
            
    
            b = Block(ctrac_style = ctrac, 
                      est_style = est, 
                      description = desc, 
                      quantity = qty, 
                      instance=i+1)
            blocks.append(b)
        
            #print(b.__dict__)
        
#for b in blocks:
#    print(b.ctrac_style)
#    print(b.id)
#    b.declare_instance()
#    print()
           
    
dd = pd.DataFrame([vars(x) for x in blocks])
dd
# Out:
#                       created ctrac_style         description est_style  \
# 0  2018-04-27 07:12:23.748013         CN1         Cornice Top        CT
# 1  2018-04-27 07:12:23.750013         CN1         Cornice Top        CT
# 2  2018-04-27 07:12:23.752013         CN1         Cornice Top        CT
# 3  2018-04-27 07:12:23.755013         CN1         Cornice Top        CT
# 4  2018-04-27 07:12:23.757013         CN1         Cornice Top        CT
# 5  2018-04-27 07:12:23.759013         CN1         Cornice Top        CT
# 6  2018-04-27 07:12:23.762013         CN1         Cornice Top        CT
# 7  2018-04-27 07:12:23.764013         CN1         Cornice Top        CT
# 8  2018-04-27 07:12:23.766013         CN1         Cornice Top        CT
# 9  2018-04-27 07:12:23.769013         CN1         Cornice Top        CT
# 10 2018-04-27 07:12:23.771013         CN1         Cornice Top        CT
# 11 2018-04-27 07:12:23.773013         CN1         Cornice Top        CT
# 12 2018-04-27 07:12:23.775013         CN1         Cornice Top        CT
# 13 2018-04-27 07:12:23.778013         CN1         Cornice Top        CT
# 14 2018-04-27 07:12:23.780013         CN1         Cornice Top        CT
# 15 2018-04-27 07:12:23.782013         CN1         Cornice Top        CT
# 16 2018-04-27 07:12:23.784013         CN1         Cornice Top        CT
# 17 2018-04-27 07:12:23.785013         CN1         Cornice Top        CT
# 18 2018-04-27 07:12:23.787013         CN1         Cornice Top        CT
# 19 2018-04-27 07:12:23.789013         CN1         Cornice Top        CT
# 20 2018-04-27 07:12:23.791013         CN1         Cornice Top        CT
# 21 2018-04-27 07:12:23.793013         CN1         Cornice Top        CT
# 22 2018-04-27 07:12:23.795013         CN1         Cornice Top        CT
# 23 2018-04-27 07:12:23.796013         CN1         Cornice Top        CT
# 24 2018-04-27 07:12:23.798013         CN1         Cornice Top        CT
# 25 2018-04-27 07:12:23.800013         CN1         Cornice Top        CT
# 26 2018-04-27 07:12:23.802013         CN1         Cornice Top        CT
# 27 2018-04-27 07:12:23.804013         CN1         Cornice Top        CT
# 28 2018-04-27 07:12:23.806013         CN1         Cornice Top        CT
# 29 2018-04-27 07:12:23.808013         CN1         Cornice Top        CT
# ..                        ...         ...                 ...       ...
# 34 2018-04-27 07:12:23.818013         CN1         Cornice Top        CT
# 35 2018-04-27 07:12:23.819013         CN1         Cornice Top        CT
# 36 2018-04-27 07:12:23.821013         CN1         Cornice Top        CT
# 37 2018-04-27 07:12:23.823013         CN1         Cornice Top        CT
# 38 2018-04-27 07:12:23.825013         CN1         Cornice Top        CT
# 39 2018-04-27 07:12:23.827013         CN1         Cornice Top        CT
# 40 2018-04-27 07:12:23.829013         CN1         Cornice Top        CT
# 41 2018-04-27 07:12:23.831013         CN1         Cornice Top        CT
# 42 2018-04-27 07:12:23.832013         CN1         Cornice Top        CT
# 43 2018-04-27 07:12:23.834013         CN1         Cornice Top        CT
# 44 2018-04-27 07:12:23.836013         CN1         Cornice Top        CT
# 45 2018-04-27 07:12:23.838013         CN1         Cornice Top        CT
# 46 2018-04-27 07:12:23.840013         CN1         Cornice Top        CT
# 47 2018-04-27 07:12:23.842013         CN1         Cornice Top        CT
# 48 2018-04-27 07:12:23.844013         CN1         Cornice Top        CT
# 49 2018-04-27 07:12:23.846013         CN1         Cornice Top        CT
# 50 2018-04-27 07:12:23.848013         CN1         Cornice Top        CT
# 51 2018-04-27 07:12:23.850013         CN1         Cornice Top        CT
# 52 2018-04-27 07:12:23.852013         CN1         Cornice Top        CT
# 53 2018-04-27 07:12:23.853013         CN1         Cornice Top        CT
# 54 2018-04-27 07:12:23.855013         CN1         Cornice Top        CT
# 55 2018-04-27 07:12:23.857013         CN1         Cornice Top        CT
# 56 2018-04-27 07:12:23.859013         CN1         Cornice Top        CT
# 57 2018-04-27 07:12:23.862013         CN1         Cornice Top        CT
# 58 2018-04-27 07:12:23.864013         CN2      Cornice Bottom        CB
# 59 2018-04-27 07:12:23.866013         CN2      Cornice Bottom        CB
# 60 2018-04-27 07:12:23.869013         CN3  Cornice Top Corner      CT-C
# 61 2018-04-27 07:12:23.870013         CN3  Cornice Top Corner      CT-C
# 62 2018-04-27 07:12:23.873013         CN3  Cornice Top Corner      CT-C
# 63 2018-04-27 07:12:23.875013         CN3  Cornice Top Corner      CT-C
#
#                                       id  instance        machine  quantity  \
# 0   0c0f42a5-d378-4dd0-b5f3-01631d30d734         1  BVTC-Render08        58
# 1   64c49133-5d42-41eb-b4da-22c09af26ac0         2  BVTC-Render08        58
# 2   01c0175d-cecd-4962-b987-38ad15dee9a3         3  BVTC-Render08        58
# 3   62d3f7ad-d639-4888-ae7f-e2c44ed58629         4  BVTC-Render08        58
# 4   a34ed55e-57f2-4261-9855-974669b16ffb         5  BVTC-Render08        58
# 5   4a4f41cf-7e64-4a0f-9526-77530b0ae3e9         6  BVTC-Render08        58
# 6   a7689229-aff4-4208-9bae-f3578e819cc4         7  BVTC-Render08        58
# 7   9b2dc54e-4c82-4808-b761-8b37e5b6d782         8  BVTC-Render08        58
# 8   e92303d2-0ac7-47ca-8a42-71e51918bf66         9  BVTC-Render08        58
# 9   28d05a00-d2a4-4dfe-bd9b-74160baedc04        10  BVTC-Render08        58
# 10  a7993dc2-bcba-44cb-8749-2567444e700b        11  BVTC-Render08        58
# 11  c01dd520-56c7-4221-acce-e6be78292fa4        12  BVTC-Render08        58
# 12  29ea4c27-bb5c-4e63-a5a1-d025400a17e9        13  BVTC-Render08        58
# 13  887896ae-254c-4036-b2e4-705b246990dd        14  BVTC-Render08        58
# 14  22d7c2fd-8c8f-467f-abed-6d3fcbdd6314        15  BVTC-Render08        58
# 15  2d5970b2-2743-42ad-b6bb-fc404a967a17        16  BVTC-Render08        58
# 16  f3d404f2-9c51-4a95-9397-cda08f2aa7e1        17  BVTC-Render08        58
# 17  bcc61598-badd-4a3c-966b-8e1e2a31bd62        18  BVTC-Render08        58
# 18  db303dd4-dc24-401f-89bc-dd485c0adcc6        19  BVTC-Render08        58
# 19  8db9730a-dd79-4455-916a-e5ccd4772d70        20  BVTC-Render08        58
# 20  9a98fe5e-d960-4fee-a930-0ab54296b6aa        21  BVTC-Render08        58
# 21  addd4b8a-9725-4f7f-bb7d-bf9a5a977f1d        22  BVTC-Render08        58
# 22  92836e6b-96a5-4d2e-8f93-9f247d6ad82e        23  BVTC-Render08        58
# 23  8853c019-6ab1-426d-b635-e94b1a66c5ed        24  BVTC-Render08        58
# 24  c99933fa-723f-4cd6-9180-b0a5ac489f29        25  BVTC-Render08        58
# 25  da37e845-2334-4e3d-a18b-0a9ccbd13469        26  BVTC-Render08        58
# 26  1851a771-4f56-4bfd-95f0-c5554530cd86        27  BVTC-Render08        58
# 27  876a445f-bf8b-46c0-b3ee-0a30615b8025        28  BVTC-Render08        58
# 28  e88f9f66-543c-4538-98b3-3061a5a90acc        29  BVTC-Render08        58
# 29  96fb2d9e-f0e4-40d3-a540-b0cf9989f783        30  BVTC-Render08        58
# ..                                   ...       ...            ...       ...
# 34  492699a4-6dd6-45c0-923c-c0846fac372c        35  BVTC-Render08        58
# 35  ce577c93-74be-4582-8119-674936e9b9da        36  BVTC-Render08        58
# 36  0b2db180-d972-4f0d-aac3-3ac645c4c554        37  BVTC-Render08        58
# 37  6cc7fa85-a5e8-47d2-883a-85b79c848aed        38  BVTC-Render08        58
# 38  360c5af1-6126-429a-b35e-6ccede6682bd        39  BVTC-Render08        58
# 39  f95aa934-268e-4625-a33b-ca79942a25a6        40  BVTC-Render08        58
# 40  ccdf2036-45b0-403f-bede-08a709ab31ad        41  BVTC-Render08        58
# 41  d0e20ad8-3241-4625-8f5f-d371f297cd45        42  BVTC-Render08        58
# 42  d342a2c4-df2c-4fc0-8b8b-eed02ecea13a        43  BVTC-Render08        58
# 43  23d08c0e-a453-4901-ba49-ef535acd61c1        44  BVTC-Render08        58
# 44  e5676781-6826-4b49-a509-d3bf5d0f67f2        45  BVTC-Render08        58
# 45  31f68702-d704-4a7e-95d4-78b22369df18        46  BVTC-Render08        58
# 46  4f581e97-4b83-4730-b29f-b83339555a82        47  BVTC-Render08        58
# 47  fdc5924d-856e-45d2-ae5c-8bbaf79dabd7        48  BVTC-Render08        58
# 48  3642762a-0acf-4b1c-be29-c395bca16c16        49  BVTC-Render08        58
# 49  0cf7eabb-4103-4e50-a667-b8c4ada880ca        50  BVTC-Render08        58
# 50  ba40b818-c62e-43cb-a198-adac4e9ab2b2        51  BVTC-Render08        58
# 51  1476fff6-e870-4ec7-a7cf-ebf024160072        52  BVTC-Render08        58
# 52  991cae3e-b1ea-445a-a376-963873d906b5        53  BVTC-Render08        58
# 53  ea6fdecf-60f4-43a5-bac9-96f84b677b1d        54  BVTC-Render08        58
# 54  a0f9a8f6-6ec9-4145-97a2-a73b91e4731d        55  BVTC-Render08        58
# 55  ece8449d-f934-4e98-86bf-82249bcd0bbd        56  BVTC-Render08        58
# 56  d95a1de4-ad18-4a3a-a311-efeec59c131e        57  BVTC-Render08        58
# 57  9303c6a7-f149-4b7d-bc2d-2fff15fba691        58  BVTC-Render08        58
# 58  100a4268-2328-4f99-8f95-c8a65cb3b12c         1  BVTC-Render08         2
# 59  30fa41fd-6821-42b5-b7c6-c8759331d42f         2  BVTC-Render08         2
# 60  f1ce5be8-81b2-42b0-b2fc-9237520c9e82         1  BVTC-Render08         4
# 61  4a4c23b3-c346-4ae9-9955-55e826a97c46         2  BVTC-Render08         4
# 62  f58ff455-ca68-4f8b-8bb8-9fd820a75109         3  BVTC-Render08         4
# 63  3f977d0f-5a01-4cb8-89fe-30daae535741         4  BVTC-Render08         4
#
#          user
# 0   mkreidler
# 1   mkreidler
# 2   mkreidler
# 3   mkreidler
# 4   mkreidler
# 5   mkreidler
# 6   mkreidler
# 7   mkreidler
# 8   mkreidler
# 9   mkreidler
# 10  mkreidler
# 11  mkreidler
# 12  mkreidler
# 13  mkreidler
# 14  mkreidler
# 15  mkreidler
# 16  mkreidler
# 17  mkreidler
# 18  mkreidler
# 19  mkreidler
# 20  mkreidler
# 21  mkreidler
# 22  mkreidler
# 23  mkreidler
# 24  mkreidler
# 25  mkreidler
# 26  mkreidler
# 27  mkreidler
# 28  mkreidler
# 29  mkreidler
# ..        ...
# 34  mkreidler
# 35  mkreidler
# 36  mkreidler
# 37  mkreidler
# 38  mkreidler
# 39  mkreidler
# 40  mkreidler
# 41  mkreidler
# 42  mkreidler
# 43  mkreidler
# 44  mkreidler
# 45  mkreidler
# 46  mkreidler
# 47  mkreidler
# 48  mkreidler
# 49  mkreidler
# 50  mkreidler
# 51  mkreidler
# 52  mkreidler
# 53  mkreidler
# 54  mkreidler
# 55  mkreidler
# 56  mkreidler
# 57  mkreidler
# 58  mkreidler
# 59  mkreidler
# 60  mkreidler
# 61  mkreidler
# 62  mkreidler
# 63  mkreidler
#
# [64 rows x 9 columns]
