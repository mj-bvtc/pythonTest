# %%
import pandas as pd
import re


file = r"C:\Users\mkreidler\Desktop\rhino.xlsx"
rhino = pd.read_excel(file)

file2 = r"C:\Users\mkreidler\Desktop\ctrac.xlsx"
ctrac = pd.read_excel(file2)

# %%
rhino.head()
# Out:
#    num                               layer  name  \
# 0    1   Model::CHANGE ORDER 9::CO9 P6 NEW  4B4A
# 1    2  Model::CHANGE ORDER 5::CO 5 P3 NEW  4B1F
# 2    3             Model::BASE BID::P3 NEW   3B2
# 3    4   Model::CHANGE ORDER 5::CO5 P6 NEW    W?
# 4    5   Model::CHANGE ORDER 9::CO9 P6 NEW  4A2?
#
#                                    guid   co  priority   new  faulty  \
# 0  dafb6a48-0e69-4fa7-b22a-5dfa30efcd16  9.0         6  True     NaN
# 1  0e121d15-0514-487c-8017-1b362cbd9c1f  5.0         3  True     NaN
# 2  064674eb-6866-400b-8b31-bd4f7ac4a525  NaN         3  True     NaN
# 3  53b89d31-60bb-4052-bbd7-423f37dbd5d9  5.0         6  True     NaN
# 4  72fd679c-86ff-4a7a-a186-ac72a551b89f  9.0         6  True     NaN
#
#    remediation  deduct question  \
# 0          NaN     NaN      NaN
# 1          NaN     NaN      NaN
# 2          NaN     NaN      NaN
# 3          NaN     NaN        x
# 4          NaN     NaN        x
#
#                                                zones            x     y  \
# 0  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S5'// ... -1551.306469 -88.5
# 1  ['FLOOR 21'// 'EAST ELEVATION'// 'DROP E1'// '...  6082.936299 -88.5
# 2  ['FLOOR 21'// 'SOUTH ELEVATION'// 'DROP S1'// ...    87.075733 -88.5
# 3  ['FLOOR 24'// 'SOUTH ELEVATION'// 'DROP S5'// ... -1640.468391 -88.5
# 4  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S5'// ... -1601.243115 -88.5
#
#             z  floor elevation      project swing_drop
# 0  226.358817     20     SOUTH  35 E WACKER         S5
# 1  344.433324     21      EAST  35 E WACKER         E1
# 2  383.323683     21     SOUTH  35 E WACKER         S1
# 3  867.099570     24     SOUTH  35 E WACKER         S5
# 4  239.666353     20     SOUTH  35 E WACKER         S5

# %%
ctrac.head()
# Out:
#    name  quantity  length  height  depth description dwg_num      comments
# 0   2B1         0    23.0   11.50  8.125      FRIEZE   35E-1  BOTTOM RIGHT
# 1   2B1         2    23.0   11.50  8.125      FRIEZE   35E-1  BOTTOM RIGHT
# 2  2B10         1    21.0   11.50  6.250      FRIEZE   35E-2     AT CORNER
# 3  2B11         1    22.5   11.75  8.875      HEADER   35E-4         RIGHT
# 4  2B11         1    22.5   11.75  8.875      HEADER   35E-4         RIGHT

# %%
ctrac = ctrac.drop_duplicates("name")
ctrac.head()
# Out:
#    name  quantity  length  height  depth description  dwg_num      comments
# 0   2B1         0   23.00   11.50  8.125      FRIEZE    35E-1  BOTTOM RIGHT
# 2  2B10         1   21.00   11.50  6.250      FRIEZE    35E-2     AT CORNER
# 3  2B11         1   22.50   11.75  8.875      HEADER    35E-4         RIGHT
# 5  2B12         1   21.75   11.25  8.125      FRIEZE  35E-6-1           NaN
# 6  2B13         1   10.75   11.25  8.125      FRIEZE  35E-6-2           NaN

# %%
rhino_ctrac = rhino.merge(ctrac, how="left", on="name")

len(rhino_ctrac)
# Out:
# 368

# %%
ctrac_rhino = rhino.merge(ctrac, how="right", on="name")

len(ctrac_rhino)
# Out:
# 622

# %%
merge = rhino.merge(ctrac, how="inner", on="name")

len(merge)
# Out:
# 321

# %%
merge
# Out:
#       num                               layer  name  \
# 0       1   Model::CHANGE ORDER 9::CO9 P6 NEW  4B4A
# 1       2  Model::CHANGE ORDER 5::CO 5 P3 NEW  4B1F
# 2       3             Model::BASE BID::P3 NEW   3B2
# 3       6   Model::CHANGE ORDER 9::CO9 P6 NEW   4A2
# 4       7   Model::CHANGE ORDER 9::CO9 P2 NEW  Q108
# 5       8   Model::CHANGE ORDER 9::CO9 P2 NEW  Q108
# 6       9   Model::CHANGE ORDER 9::CO9 P2 NEW  Q108
# 7      10   Model::CHANGE ORDER 9::CO9 P2 NEW  Q108
# 8      11  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 9      12  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 10     13  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 11     14  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 12    267  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 13    336  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 14    344  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 15    349  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 16    351  Model::CHANGE ORDER 5::CO 5 P2 NEW  Q108
# 17    585  Model::CHANGE ORDER 5::CO 5 P3 NEW  Q108
# 18    587  Model::CHANGE ORDER 5::CO 5 P3 NEW  Q108
# 19     17  Model::CHANGE ORDER 5::CO 5 P3 NEW  6B16
# 20     18  Model::CHANGE ORDER 5::CO 5 P3 NEW  6B12
# 21     24  Model::CHANGE ORDER 5::CO 5 P1 NEW  Q114
# 22    223  Model::CHANGE ORDER 5::CO 5 P3 NEW  Q114
# 23    237   Model::CHANGE ORDER 2::CO2 P1 NEW  Q114
# 24     26   Model::CHANGE ORDER 9::CO9 P3 NEW   8C1
# 25    171   Model::CHANGE ORDER 9::CO9 P1 NEW   8C1
# 26     29  Model::CHANGE ORDER 5::CO 5 P3 NEW  4B1K
# 27     32  Model::CHANGE ORDER 5::CO 5 P3 NEW   B21
# 28   3684  Model::CHANGE ORDER 5::CO 5 P1 NEW   B21
# 29     33  Model::CHANGE ORDER 5::CO 5 P3 NEW   A16
# ..    ...                                 ...   ...
# 291   523  Model::CHANGE ORDER 5::CO 5 P3 NEW   AR1
# 292   524  Model::CHANGE ORDER 5::CO 5 P3 NEW  Q102
# 293   592   Model::CHANGE ORDER 9::CO9 P3 NEW    H1
# 294   593  Model::CHANGE ORDER 5::CO 5 P3 NEW   CA1
# 295   641  Model::CHANGE ORDER 5::CO 5 P3 NEW  4B3G
# 296   723   Model::CHANGE ORDER 9::CO9 P6 NEW  6A3A
# 297   726   Model::CHANGE ORDER 9::CO9 P6 NEW  6A3A
# 298   761   Model::CHANGE ORDER 9::CO9 P9 NEW  6A3A
# 299   984   Model::CHANGE ORDER 9::CO9 P4 NEW  6A3A
# 300  1403  Model::CHANGE ORDER 9::CO9 P11 NEW   B38
# 301  1404  Model::CHANGE ORDER 9::CO9 P11 NEW   B38
# 302  1777             Model::BASE BID::P8 NEW   8C6
# 303  1789   Model::CHANGE ORDER 9::CO9 P6 NEW   9C1
# 304  1790   Model::CHANGE ORDER 9::CO9 P6 NEW   9C1
# 305  1793             Model::BASE BID::P6 NEW   3B4
# 306  1795   Model::CHANGE ORDER 9::CO9 P5 NEW   B37
# 307  3685  Model::CHANGE ORDER 5::CO 5 P1 NEW   B37
# 308  2460   Model::CHANGE ORDER 9::CO9 P5 NEW  A23A
# 309  2463   Model::CHANGE ORDER 9::CO9 P5 NEW  A23A
# 310  2467   Model::CHANGE ORDER 9::CO9 P5 NEW  A23A
# 311  2470   Model::CHANGE ORDER 9::CO9 P4 NEW  A23A
# 312  2469   Model::CHANGE ORDER 9::CO9 P4 NEW   A12
# 313  3048   Model::CHANGE ORDER 9::CO9 P4 NEW  6A4A
# 314  3049   Model::CHANGE ORDER 9::CO9 P4 NEW  6A4A
# 315  3050   Model::CHANGE ORDER 9::CO9 P4 NEW  6A9A
# 316  3051   Model::CHANGE ORDER 9::CO9 P4 NEW  6A9A
# 317  3052   Model::CHANGE ORDER 9::CO9 P4 NEW   A11
# 318  3053   Model::CHANGE ORDER 9::CO9 P4 NEW  A20A
# 319  3679   Model::CHANGE ORDER 2::CO2 P1 NEW   B27
# 320  3681  Model::CHANGE ORDER 5::CO 5 P3 NEW   6B9
#
#                                      guid   co  priority   new  faulty  \
# 0    dafb6a48-0e69-4fa7-b22a-5dfa30efcd16  9.0         6  True     NaN
# 1    0e121d15-0514-487c-8017-1b362cbd9c1f  5.0         3  True     NaN
# 2    064674eb-6866-400b-8b31-bd4f7ac4a525  NaN         3  True     NaN
# 3    487c0c80-1715-4126-89cf-9df128a1281b  9.0         6  True     NaN
# 4    838b37e0-9a97-4452-ac22-e50d24c70669  9.0         2  True     NaN
# 5    6167a1f1-253d-4318-af6f-92cb07e7bea0  9.0         2  True     NaN
# 6    655103ae-8145-4572-9284-00e46576c13b  9.0         2  True     NaN
# 7    44adc1e5-321d-464c-8c28-b7b7d5aa0af8  9.0         2  True     NaN
# 8    8d9a56c4-b4f7-4156-a923-4adc252b4a33  5.0         2  True     NaN
# 9    487d28f0-0e6d-43a8-b55e-d2a052146fa8  5.0         2  True     NaN
# 10   6c70d0d3-e0a0-485b-bf58-97158e9cdcd0  5.0         2  True     NaN
# 11   c92c0086-c9e2-4b5e-a8df-554ecb3480b6  5.0         2  True     NaN
# 12   7bde075d-74e7-470b-8a21-58193f334cf3  5.0         2  True     NaN
# 13   4aaf7195-2cb8-439e-a01d-7151234d32b3  5.0         2  True     NaN
# 14   d712d4ad-b873-4937-b125-767c883f27eb  5.0         2  True     NaN
# 15   8b829416-9e97-4f25-a7c2-8d8042c25640  5.0         2  True     NaN
# 16   20a32c9f-1552-4c79-9e98-6f397f8e2420  5.0         2  True     NaN
# 17   89060bd9-586c-45cc-b473-000422bd5f35  5.0         3  True     NaN
# 18   b7e5f031-9301-4247-8bec-e0d973308ef6  5.0         3  True     NaN
# 19   cba982cb-e73a-4d6a-a9fe-a3040b1f2a65  5.0         3  True     NaN
# 20   43b41ee5-93b4-4d97-b40f-fe9aa0a73251  5.0         3  True     NaN
# 21   5a961dc0-c1aa-40ee-87c0-d6feb86ec15b  5.0         1  True     NaN
# 22   40c4b6c3-c7d3-4cf9-a4f2-0f839c618daa  5.0         3  True     NaN
# 23   88efb0d1-9a10-4a30-879f-2d925d69aba3  2.0         1  True     NaN
# 24   33fd6f95-499b-4157-ab1d-643c4c338e97  9.0         3  True     NaN
# 25   9719aa7a-8f3b-4f90-9ab4-95b29a767588  9.0         1  True     NaN
# 26   801bbee4-a5c2-4d3f-a455-39d1848f5d64  5.0         3  True     NaN
# 27   c56c94b0-f082-43ca-bbe3-9914c1ddff89  5.0         3  True     NaN
# 28   7ef9624a-dd82-4d0d-bb65-4f6741f23db5  5.0         1  True     NaN
# 29   4d97da1d-bfd0-4d91-aa80-ae327ce7a97e  5.0         3  True     NaN
# ..                                    ...  ...       ...   ...     ...
# 291  df1daff4-1c7c-42e2-9aa0-1d07358163b0  5.0         3  True     NaN
# 292  f343fecc-5451-4ec8-854c-fb5d4022bee3  5.0         3  True     NaN
# 293  740fe5ca-49c5-45ff-8b29-198e4b91acff  9.0         3  True     NaN
# 294  75c58ecd-409b-4e63-aae7-28e60e9f3b82  5.0         3  True     NaN
# 295  a61f6670-cedb-413f-bbc7-017a26289873  5.0         3  True     NaN
# 296  f64152a2-87b9-4842-8954-a842d5038992  9.0         6  True     NaN
# 297  8dc11a30-bdf6-49b6-b644-ef2b386367de  9.0         6  True     NaN
# 298  c862b199-b423-4c97-a23f-4afc5a190609  9.0         9  True     NaN
# 299  5b943f90-76b8-4127-857b-11af58e5005a  9.0         4  True     NaN
# 300  d71cdd28-bd9f-4858-b23e-32bf086d9532  9.0        11  True     NaN
# 301  df45f762-7b2b-4041-9fea-a2f4540da452  9.0        11  True     NaN
# 302  f286ef7f-48c6-48d1-8e0b-3c2e2114d352  NaN         8  True     NaN
# 303  09973a52-9ee7-4ebf-87ed-edbace152b66  9.0         6  True     NaN
# 304  0fba6390-fb76-474e-8139-46abc661eb21  9.0         6  True     NaN
# 305  f01bb248-7064-4dba-8ef7-2bb6ddda74bd  NaN         6  True     NaN
# 306  49767d3f-2110-449e-8fcb-b0fc0ac17597  9.0         5  True     NaN
# 307  30828f95-607d-466c-8911-083da2bb48d4  5.0         1  True     NaN
# 308  31bf6a64-6393-49ae-aff5-78ca7bd1b4d2  9.0         5  True     NaN
# 309  2f07374c-4f78-457f-808c-09306d6c3f61  9.0         5  True     NaN
# 310  fd121e00-9646-452d-8c21-4561eaae321e  9.0         5  True     NaN
# 311  b4b194fe-3548-4c35-bc38-0eb0eb2c8749  9.0         4  True     NaN
# 312  ab8ec0e1-98b9-4acd-adb7-bb74161bd619  9.0         4  True     NaN
# 313  d159b654-a262-4215-91e8-5f1bc02959ac  9.0         4  True     NaN
# 314  1d240264-9b63-4e83-8a57-98f9530bb0b4  9.0         4  True     NaN
# 315  1ee439ec-d60f-4009-aecd-87da68b64d09  9.0         4  True     NaN
# 316  6bf4ea99-fc7d-4e5e-83a6-75a319578550  9.0         4  True     NaN
# 317  d21ffc31-2307-41a6-97be-fa7d056b2cb8  9.0         4  True     NaN
# 318  44f7b71f-a168-4df4-8c93-f5d94ea0c6f7  9.0         4  True     NaN
# 319  5c872270-40fe-494a-a540-1ef9196be3d9  2.0         1  True     NaN
# 320  ffae739b-573d-46dc-acdf-4761c18125b3  5.0         3  True     NaN
#
#      remediation  deduct      ...       elevation      project  swing_drop  \
# 0            NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 1            NaN     NaN      ...            EAST  35 E WACKER          E1
# 2            NaN     NaN      ...           SOUTH  35 E WACKER          S1
# 3            NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 4            NaN     NaN      ...            EAST  35 E WACKER          E1
# 5            NaN     NaN      ...            EAST  35 E WACKER          E1
# 6            NaN     NaN      ...            EAST  35 E WACKER          E1
# 7            NaN     NaN      ...            EAST  35 E WACKER          E1
# 8            NaN     NaN      ...            EAST  35 E WACKER          E1
# 9            NaN     NaN      ...            EAST  35 E WACKER          E1
# 10           NaN     NaN      ...            EAST  35 E WACKER          E1
# 11           NaN     NaN      ...            EAST  35 E WACKER          E1
# 12           NaN     NaN      ...            EAST  35 E WACKER          E1
# 13           NaN     NaN      ...            EAST  35 E WACKER          E1
# 14           NaN     NaN      ...            EAST  35 E WACKER          E1
# 15           NaN     NaN      ...            EAST  35 E WACKER          E1
# 16           NaN     NaN      ...            EAST  35 E WACKER          E1
# 17           NaN     NaN      ...            EAST  35 E WACKER          E1
# 18           NaN     NaN      ...            EAST  35 E WACKER          E1
# 19           NaN     NaN      ...            EAST  35 E WACKER          E1
# 20           NaN     NaN      ...            EAST  35 E WACKER          E1
# 21           NaN     NaN      ...            EAST  35 E WACKER          E1
# 22           NaN     NaN      ...            EAST  35 E WACKER          E1
# 23           NaN     NaN      ...            EAST  35 E WACKER          E1
# 24           NaN     NaN      ...            EAST  35 E WACKER          E1
# 25           NaN     NaN      ...            EAST  35 E WACKER          E1
# 26           NaN     NaN      ...            EAST  35 E WACKER          E1
# 27           NaN     NaN      ...            EAST  35 E WACKER          E1
# 28           NaN     NaN      ...            EAST  35 E WACKER          E1
# 29           NaN     NaN      ...            EAST  35 E WACKER          E1
# ..           ...     ...      ...             ...          ...         ...
# 291          NaN     NaN      ...            EAST  35 E WACKER          E1
# 292          NaN     NaN      ...            EAST  35 E WACKER          E1
# 293          NaN     NaN      ...            EAST  35 E WACKER          E1
# 294          NaN     NaN      ...            EAST  35 E WACKER          E1
# 295          NaN     NaN      ...            EAST  35 E WACKER          E1
# 296          NaN     NaN      ...            WEST  35 E WACKER          W2
# 297          NaN     NaN      ...            WEST  35 E WACKER          W2
# 298          NaN     NaN      ...            WEST  35 E WACKER          W3
# 299          NaN     NaN      ...            WEST  35 E WACKER          W1
# 300          NaN     NaN      ...            WEST  35 E WACKER          W3
# 301          NaN     NaN      ...            WEST  35 E WACKER          W3
# 302          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 303          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 304          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 305          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 306          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 307          NaN     NaN      ...            EAST  35 E WACKER          E1
# 308          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 309          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 310          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 311          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 312          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 313          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 314          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 315          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 316          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 317          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 318          NaN     NaN      ...           SOUTH  35 E WACKER          S5
# 319          NaN     NaN      ...            EAST  35 E WACKER          E1
# 320          NaN     NaN      ...            EAST  35 E WACKER          E1
#
#      quantity  length   height  depth          description    dwg_num  \
# 0           1  24.000   5.7500   7.00      BELT COURSE STD     35E-35
# 1           2  23.750  12.0000   8.50      BELT COURSE STD     35E-31
# 2           2  23.250   5.7500   5.50      BELT COURSE STD     35E-10
# 3           1  21.250  16.8125  20.75      DECORATIVE BAND     35E-23
# 4           4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 5           4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 6           4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 7           4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 8           4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 9           4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 10          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 11          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 12          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 13          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 14          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 15          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 16          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 17          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 18          4   6.000  12.0000   8.50                QUOIN   35E-Q108
# 19          9  20.500  11.0000   6.50                FLUTE   35E-51-2
# 20          1  22.750  11.3750  15.50                FLUTE   35E-51-4
# 21          1   5.750  12.5000  15.25                QUOIN   35E-Q114
# 22          1   5.750  12.5000  15.25                QUOIN   35E-Q114
# 23          1   5.750  12.5000  15.25                QUOIN   35E-Q114
# 24         29  12.875  12.0000   4.50                 BAND     35E-63
# 25         29  12.875  12.0000   4.50                 BAND     35E-63
# 26          2  22.000  12.0000   8.50                 BAND   35E-31-0
# 27          7  15.250  12.0000   8.00                QUOIN   35E-53-7
# 28          7  15.250  12.0000   8.00                QUOIN   35E-53-7
# 29          8  18.625  12.0000   4.00               ASHLAR     35E-69
# ..        ...     ...      ...    ...                  ...        ...
# 291         1  14.000  15.9375   7.75         ARCH SEGMENT    35E-AR1
# 292         1  20.875  12.0000  13.00                QUOIN   35E-Q102
# 293         1  22.500  11.7500  10.00               HEADER     35E-H1
# 294         1  26.000  12.0000  15.00              CAPITOL    35E-CA1
# 295         1  22.500   5.7500   6.25      BELT COURSE STD   35E-34-2
# 296         2  21.500  11.0000   4.00               FRIEZE   35E-42-1
# 297         2  21.500  11.0000   4.00               FRIEZE   35E-42-1
# 298         2  21.500  11.0000   4.00               FRIEZE   35E-42-1
# 299         2  21.500  11.0000   4.00               FRIEZE   35E-42-1
# 300        40   6.000  12.0000   6.00                QUOIN  35E-108-3
# 301        40   6.000  12.0000   6.00                QUOIN  35E-108-3
# 302         1  11.000  12.0000   5.00      DECORATIVE BAND   35E-68-0
# 303        16   4.500  12.0000   4.00                 JAMB     35E-77
# 304        16   4.500  12.0000   4.00                 JAMB     35E-77
# 305         1  25.750   5.7500   5.50  BELT COURSE OC LEFT     35E-11
# 306        37   8.000  12.0000   6.00                QUOIN  35E-108-3
# 307        37   8.000  12.0000   6.00                QUOIN  35E-108-3
# 308        24   6.000  12.0000   4.00               ASHLAR   35E-69-9
# 309        24   6.000  12.0000   4.00               ASHLAR   35E-69-9
# 310        24   6.000  12.0000   4.00               ASHLAR   35E-69-9
# 311        24   6.000  12.0000   4.00               ASHLAR   35E-69-9
# 312         2  19.750  12.0000   4.00               ASHLAR     35E-69
# 313         6  20.750  11.0000   4.00               FRIEZE     35E-41
# 314         6  20.750  11.0000   4.00               FRIEZE     35E-41
# 315         1  21.000  11.0000   4.00               FRIEZE     35E-41
# 316         1  21.000  11.0000   4.00               FRIEZE     35E-41
# 317         2  20.000  12.0000   4.00               ASHLAR     35E-69
# 318         1  11.500  12.0000   4.00               ASHLAR   35E-69-9
# 319        11  13.000  12.0000   4.00                QUOIN     35E-53
# 320         1  16.250  11.0000   4.00                FLUTE     35E-51
#
#           comments
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19          HEADER
# 20          HEADER
# 21             NaN
# 22             NaN
# 23             NaN
# 24   DECORATIVE OC
# 25   DECORATIVE OC
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ..             ...
# 291            NaN
# 292            NaN
# 293            NaN
# 294            NaN
# 295            NaN
# 296            NaN
# 297            NaN
# 298            NaN
# 299            NaN
# 300            NaN
# 301            NaN
# 302            NaN
# 303            NaN
# 304            NaN
# 305            NaN
# 306            NaN
# 307            NaN
# 308            NaN
# 309            NaN
# 310            NaN
# 311            NaN
# 312            NaN
# 313            NaN
# 314            NaN
# 315            NaN
# 316            NaN
# 317            NaN
# 318            NaN
# 319            NaN
# 320          RIGHT
#
# [321 rows x 26 columns]

# %%
#merge.to_excel(r"C:\Users\mkreidler\Desktop\35ewacker_merge.xlsx")
len(merge)
# Out:
# 321

# %%
merge_cut = merge.drop_duplicates("name")
len(merge_cut)
# Out:
# 72

# %%
#merge_cut.to_excel(r"C:\Users\mkreidler\Desktop\35ewacker_merge_cut.xlsx")

# %%
styles = merge_cut.name.tolist()
styles.sort()

print(len(styles))

styles
# Out:
# 72
# ['2B1',
#  '2B10',
#  '3B1',
#  '3B11',
#  '3B2',
#  '3B4',
#  '3C10',
#  '4A2',
#  '4A8',
#  '4B1F',
#  '4B1K',
#  '4B3G',
#  '4B4A',
#  '6A3A',
#  '6A4A',
#  '6A9A',
#  '6B12',
#  '6B16',
#  '6B9',
#  '8A2',
#  '8C1',
#  '8C2',
#  '8C6',
#  '9C1',
#  'A101',
#  'A102',
#  'A11',
#  'A12',
#  'A15',
#  'A15A',
#  'A16',
#  'A16A',
#  'A20A',
#  'A23A',
#  'AR1',
#  'B101',
#  'B17',
#  'B17A',
#  'B20',
#  'B20A',
#  'B21',
#  'B27',
#  'B34',
#  'B34A',
#  'B35A',
#  'B37',
#  'B38',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'CA1',
#  'H1',
#  'NF1',
#  'PA7',
#  'Q101',
#  'Q102',
#  'Q103',
#  'Q104',
#  'Q106',
#  'Q108',
#  'Q109',
#  'Q110',
#  'Q111',
#  'Q114',
#  'Q115',
#  'Q116',
#  'S1']

# %%
cnt = merge[["name","guid"]].groupby("name").count()

cnt
# Out:
#       guid
# name
# 2B1      2
# 2B10     1
# 3B1      1
# 3B11     2
# 3B2      1
# 3B4      1
# 3C10     2
# 4A2      1
# 4A8      2
# 4B1F     1
# 4B1K     1
# 4B3G     1
# 4B4A     1
# 6A3A     4
# 6A4A     2
# 6A9A     2
# 6B12     1
# 6B16     1
# 6B9      1
# 8A2      7
# 8C1      2
# 8C2      2
# 8C6      1
# 9C1      2
# A101     1
# A102     5
# A11      1
# A12      1
# A15     14
# A15A    14
# ...    ...
# B34     16
# B34A    14
# B35A     2
# B37      2
# B38      2
# C1       7
# C2       7
# C3       6
# C4       7
# C5       7
# C6       6
# C7       1
# C8       1
# CA1      1
# H1       1
# NF1      1
# PA7      1
# Q101     2
# Q102     1
# Q103    14
# Q104    14
# Q106     1
# Q108    15
# Q109    10
# Q110     9
# Q111     5
# Q114     3
# Q115     1
# Q116     1
# S1       1
#
# [72 rows x 1 columns]
