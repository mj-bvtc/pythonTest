# %%
import os
import pandas as pd
import datetime
import uuid
from PIL import Image
import tkinter
from tkinter import filedialog

def get_path(_title=None, default_dir=r"V:\Sample Data"):
    tkinter.Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
    path = filedialog.askdirectory(title=_title,
                                   initialdir=default_dir) # show an "Open" dialog box and return the path to the selected file
    msg = f"Found this path: {path}"
    print(msg)
    return path


#path = r"V:\Sample Data\Chatsworth Apartments"
path = get_path()

def get_pics():
    pics = []
    for root, dirs, files in os.walk(path, topdown=False):
       for name in files:
          if name.upper().endswith("JPG"):
                full = os.path.join(root, name)
                pics.append(full)
                
    return pics


def get_date_taken(path):
    return Image.open(path)._getexif()[36867]
                
pics = get_pics()

df = pd.DataFrame(pics)
df.columns = ["path"]

base = [os.path.basename(x) for x in pics]
dt = [get_date_taken(x) for x in pics]
qr = [str(uuid.uuid4()) for x in pics]
 
df["pic"] = base
df["datetime"] = dt
df["tbr"] = None
df["color_sample"] = None
df["broken"] = None
df["group"] = None
df["qr"] = qr
df["project"] = None
df["crate"] = None
df["unit"] = None
df["pallet"] = None

df = df.sort_values(by="datetime")
df = df.reset_index(drop=True)


def find(search):
    flags = ["Crate", 
             "Pallet", 
             "Broken", 
             "Project", 
            "Color"]
    for flag in flags:
        if flag.upper() in search.upper():
            return search

    

df["flags"] = df['pic'].apply(find)
df[["pic", "datetime", "flags"]].head()
df

def assign_labels(flag, series):
    label = None
    result = []
    search = series.tolist()
    for s in search:
        #print(f"flag: {flag}, search: {s}")
        try:
            if flag.upper() in s.upper():           
                a = s.upper().replace(".JPG", "")    
                b = a.upper().replace(flag.upper(), "")
                label = f"{b.title()}"
            result.append(label)
        except:
            result.append(label)
            continue
    return result
        
df["crate"] = assign_labels("Crate", df["flags"])
df["project"] = assign_labels("Project", df["flags"])
df["pallet"] = assign_labels("Pallet", df["flags"])



data = df[["pic", "flags", "unit"]]

df["unit"] = data["pic"][data["flags"].isnull()]

#df[["pic", "project"]]

#df

#TODO add checklist for tbr, color sample, broken piece
#TODO figure out groups

#output = r"V:\Sample Data\Chatsworth Apartments\SampleReport.xlsx"


def format_file(folder):
    ext = ".xlsx"
    timestamp = str(datetime.datetime.now()).replace(":","_")
    excel = timestamp + ext
    result = os.path.join(folder, "Sample_Report_" + excel)
    return result


def create_excel(path):      
    writer = pd.ExcelWriter(path)
    df.to_excel(writer,'Sheet1')
    writer.save()
    print(f"Created excel report: {path}")
    
#create_excel(output)

report = format_file(path)
create_excel(report)
# Out:
# Found this path: V:/Sample Data/Chatsworth Apartments/Log Photos
# Created excel report: V:/Sample Data/Chatsworth Apartments/Log Photos\Sample_Report_2018-04-14 11_02_02.372007.xlsx

# %%
import os
import pandas as pd
import datetime
import uuid
from PIL import Image
import tkinter
from tkinter import filedialog


def get_path(_title=None, default_dir=r"V:\Sample Data"):
    """
    brings up a dialog to search for directory
    """
    tkinter.Tk().withdraw()  # we don't want a full GUI, so keep the root window from appearing
    path = filedialog.askdirectory(title=_title,
                                   initialdir=default_dir)  # show an "Open" dialog box and return the path to the selected file
    msg = f"Found this path: {path}"
    print(msg)
    return path


def get_pics(path):
    """
    finds any .jpg in a given directory and returns a list of pics
    """
    pics = []
    for root, dirs, files in os.walk(path, topdown=False):
        for name in files:
            if name.upper().endswith("JPG"):
                full = os.path.join(root, name)
                pics.append(full)
    print(f"Found {len(pics)} photos")
    return pics


def get_date_taken(path):
    """gets the date a photo was taken"""
    return Image.open(path)._getexif()[36867]


def create_report(path):
    """
    after looking through the names of log photos,
    a framework is created in pandas.  A pandas
    data frame is created to correlate pictures to
    date taken, flags present, what project you are looking at,
    the Crate/Pallet/Unit you are looking at etc.
    """
    pics = get_pics(path)
    print("Setting up dataframe")
    df = pd.DataFrame(pics)
    df.columns = ["path"]

    base = [os.path.basename(x) for x in pics]
    dt = [get_date_taken(x) for x in pics]
    qr = [str(uuid.uuid4()) for x in pics]
    df["pic"] = base
    df["datetime"] = dt
    df["tbr"] = None
    df["color_sample"] = None
    df["broken"] = None
    df["group"] = None
    df["qr"] = qr
    df["project"] = None
    df["crate"] = None
    df["unit"] = None
    df["pallet"] = None

    df = df.sort_values(by="datetime")
    df = df.reset_index(drop=True)
    df["flags"] = df['pic'].apply(find_flags)
    df["crate"] = assign_labels("Crate", df["flags"])
    df["project"] = assign_labels("Project", df["flags"])
    df["pallet"] = assign_labels("Pallet", df["flags"])
    data = df[["pic", "flags", "unit"]]

    df["unit"] = data["pic"][data["flags"].isnull()]

    # TODO add checklist for tbr, color sample, broken piece

    return df


def find_flags(search):
    """searches for flags in list, returns results"""
    flags = ["Crate",
             "Pallet",
             "Broken",
             "Project",
             "Color"]
    for flag in flags:
        if flag.upper() in search.upper():
            return search


def assign_labels(flag, series):
    """labels cells of given column if necessary column contains proper flag"""
    label = None
    result = []
    search = series.tolist()
    for s in search:
        # print(f"flag: {flag}, search: {s}")
        try:
            if flag.upper() in s.upper():
                a = s.upper().replace(".JPG", "")
                b = a.upper().replace(flag.upper(), "")
                label = f"{b.title()}"
            result.append(label)

        except:
            result.append(label)
            continue
    return result


def format_file(folder):
    ext = ".xlsx"
    timestamp = str(datetime.datetime.now()).replace(":", "_")
    excel = timestamp + ext
    result = os.path.join(folder, "Sample_Report_" + excel)
    print(f"Formatted report: {result}")
    return result


def create_excel(path, df):
    writer = pd.ExcelWriter(path)
    df.to_excel(writer, 'Sheet1')
    writer.save()
    print(f"Created excel report: {path}")


def run():
    print("Selecting folder...")
    prompt = "Select the folder which contains log photos:"
    path = get_path(_title=prompt)
    # path = r"V:\Sample Data\Chatsworth Apartments\log photos"
    print("Creating report...")
    report = create_report(path)
    print("Formatting report...")
    report_path = format_file(path)
    print("Saving Excel Spreadsheet...")
    create_excel(report_path, report)
    print("Report: ")
    print(report)


def main():
    run()


if __name__ == "__main__":
    main()
# Out:
# Selecting folder...
# Found this path: V:/Sample Data/222 Central Park South/_Crate-Pallet-Unit Photos/Received 2018-04-10
# Creating report...
# Found 84 photos
# Setting up dataframe
# Formatting report...
# Formatted report: V:/Sample Data/222 Central Park South/_Crate-Pallet-Unit Photos/Received 2018-04-10\Sample_Report_2018-04-14 12_07_38.241007.xlsx
# Saving Excel Spreadsheet...
# Created excel report: V:/Sample Data/222 Central Park South/_Crate-Pallet-Unit Photos/Received 2018-04-10\Sample_Report_2018-04-14 12_07_38.241007.xlsx
# Report:
#                                                  path  \
# 0   V:/Sample Data/222 Central Park South/_Crate-P...
# 1   V:/Sample Data/222 Central Park South/_Crate-P...
# 2   V:/Sample Data/222 Central Park South/_Crate-P...
# 3   V:/Sample Data/222 Central Park South/_Crate-P...
# 4   V:/Sample Data/222 Central Park South/_Crate-P...
# 5   V:/Sample Data/222 Central Park South/_Crate-P...
# 6   V:/Sample Data/222 Central Park South/_Crate-P...
# 7   V:/Sample Data/222 Central Park South/_Crate-P...
# 8   V:/Sample Data/222 Central Park South/_Crate-P...
# 9   V:/Sample Data/222 Central Park South/_Crate-P...
# 10  V:/Sample Data/222 Central Park South/_Crate-P...
# 11  V:/Sample Data/222 Central Park South/_Crate-P...
# 12  V:/Sample Data/222 Central Park South/_Crate-P...
# 13  V:/Sample Data/222 Central Park South/_Crate-P...
# 14  V:/Sample Data/222 Central Park South/_Crate-P...
# 15  V:/Sample Data/222 Central Park South/_Crate-P...
# 16  V:/Sample Data/222 Central Park South/_Crate-P...
# 17  V:/Sample Data/222 Central Park South/_Crate-P...
# 18  V:/Sample Data/222 Central Park South/_Crate-P...
# 19  V:/Sample Data/222 Central Park South/_Crate-P...
# 20  V:/Sample Data/222 Central Park South/_Crate-P...
# 21  V:/Sample Data/222 Central Park South/_Crate-P...
# 22  V:/Sample Data/222 Central Park South/_Crate-P...
# 23  V:/Sample Data/222 Central Park South/_Crate-P...
# 24  V:/Sample Data/222 Central Park South/_Crate-P...
# 25  V:/Sample Data/222 Central Park South/_Crate-P...
# 26  V:/Sample Data/222 Central Park South/_Crate-P...
# 27  V:/Sample Data/222 Central Park South/_Crate-P...
# 28  V:/Sample Data/222 Central Park South/_Crate-P...
# 29  V:/Sample Data/222 Central Park South/_Crate-P...
# ..                                                ...
# 54  V:/Sample Data/222 Central Park South/_Crate-P...
# 55  V:/Sample Data/222 Central Park South/_Crate-P...
# 56  V:/Sample Data/222 Central Park South/_Crate-P...
# 57  V:/Sample Data/222 Central Park South/_Crate-P...
# 58  V:/Sample Data/222 Central Park South/_Crate-P...
# 59  V:/Sample Data/222 Central Park South/_Crate-P...
# 60  V:/Sample Data/222 Central Park South/_Crate-P...
# 61  V:/Sample Data/222 Central Park South/_Crate-P...
# 62  V:/Sample Data/222 Central Park South/_Crate-P...
# 63  V:/Sample Data/222 Central Park South/_Crate-P...
# 64  V:/Sample Data/222 Central Park South/_Crate-P...
# 65  V:/Sample Data/222 Central Park South/_Crate-P...
# 66  V:/Sample Data/222 Central Park South/_Crate-P...
# 67  V:/Sample Data/222 Central Park South/_Crate-P...
# 68  V:/Sample Data/222 Central Park South/_Crate-P...
# 69  V:/Sample Data/222 Central Park South/_Crate-P...
# 70  V:/Sample Data/222 Central Park South/_Crate-P...
# 71  V:/Sample Data/222 Central Park South/_Crate-P...
# 72  V:/Sample Data/222 Central Park South/_Crate-P...
# 73  V:/Sample Data/222 Central Park South/_Crate-P...
# 74  V:/Sample Data/222 Central Park South/_Crate-P...
# 20   222 Central Park South     8            NaN      4
# 21   222 Central Park South     8            NaN      5
# 22   222 Central Park South     8        018.JPG      5
# 23   222 Central Park South     8        08R.JPG      5
# 24   222 Central Park South     8        017.JPG      5
# 25   222 Central Park South     8       032R.JPG      5
# 26   222 Central Park South     8       030R.JPG      5
# 27   222 Central Park South     8       020R.JPG      5
# 28   222 Central Park South     8            NaN      6
# 29   222 Central Park South     8       021R.JPG      6
# ..                      ...   ...            ...    ...
# 54   222 Central Park South     6        AGA.JPG     10
# 55   222 Central Park South     6       ATRB.JPG     10
# 56   222 Central Park South     6            NaN     11
# 57   222 Central Park South     6          G.JPG     11
# 58   222 Central Park South     6        AH2.JPG     11
# 59   222 Central Park South     6        AG1.JPG     11
# 60   222 Central Park South     6        AJ3.JPG     11
# 61   222 Central Park South     6            NaN     12
# 62   222 Central Park South     6        WL1.JPG     12
# 63   222 Central Park South     6        ABR.JPG     12
# 64   222 Central Park South     9            NaN     12
# 65   222 Central Park South     9            NaN     13
# 66   222 Central Park South     9        06R.JPG     13
# 67   222 Central Park South     9         ST.JPG     13
# 68   222 Central Park South     9        GCB.JPG     13
# 69   222 Central Park South     9         GC.JPG     13
# 70   222 Central Park South     9            NaN     14
# 71   222 Central Park South     9        STR.JPG     14
# 72   222 Central Park South     9        STL.JPG     14
# 73   222 Central Park South     9        GCR.JPG     14
# 74   222 Central Park South     9        GCL.JPG     14
# 75   222 Central Park South     9        STB.JPG     14
# 76   222 Central Park South     9       020L.JPG     14
# 77   222 Central Park South     9            NaN     15
# 78   222 Central Park South     9        HCL.JPG     15
# 79   222 Central Park South     9       023L.JPG     15
# 80   222 Central Park South     9        HC1.JPG     15
# 81   222 Central Park South     9        HCR.JPG     15
# 82   222 Central Park South     9            NaN     16
# 83   222 Central Park South     9       022R.JPG     16
#
#                                  flags
# 0   Project 222 Central Park South.JPG
# 1                          Crate 7.JPG
# 2                         Pallet 1.JPG
# 3                                 None
# 4                                 None
# 5                                 None
# 6                                 None
# 7                                 None
# 8                         Pallet 2.JPG
# 9                                 None
# 10                                None
# 11                                None
# 12                                None
# 13                        PALLET 3.JPG
# 14                                None
# 15                                None
# 16                                None
# 17                        PALLET 4.JPG
# 18                                None
# 19                                None
# 20                         CRATE 8.JPG
# 21                        PALLET 5.JPG
# 22                                None
# 23                                None
# 24                                None
# 25                                None
# 26                                None
# 27                                None
# 28                        PALLET 6.JPG
# 29                                None
# ..                                 ...
# 54                                None
# 55                                None
# 56                       PALLET 11.JPG
# 57                                None
# 58                                None
# 59                                None
# 60                                None
# 61                       PALLET 12.JPG
# 62                                None
# 63                                None
# 64                         CRATE 9.JPG
# 65                       PALLET 13.JPG
# 66                                None
# 67                                None
# 68                                None
# 69                                None
# 70                       PALLET 14.JPG
# 71                                None
# 72                                None
# 73                                None
# 74                                None
# 75                                None
# 76                                None
# 77                       PALLET 15.JPG
# 78                                None
# 79                                None
# 80                                None
# 81                                None
# 82                       PALLET 16.JPG
# 83                                None
#
# [84 rows x 13 columns]

# %%
dog = "julia"

# %%
print(dog)
# Out:
# julia
