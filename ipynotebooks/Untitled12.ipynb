# %%
import kivy
kivy.require('1.11.1') # replace with your current kivy version !

from kivy.app import App
from kivy.uix.label import Label


class MyApp(App):

    def build(self):
        return Label(text='Hello world')


if __name__ == '__main__':
    MyApp().run()
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\core\window\window_sdl2.py in mainloop(self)
#     746             try:
# --> 747                 self._mainloop()
#     748             except BaseException as inst:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\core\window\window_sdl2.py in _mainloop(self)
#     478     def _mainloop(self):
# --> 479         EventLoop.idle()
#     480
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in idle(self)
#     361             Logger.error('Base: Application will leave')
# --> 362             self.exit()
#     363             return False
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in exit(self)
#     374         '''Close the main loop and close the window.'''
# --> 375         self.close()
#     376         if self.window:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in close(self)
#     171         self.quit = True
# --> 172         self.stop()
#     173         self.status = 'closed'
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in stop(self)
#     183         for provider in reversed(self.input_providers[:]):
# --> 184             provider.stop()
#     185             if provider in self.input_providers_autoremove:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\input\providers\wm_pen.py in stop(self)
#     110             self.pen = None
# --> 111             SetWindowLong_WndProc_wrapper(self.hwnd, self.old_windProc)
#     112
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\input\providers\wm_common.py in _closure(hWnd, wndProc)
#     121         def _closure(hWnd, wndProc):
# --> 122             oldAddr = func(hWnd, GWL_WNDPROC, cast(wndProc, c_void_p).value)
#     123             return cast(c_void_p(oldAddr), WNDPROC)
#
# ArgumentError: argument 3: <class 'TypeError'>: wrong type
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in runTouchApp(widget, slave)
#     503         else:
# --> 504             EventLoop.window.mainloop()
#     505     finally:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\core\window\window_sdl2.py in mainloop(self)
#     751                 if r == ExceptionManager.RAISE:
# --> 752                     stopTouchApp()
#     753                     raise
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in stopTouchApp()
#     520     Logger.info('Base: Leaving application in progress...')
# --> 521     EventLoop.close()
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in close(self)
#     171         self.quit = True
# --> 172         self.stop()
#     173         self.status = 'closed'
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in stop(self)
#     183         for provider in reversed(self.input_providers[:]):
# --> 184             provider.stop()
#     185             if provider in self.input_providers_autoremove:
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\input\providers\wm_pen.py in stop(self)
#     110             self.pen = None
# --> 111             SetWindowLong_WndProc_wrapper(self.hwnd, self.old_windProc)
#     112
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\input\providers\wm_common.py in _closure(hWnd, wndProc)
#     121         def _closure(hWnd, wndProc):
# --> 122             oldAddr = func(hWnd, GWL_WNDPROC, cast(wndProc, c_void_p).value)
#     123             return cast(c_void_p(oldAddr), WNDPROC)
#
# ArgumentError: argument 3: <class 'TypeError'>: wrong type
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-9-6c1f7076e999> in <module>
#      13
#      14 if __name__ == '__main__':
# ---> 15     MyApp().run()
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\app.py in run(self)
#     853
#     854         self.dispatch('on_start')
# --> 855         runTouchApp()
#     856         self.stop()
#     857
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in runTouchApp(widget, slave)
#     504             EventLoop.window.mainloop()
#     505     finally:
# --> 506         stopTouchApp()
#     507
#     508
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in stopTouchApp()
#     519         return
#     520     Logger.info('Base: Leaving application in progress...')
# --> 521     EventLoop.close()
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in close(self)
#     170         input providers.'''
#     171         self.quit = True
# --> 172         self.stop()
#     173         self.status = 'closed'
#     174
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\base.py in stop(self)
#     182         # problem happens, crashing badly without error
#     183         for provider in reversed(self.input_providers[:]):
# --> 184             provider.stop()
#     185             if provider in self.input_providers_autoremove:
#     186                 self.input_providers_autoremove.remove(provider)
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\input\providers\wm_pen.py in stop(self)
#     109         def stop(self):
#     110             self.pen = None
# --> 111             SetWindowLong_WndProc_wrapper(self.hwnd, self.old_windProc)
#     112
#     113     MotionEventFactory.register('wm_pen', WM_PenProvider)
#
# ~\AppData\Local\Continuum\Anaconda3\lib\site-packages\kivy\input\providers\wm_common.py in _closure(hWnd, wndProc)
#     120     def SetWindowLong_WndProc_wrapper_generator(func):
#     121         def _closure(hWnd, wndProc):
# --> 122             oldAddr = func(hWnd, GWL_WNDPROC, cast(wndProc, c_void_p).value)
#     123             return cast(c_void_p(oldAddr), WNDPROC)
#     124
#
# ArgumentError: argument 3: <class 'TypeError'>: wrong type

# %%
1.11.1
