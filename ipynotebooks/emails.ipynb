# %%
import win32com.client

outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

inbox = outlook.GetDefaultFolder(6) # "6" refers to the index of a folder - in this case,
                                    # the inbox. You can change that number to reference
                                    # any other folder
messages = inbox.Items
message = messages.GetFirst()
body_content = message.body
print (body_content)
# Out:
# I am  on conference call.
#
#
#
# Best regards,
#
#
#
# Farhood Selamie, Senior Vice President
#
# Celebrating 26 Years of Excellence
#
#
#
#
#
#      www.ctsiweb.com <http://www.ctsiweb.com/>
#
#
#
# 237 W. 35th St., Suite 1201, NY, NY 10001  -  Cell: (908) 413-0166 Tel: (212) 971-7016, Fax: (212) 971-7019
#
#
#
# Please consider the environment before printing this email. View important information about our email disclosures here <http://www.ctsiweb.com/email-disclaimer/>
#
#
#
#
#
# From: Siev, Joshua <jsiev@rxrrealty.com>
# Sent: Thursday, June 20, 2019 7:59 AM
# To: Bingert, Patrick <pbingert@rxrrealty.com>; Nash, Justin <jnash@rxrrealty.com>; Elli Rusi <ellirusi@benmaintenance.com>; Nail Capri <ncapri@benmaintenance.com>; Yu, Jun <JYu@ThorntonTomasetti.com>; Van Winckle, Charles <CVanWinckle@ThorntonTomasetti.com>; Yana Teitel <YTeitel@rizzogroup.com>; Farhood Selamie <farhoods@ctsiweb.com>; conor.costigan@safwayatlantic.com; Mark Cansdale <mark@bostonvalley.com>; Matthew Kreidler <mkreidler@bostonvalley.com>; Gordon, Jenny <jgordon@rxrrealty.com>; Eddie Bairami <ebairami@benmaintenance.com>; Eli Rusi <erusi@benmaintenance.com>; Graeme Jones <GJones@c-probe.com>; Rajiv Pathak <rajiv@ctsiweb.com>; Sahar Sadjedi <sahar@ctsiweb.com>; Impagliazzo, Suzanne <simpagliazzo@rxrrealty.com>; Giametta, Gary <ggiametta@rxrrealty.com>
# Cc: Losi, Ben <blosi@rxrrealty.com>; Brown, Gregory <gbrown@rxrrealty.com>
# Subject: RE: Local Law 11 - 230 Park Ave
#
#
#
# All, We need to move todays meeting to 11. Thanks
#
#
#
#
#
#  <http://www.rxrrealty.com/>
#
# Joshua​ Siev
#
# Assistant Project Manager
#
# RXR Construction Services
#
# 75 Rockefeller Plaza
# Suite 1300
# New York, New York 10019
#
# T:
#
# 212.390.9627 x4627 <tel:212.390.9627%20x4627>
#
#
#
#
# jsiev@rxrrealty.com <mailto:jsiev@rxrrealty.com>
#
#
#
# www.rxrrealty.com <http://www.rxrrealty.com/>
#
# Confidentiality Notice: The information contained in this e-mail and any attachments may be legally privileged and confidential. If you are not an intended recipient, you should not retain, copy or use this e-mail or any attachment for any purpose, nor disclose all or any part of the contents to any other person.
#
# -----Original Appointment-----
# From: Siev, Joshua
# Sent: Thursday, February 21, 2019 8:26 AM
# To: Siev, Joshua; Bingert, Patrick; Nash, Justin; Elli Rusi; Nail Capri; Yu, Jun; Van Winckle, Charles; Yana Teitel; Farhood Selamie; conor.costigan@safwayatlantic.com <mailto:conor.costigan@safwayatlantic.com> ; Mark Cansdale; Matthew Kreidler; Gordon, Jenny; Eddie Bairami; Eli Rusi; Graeme Jones; Rajiv Pathak; Sahar Sadjedi; Impagliazzo, Suzanne; Giametta, Gary
# Cc: Losi, Ben; Brown, Gregory
# Subject: Local Law 11 - 230 Park Ave
# When: Thursday, June 20, 2019 11:00 AM-12:00 PM (UTC-05:00) Eastern Time (US & Canada).
# Where: 230 Park Ave - Suite 1534
#
#
#
# This meeting will now take place at 230 Park Ave every week.
#
#
#
# If you cannot make it in person:
#
#
#
# Dial In: (605) 472-5465
#
#
#
# Access Code: 260208

# %%
import win32com.client

items = []

def encodeit(s):
    if isinstance(s, str):
        return unicode(s, 'utf-8')
    else:
        return s

def extract():
  
  outlook  = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")
  inbox    = outlook.GetDefaultFolder(6)  # "6" refers to the inbox
  messages = inbox.Items
  message  = messages.GetFirst()
  
  
  while message:
      
      try:
          d = dict()
          d['Subject'] = encodeit(getattr(message, 'Subject', '<UNKNOWN>'))
          d['SentOn']  = encodeit(getattr(message, 'SentOn', '<UNKNOWN>'))
          d['EntryID'] = encodeit(getattr(message, 'EntryID', '<UNKNOWN>'))
          d['Sender']  = encodeit(getattr(message, 'Sender', '<UNKNOWN>'))
          d['Size']    = encodeit(getattr(message, 'Size', '<UNKNOWN>'))
          d['Body']    = encodeit(getattr(message, 'Body', '<UNKNOWN>'))
          items.append(d)

      except Exception as inst:
          print ("Error processing mail")
  
      message = messages.GetNext()
      
def showMessage():
  items.sort(key=lambda tup: tup['SentOn']) 
  
  for i in items:
    print (i["SentOn"], i["Subject"])
    
extract()
import win32com.client

outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

inbox = outlook.GetDefaultFolder(6) # "6" refers to the index of a folder - in this case,
                                    # the inbox. You can change that number to reference
                                    # any other folder
messages = inbox.Items
message = messages.GetFirst()
body_content = message.body
# Out:
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# Error processing mail
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-4ca69249c249> in <module>()
#      51 message = messages.GetFirst()
#      52 body_content = message.body
# ---> 53 print (body_content.showmail())
#
# AttributeError: 'str' object has no attribute 'showmail'

# %%
import win32com.client

outlook = win32com.client.Dispatch("Outlook.Application").GetNamespace("MAPI")

inbox = outlook.GetDefaultFolder(6) # "6" refers to the index of a folder - in this case,
                                    # the inbox. You can change that number to reference
                                    # any other folder
messages = inbox.Items
message = messages.GetFirst()
message.body
# Out:
# 'I am  on conference call.\r\n\r\n \r\n\r\nBest regards,\r\n\r\n \r\n\r\nFarhood Selamie, Senior Vice President \r\n\r\nCelebrating 26 Years of Excellence\r\n\r\n \r\n\r\n\r\n\r\n     www.ctsiweb.com <http://www.ctsiweb.com/> \r\n\r\n \r\n\r\n237 W. 35th St., Suite 1201, NY, NY 10001  -  Cell: (908) 413-0166 Tel: (212) 971-7016, Fax: (212) 971-7019  \r\n\r\n \r\n\r\nPlease consider the environment before printing this email. View important information about our email disclosures here <http://www.ctsiweb.com/email-disclaimer/>  \r\n\r\n \r\n\r\n \r\n\r\nFrom: Siev, Joshua <jsiev@rxrrealty.com> \r\nSent: Thursday, June 20, 2019 7:59 AM\r\nTo: Bingert, Patrick <pbingert@rxrrealty.com>; Nash, Justin <jnash@rxrrealty.com>; Elli Rusi <ellirusi@benmaintenance.com>; Nail Capri <ncapri@benmaintenance.com>; Yu, Jun <JYu@ThorntonTomasetti.com>; Van Winckle, Charles <CVanWinckle@ThorntonTomasetti.com>; Yana Teitel <YTeitel@rizzogroup.com>; Farhood Selamie <farhoods@ctsiweb.com>; conor.costigan@safwayatlantic.com; Mark Cansdale <mark@bostonvalley.com>; Matthew Kreidler <mkreidler@bostonvalley.com>; Gordon, Jenny <jgordon@rxrrealty.com>; Eddie Bairami <ebairami@benmaintenance.com>; Eli Rusi <erusi@benmaintenance.com>; Graeme Jones <GJones@c-probe.com>; Rajiv Pathak <rajiv@ctsiweb.com>; Sahar Sadjedi <sahar@ctsiweb.com>; Impagliazzo, Suzanne <simpagliazzo@rxrrealty.com>; Giametta, Gary <ggiametta@rxrrealty.com>\r\nCc: Losi, Ben <blosi@rxrrealty.com>; Brown, Gregory <gbrown@rxrrealty.com>\r\nSubject: RE: Local Law 11 - 230 Park Ave\r\n\r\n \r\n\r\nAll, We need to move todays meeting to 11. Thanks\r\n\r\n \r\n\r\n \r\n\r\n <http://www.rxrrealty.com/> \r\n\r\nJoshua\u200b Siev\r\n\r\nAssistant Project Manager\r\n\r\nRXR Construction Services\r\n\r\n75 Rockefeller Plaza\r\nSuite 1300\r\nNew York, New York 10019\r\n\r\nT: \r\n\r\n212.390.9627 x4627 <tel:212.390.9627%20x4627> \r\n\r\n\t\t\r\n \r\n\r\njsiev@rxrrealty.com <mailto:jsiev@rxrrealty.com> \r\n\r\n \r\n\r\nwww.rxrrealty.com <http://www.rxrrealty.com/> \r\n\r\nConfidentiality Notice: The information contained in this e-mail and any attachments may be legally privileged and confidential. If you are not an intended recipient, you should not retain, copy or use this e-mail or any attachment for any purpose, nor disclose all or any part of the contents to any other person.\r\n\r\n-----Original Appointment-----\r\nFrom: Siev, Joshua \r\nSent: Thursday, February 21, 2019 8:26 AM\r\nTo: Siev, Joshua; Bingert, Patrick; Nash, Justin; Elli Rusi; Nail Capri; Yu, Jun; Van Winckle, Charles; Yana Teitel; Farhood Selamie; conor.costigan@safwayatlantic.com <mailto:conor.costigan@safwayatlantic.com> ; Mark Cansdale; Matthew Kreidler; Gordon, Jenny; Eddie Bairami; Eli Rusi; Graeme Jones; Rajiv Pathak; Sahar Sadjedi; Impagliazzo, Suzanne; Giametta, Gary\r\nCc: Losi, Ben; Brown, Gregory\r\nSubject: Local Law 11 - 230 Park Ave\r\nWhen: Thursday, June 20, 2019 11:00 AM-12:00 PM (UTC-05:00) Eastern Time (US & Canada).\r\nWhere: 230 Park Ave - Suite 1534\r\n\r\n \r\n\r\nThis meeting will now take place at 230 Park Ave every week.\r\n\r\n \r\n\r\nIf you cannot make it in person:\r\n\r\n \r\n\r\nDial In: (605) 472-5465 \r\n\r\n \r\n\r\nAccess Code: 260208\r\n\r\n \r\n'

# %%
import win32com.client
import os
outlook=win32com.client.Dispatch("Outlook.Application").GetNameSpace("MAPI")
inbox=outlook.GetDefaultFolder(6) #Inbox default index value is 6
message=inbox.Items
message2=message.GetFirst()
subject=message2.Subject
body=message2.body
date=message2.senton.date()   
sender=message2.Sender
attachments=message2.Attachments


print(subject)
print(body)
print(sender)
print(attachments.count)
print(date)
# Out:
# RE: Local Law 11 - 230 Park Ave
# I am  on conference call.
#
#
#
# Best regards,
#
#
#
# Farhood Selamie, Senior Vice President
#
# Celebrating 26 Years of Excellence
#
#
#
#
#
#      www.ctsiweb.com <http://www.ctsiweb.com/>
#
#
#
# 237 W. 35th St., Suite 1201, NY, NY 10001  -  Cell: (908) 413-0166 Tel: (212) 971-7016, Fax: (212) 971-7019
#
#
#
# Please consider the environment before printing this email. View important information about our email disclosures here <http://www.ctsiweb.com/email-disclaimer/>
#
#
#
#
#
# From: Siev, Joshua <jsiev@rxrrealty.com>
# Sent: Thursday, June 20, 2019 7:59 AM
# To: Bingert, Patrick <pbingert@rxrrealty.com>; Nash, Justin <jnash@rxrrealty.com>; Elli Rusi <ellirusi@benmaintenance.com>; Nail Capri <ncapri@benmaintenance.com>; Yu, Jun <JYu@ThorntonTomasetti.com>; Van Winckle, Charles <CVanWinckle@ThorntonTomasetti.com>; Yana Teitel <YTeitel@rizzogroup.com>; Farhood Selamie <farhoods@ctsiweb.com>; conor.costigan@safwayatlantic.com; Mark Cansdale <mark@bostonvalley.com>; Matthew Kreidler <mkreidler@bostonvalley.com>; Gordon, Jenny <jgordon@rxrrealty.com>; Eddie Bairami <ebairami@benmaintenance.com>; Eli Rusi <erusi@benmaintenance.com>; Graeme Jones <GJones@c-probe.com>; Rajiv Pathak <rajiv@ctsiweb.com>; Sahar Sadjedi <sahar@ctsiweb.com>; Impagliazzo, Suzanne <simpagliazzo@rxrrealty.com>; Giametta, Gary <ggiametta@rxrrealty.com>
# Cc: Losi, Ben <blosi@rxrrealty.com>; Brown, Gregory <gbrown@rxrrealty.com>
# Subject: RE: Local Law 11 - 230 Park Ave
#
#
#
# All, We need to move todays meeting to 11. Thanks
#
#
#
#
#
#  <http://www.rxrrealty.com/>
#
# Joshua​ Siev
#
# Assistant Project Manager
#
# RXR Construction Services
#
# 75 Rockefeller Plaza
# Suite 1300
# New York, New York 10019
#
# T:
#
# 212.390.9627 x4627 <tel:212.390.9627%20x4627>
#
#
#
#
# jsiev@rxrrealty.com <mailto:jsiev@rxrrealty.com>
#
#
#
# www.rxrrealty.com <http://www.rxrrealty.com/>
#
# Confidentiality Notice: The information contained in this e-mail and any attachments may be legally privileged and confidential. If you are not an intended recipient, you should not retain, copy or use this e-mail or any attachment for any purpose, nor disclose all or any part of the contents to any other person.
#
# -----Original Appointment-----
# From: Siev, Joshua
# Sent: Thursday, February 21, 2019 8:26 AM
# To: Siev, Joshua; Bingert, Patrick; Nash, Justin; Elli Rusi; Nail Capri; Yu, Jun; Van Winckle, Charles; Yana Teitel; Farhood Selamie; conor.costigan@safwayatlantic.com <mailto:conor.costigan@safwayatlantic.com> ; Mark Cansdale; Matthew Kreidler; Gordon, Jenny; Eddie Bairami; Eli Rusi; Graeme Jones; Rajiv Pathak; Sahar Sadjedi; Impagliazzo, Suzanne; Giametta, Gary
# Cc: Losi, Ben; Brown, Gregory
# Subject: Local Law 11 - 230 Park Ave
# When: Thursday, June 20, 2019 11:00 AM-12:00 PM (UTC-05:00) Eastern Time (US & Canada).
# Where: 230 Park Ave - Suite 1534
#
#
#
# This meeting will now take place at 230 Park Ave every week.
#
#
#
# If you cannot make it in person:
#
#
#
# Dial In: (605) 472-5465
#
#
#
# Access Code: 260208
#
#
#
# Farhood Selamie
# 2
# 2019-06-20
