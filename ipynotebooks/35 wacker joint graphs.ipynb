# %%
import matplotlib.pyplot as plt
import pandas as pd

widths = r"C:\Users\mkreidler\Desktop\widths.xlsx"

wid = pd.read_excel(widths)

plt.plot(wid.oawidth, wid.cobra_joint)
plt.plot(wid.oawidth, wid.ashlar_joint)
plt.show()

# %%
heights = r"C:\Users\mkreidler\Desktop\heights.xlsx"

ht = pd.read_excel(heights)

plt.plot(ht.height, ht.height_joint)
plt.show()
