# %%
import os 
import pandas as pd

path = r"V:\Projects\222 Central Park South\TerraCotta"

folders = os.listdir(path)
for f in folders:
    print(f)
# Out:
# A1
# A2
# A3
# A4
# A7
# A8L
# A8R
# BK1
# BK2
# BK3L
# BK3R
# CS1
# CS2
# D1
# D2L
# D2R
# D3L
# D3R
# D4
# F1
# F2L
# F2R
# F3
# F4 (VOID)
# NF1
# P1
# P10 (VOID)
# P11 (VOID)
# P12
# P13
# P14(VOID)
# P15
# P17L
# P17R
# P18
# P19
# P2
# P20 (VOID)
# P21 (VOID)
# P23
# P24
# P25
# P26
# P29L
# P29R
# P3
# P30L
# P30R
# P31
# P4
# P5
# P6
# P7
# P8
# P9
# PA1
# PA10
# PA11
# PA12
# PA13
# PA14
# PA2
# PA3
# PA4
# PA5
# PA6
# PA7
# PA8
# PA9
# Preliminary Models
# Profiles
# PS3L
# PS3R
# S1
# Settings
# SF1
# SF2L
# SF2R
# SF3L
# SF3R
# SF4L
# SF4R
# SF5
# SF6L
# SF6R
# SF7
# SF8
# SIGN TEMPLATES.3dm
# SIGN TEMPLATES.3dm.rhl
# Thumbs.db
# W1
# W2L
# W2R
# W3L
# W3R
# WT1
# WT2
# WT3
# WT4
# WT5
# WT6
# _Data
# _Profiles.3dm
# _Profiles.3dmbak
# _Sample Scans

# %%
file = r"C:\Users\mkreidler\Desktop\222 CPS.txt"
data = pd.read_csv(file, sep=" ", header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-a07124181461> in <module>()
#       1 file = r"C:\Users\mkreidler\Desktop\222 CPS.txt"
# ----> 2 data = pd.read_csv(file, sep=" ", header=None)
#
# ...
