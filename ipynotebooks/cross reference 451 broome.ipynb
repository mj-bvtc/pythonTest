# %%
import os

def check(skip, test):
    result = None
    for s in skip:
        if s in test:
            result = True
            
        

def find_folder(path):
    dirs = set()
    skip = ["embedded", "sample", "log", "crate" ]
    for dirpath, dirnames, filenames in os.walk(path):
        for d in dirnames:
            if any(s.upper() in d.upper() for s in skip):
                #print()
                pass
            else:
                #print(d)
                dirs.add(d)
                pass
    return list(dirs)
            
folders = find_folder(r"V:\Sample Data\451 Broome")
#print(folders)
folders.sort()

for f in folders:
    print(f)
# Out:
# 10-FLB
# 10-FLB2
# 10-FLB3-L
# 10-FLB3-R
# 2-28-18
# 3-14-18
# 3-21-18
# 4FCB1
# 5FCB
# 65b9f8b5-0bfe-46a9-9061-a583f5d45b6a
# 6FS
# 8F5B2
# ABF
# AH-AK
# B1-B
# B1-H
# B1-HK
# B1-HK_17
# B1-HL
# B1-HL-1
# B1-HR
# B1-HR-1
# B1-L
# B1-L CHECK NAME
# B2-R
# B3-AHL 2
# B3-AHR
# B3-TF1
# B4-C
# B4-MB
# B4-Q
# B4-S-1
# B4-SF
# B4JH
# B4JL
# B4JR
# BK2 B-2
# BOP2
# BOPB2b
# BR-7MR1
# BR9-L E-9-H1-L1
# CBB 4
# CF1 NUMBER 14
# CF2 NUMBER 12
# DMC
# E-5
# E-5-B4SF
# E-5-S1-1
# E-5-S1-1 SCULPT
# E-7-H1-C
# E-7-H1-C BR7-MC2
# E-7-H1-L
# E-7-H2-L1 BR7-ML2
# E-7-H2-R
# E-9-H1-C
# E-9-H1-L2
# E-9-H1-R1
# E-9-H1-R1 BR-9-R1
# E-9-H1-R2
# E-9-H2-C
# E-9-H2-L1 BR9-L
# E-9-H2-L2 BR-9-L1
# E5-PBB
# E6-H1-C1
# E6-H1-L1
# E6-H1-R1
# E6-H2-C1 H2
# E6-H2-L1
# E6-H2-R1
# E7 M5
# E7M6
# FBC-2
# FOPB1
# FOPB2
# FOPB2 CORNER
# H2-R
# HK2b
# JC2
# LBLCC
# M1
# M10
# M3
# M4
# M8
# M9
# N4-4 PB1
# OPB1
# OPB1-CORNER
# OS2
# SOCB
# SOCBL2 20
# SOCL
# WT1
# WT2

# %%
txt = r"C:\Users\mkreidler\Documents\451 broome.txt"

file = open(txt, 'r')
blocks = []

for l in file.readlines():
    if l.isspace():
        pass
    else:
        #print(l.strip())
        blocks.append(l.strip())
file.close()


scan = []
for b in blocks:
    if b in folders:
        #print(b)
        scan.append(b)
        
scan.sort()
for s in scan:
    print(s)
# Out:
# 5FCB
# 6FS
# ABF
# AH-AK
# B1-B
# B1-H
# B1-HK
# B1-HL
# B1-HL-1
# B1-HR
# B1-HR-1
# B3-AHR
# B4-C
# B4-MB
# B4-Q
# B4-S-1
# B4-SF
# DMC
# JC2
# LBLCC
# M1
# M10
# M3
# M4
# M8
# M9
# OPB1
# OS2
# SOCB
# SOCL

# %%
import os

def find_folder(path):
    dirs = set()
    skip = ["embedded", "sample", "log", "crate", ".files" ]
    for dirpath, dirnames, filenames in os.walk(path):
        for f in filenames:
            if f.endswith("3dm"):
                #print(f)
                print(os.path.basename(dirpath))
                
    
            
    
file = r"V:\Projects\451 Broome\Field Work\Agi-Renders"
    
find_folder(file)
# Out:
# Agi-B1-HK
# E-4-M8
# E-5-5FS
# E-5-H1-3
# E-5-PBB2
# E-5-S1
# E-8-8FSB_OPPOSITEHAND
# E-8-B4MB
# E-8-M4
# E-9-LBLCC
# E-9-M1
# E1-12-AH-AK
# E1-12-B1-HK
# E1-12-B412B
# E7-DMC
# N2-5-B4C
# N2-5-JC2
# N2-7-B4C
# N2-7-JC2
# N6-12-CF1_CF2_SOCLB2
# NWC-11-BOPB2-THREE
# NWC-11-BOPB2A
# NWC-11-BOPB2B
# NWC-11-BOPB2B_
# NWC-11-BOPB2O
# NWC-11-BOPB2__
# NWC-11__
# W-10-B3-AHL
# W-10-M(N)
# W-10-M(N)_2
# W-11-B-2
# W-11-B-2_
# W-11-B4PB
# W-11-B4WT
# W-11-B4WT_4
# W-4-B4MB
# W-4-PB PFOFILE
# W-5-4FCB
# W-5-B4Q

# %%
import os

def find_folder(path):
    dirs = set()
    skip = ["embedded", "sample", "log", "crate", ".files" ]
    for dirpath, dirnames, filenames in os.walk(path):
        for f in filenames:
            if f.endswith("TIF"):
                #print(f)
                #print(os.path.basename(dirpath))
                if "(2)" in f:
                    d = os.path.join(dirpath, f)
                    os.remove(d)
                    print(f"Removed duplicate file: {f}")
                
    
            
    
file = r"V:\Projects\451 Broome\Field Work\Agi-Renders"
    
find_folder(file)
# Out:
# Removed duplicate file: DSC_1080 (2).TIF
# Removed duplicate file: DSC_1081 (2).TIF
# Removed duplicate file: DSC_1082 (2).TIF
# Removed duplicate file: DSC_1083 (2).TIF
# Removed duplicate file: DSC_1084 (2).TIF
# Removed duplicate file: DSC_1085 (2).TIF
# Removed duplicate file: DSC_1086 (2).TIF
# Removed duplicate file: DSC_1087 (2).TIF
# Removed duplicate file: DSC_1088 (2).TIF
# Removed duplicate file: DSC_1089 (2).TIF
# Removed duplicate file: DSC_1090 (2).TIF
# Removed duplicate file: DSC_1091 (2).TIF
# Removed duplicate file: DSC_1092 (2).TIF
# Removed duplicate file: DSC_1093 (2).TIF
# Removed duplicate file: DSC_1094 (2).TIF
# Removed duplicate file: DSC_1095 (2).TIF
# Removed duplicate file: DSC_1096 (2).TIF
# Removed duplicate file: DSC_1097 (2).TIF
# Removed duplicate file: DSC_1098 (2).TIF
# Removed duplicate file: DSC_1099 (2).TIF
# Removed duplicate file: DSC_1100 (2).TIF
# Removed duplicate file: DSC_1101 (2).TIF
# Removed duplicate file: DSC_1102 (2).TIF
# ...
