# %%
import pandas as pd

drafting_status = r"C:\Users\mkreidler\Desktop\Drafting Status.csv"

df = pd.read_csv(drafting_status)

drafters = r"C:\Users\mkreidler\Desktop\drafters.csv"

resources = pd.read_csv(drafters).sort_values(by="last")

hours = 50

projects = df[["pnum", "pname"]].dropna()


resources.sort_values(by="last")

df[["pnum", "pname" ]]

df["color"] = ""


#df[df['green'].isnull() == False]["color"] 

df.loc[df['green'].isnull() == False, "color"] = "G"
df.loc[df['yellow'].isnull() == False, "color"] = "Y"
df.loc[df['red'].isnull() == False, "color"] = "R"


df[["pnum", "pname", "color"]]

df
# Out:
#           pm     pnum  priority green yellow  red  \
# 0    Mark C.  15-0143       1.0     x    NaN  NaN
# 1    Mark C.  15-0143       1.0     x    NaN  NaN
# 2    Nick P.  17-1262       1.0     x    NaN  NaN
# 3    Mark C.  15-0143       1.0   NaN    NaN    x
# 4    Mark C.  18-1348       1.0   NaN    NaN    x
# 5    Mark C.  18-1312       1.0     x    NaN  NaN
# 6    Nick P.  18-1524       1.0   NaN    NaN    x
# 7    Mark C.  18-1312       1.0     x    NaN  NaN
# 8    Nick P.  16-0513       1.0     x    NaN  NaN
# 9    Nick P.  17-0983       1.0     x    NaN  NaN
# 10   Nick P.  17-0737       1.0     x    NaN  NaN
# 11   Nick P.  16-0082       1.0     x    NaN  NaN
# 12   Mark C.  18-1325       3.0   NaN    NaN    x
# 13   Nick P.  16-0513       2.0     x    NaN  NaN
# 14   Mark C.  18-1325       2.0     x    NaN  NaN
# 15   Nick P.  17-1262       1.0   NaN      x  NaN
# 16   Mark C.  17-1144       1.0   NaN      x  NaN
# 17   Nick P.  16-0632       2.0     x    NaN  NaN
# ...
