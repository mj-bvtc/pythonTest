# %%
import pandas as pd
import re

path = r"C:\Users\mkreidler\Desktop\Quoins.xlsx"

df = pd.read_excel(path)

data = df[["block_id", "height", "len_a", "len_b", "depth" ]]

data = data[data.block_id.str.match("^Q")]

data[]
# Out:
#     block_id  height  len_a  len_b  depth
# 24       Q31     NaN    NaN    NaN    NaN
# 25       Q32   350.0  254.0  375.0    NaN
# 26       Q33   254.0  566.0  100.0    NaN
# 27      Q35A   355.0  477.0  487.0    NaN
# 28       Q36   480.0  630.0  487.0    NaN
# 85       Q27   400.0  445.0   95.0    NaN
# 86       Q29   400.0  363.0  363.0    NaN
# 87       Q30   400.0  100.0  100.0    NaN
# 88      Q35B     NaN    NaN  487.0    NaN
# 89      Q35C     NaN    NaN  487.0    NaN
# 90       Q80     NaN  467.0    NaN    NaN
# 101      Q25   375.0  515.0  305.0    NaN
# 102      Q28   400.0  325.0  215.0    NaN
# 103      Q79   400.0  450.0    NaN    NaN
# 119       Q1   400.0  430.0  270.0    NaN
# 120      Q11   400.0  305.0  360.0    NaN
# 121      Q14   255.0    NaN    NaN    NaN
# 122      Q15   255.0  215.0  600.0    NaN
# 123      Q16   400.0  445.0  305.0    NaN
# 124      Q17   255.0    NaN    NaN    NaN
# 125      Q18   255.0    NaN    NaN    NaN
# ...

# %%
import re

test = "Q702452345 there is someting goin on heraaa Q  Q123"
pattern = r"^[Q][0-9]*"

a = re.findall(pattern, test)
print(a)
# Out:
# ['Q702452345']
