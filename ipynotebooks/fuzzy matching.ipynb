# %%
import pandas as pd

file = r"C:\Users\mkreidler\Desktop\fuzzy matching.xlsx"

df = pd.read_excel(file)

# %%
round(42352.12423421)
# Out:
# 42

# %%
round(42352.12423421,-1)
# Out:
# 42350.0

# %%
def round_ten(x):
    return round(x,-1)

def myround(x, base=25):
    return base * round(x/base)

df["fuzzy_x"] = df.x.apply(myround)

df.groupby("fuzzy_x").count()
# Out:
#          floor  guid  name   x   y   z  survey_name
# fuzzy_x
# -8150        2     2     2   2   2   2            2
# -8125       12    12    12  12  12  12           12
# -8100        8     8     8   8   8   8            8
# -8075        4     4     4   4   4   4            4
# -8050        7     7     7   7   7   7            7
# -8025        5     5     5   5   5   5            5
# -8000        2     2     2   2   2   2            2
# -7975        3     3     3   3   3   3            3
# -7950        7     7     7   7   7   7            7
# -7925        4     4     4   4   4   4            4
# -7900        6     6     6   6   6   6            6
# -7875       10    10    10  10  10  10           10
# -7850        5     5     5   5   5   5            5
# -7825        7     7     7   7   7   7            7
# -7800        2     2     2   2   2   2            2
# -7775        5     5     5   5   5   5            5
# -7750        3     3     3   3   3   3            3
# ...

# %%
import random

random.seed()
