# %%
import pandas as pd
import datetime
import math
import workdays


class Project:
    def __init__(self, name, num_dwgs, num_units, activation_date=None, team=[]):
        self.name = name
        self.num_dwgs = num_dwgs
        self.analysis_days = max([1, math.ceil(num_dwgs*.03)])
        self.num_units = num_units
        self.team = team
        self.activation_date = activation_date
        self.start = None
        self.finish = None
        self.submittals = []
        self.num_teammates = None

        self.holidays =  [datetime.date(2019, 12, 25),
                          datetime.date(2019,1,1 ),
                          datetime.date(2019, 5,27),
                          datetime.date(2019, 6,4),
                          datetime.date(2019, 9, 2),
                          datetime.date(2019, 11, 28)]
        self.workdays = None
        self.dwg_per_day = 2
        self.dwg_max_per_sub = 60
        self.QC_days = max([3, math.ceil(num_dwgs*.05)])
        self.drawing_difficulty_factor = 1
        self.expected_approval_date = None
        self.expected_book_release = None
        self.calc_workdays()
        self.calc_submittals()
        self.calc_last_sub()
        
    def calc_num_teammates(self):
        self.num_teammates = len(self.team)
        return self.num_teammates
        
    def calc_workdays(self):
        """Calculates the number of days the team assigned will need
            to finish drafting the project.  This function rounds up to the next
            whole day.  Uses the number of drawings per day defined above.  accounts
            for QC days and analysis days"""
        self.calc_num_teammates()
        self.workdays =  math.ceil(((self.num_dwgs*self.drawing_difficulty_factor)
                                    /(self.num_teammates*self.dwg_per_day)
                                    +self.QC_days+ self.analysis_days))
        return self.workdays
    
    def calc_submittals(self, start = None):
        num_sub = math.ceil(self.num_dwgs/self.dwg_max_per_sub)
        dwg_per = self.num_dwgs/num_sub
        duration_sub = math.ceil(self.workdays/num_sub)
        
        #default start is the activation day, proceeding dates will be determined 
        #by how long each submittal is
        if start is None:
            start = self.activation_date
        self.submittals = []
        for s in range(num_sub):

            # this calculates the last workday specified from a start date
            # plus some number of workdays accounting for (skipping) holidays
            # and weekends
            start = workdays.workday(start, days = duration_sub, holidays = self.holidays)
            
            self.submittals.append(start)
        
        last = self.submittals[-1]
        self.expected_approval_date = workdays.workday(last, days = 10, holidays = self.holidays)
        self.expected_book_release = workdays.workday(self.expected_approval_date, days = 2, holidays = self.holidays)
        
        
        
        return self.submittals
    
    def calc_last_sub(self):
        return self.submittals[-1]
       
    
    def report(self):
        def myformat(name, value):
            print( "{:<17} {:<20}".format(name, value))
        #print(f"Report Date: {datetime.datetime.now()}")
        myformat("Report Date:", str(datetime.datetime.now()))
        #print(f"Project: {self.name}\n{self.num_dwgs} Drawings\n{self.num_units} Units\n")
        myformat("Project:", self.name)
        myformat("Drawings:", self.num_dwgs)
        myformat("Units:", self.num_units)
        print()
        print(f"There will be {len(self.submittals)} submittals of plus or minus {math.ceil(self.num_dwgs/len(self.submittals))} Drawings")
        team_list = self.team
        team_list[-1] = "and " + team_list[-1]
        team = str(team_list).replace("[","").replace("]","").replace("'","")
        print(f"The work will be split between {team}")
        print()
        print("Timeline:")
        print(f"{self.activation_date.strftime('%b %d, %Y'):<17}{self.name} Activation")
        for i in range(len(self.submittals)):
            date = self.submittals[i]
            date = date.strftime('%b %d, %Y')
            print(f"{date:<17}Submittal Number {i+1}")
        cal_weeks = round((self.submittals[-1] - self.activation_date).days/7)
        
        print(f"{self.expected_approval_date.strftime('%b %d, %Y') :<17}Expected Approval Date ")
        print(f"{self.expected_book_release.strftime('%b %d, %Y'):<17}Expected Book Release Date ")
        print()
        print(f"There are {cal_weeks} calendar weeks between activation to the expected final submittal")
        
        dwg_per_day = math.ceil(self.num_dwgs/self.workdays)
        dwg_per_week = dwg_per_day * 5
        print(f"The team should target {dwg_per_week} drawings per work week and {dwg_per_day} drawings per work day to hit their goal")
        print(f"There are {self.workdays} work days for these drawings")
            
def main():        

    team_a = ["Andy", "Ashwini", "Cody", "Rick"]

    a = Project("PS 171", 157, 973, datetime.date(2019,5,6), team_a )
    a.report()
    
main()
# Out:
# Report Date:      2019-06-13 12:31:56.342995
# Project:          PS 171
# Drawings:         157
# Units:            973
#
# There will be 3 submittals of plus or minus 53 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 06, 2019     PS 171 Activation
# May 21, 2019     Submittal Number 1
# Jun 07, 2019     Submittal Number 2
# Jun 24, 2019     Submittal Number 3
# Jul 08, 2019     Expected Approval Date
# Jul 10, 2019     Expected Book Release Date
#
# There are 7 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 33 work days for these drawings

# %%
file = r"C:\Users\mkreidler\Desktop\Data\Drafting (4).xlsx"

def is_date(x):
    if type(x) == datetime.datetime:
        ##print("yes")
        return True
    else:
        #print(type(x))
        return False

df = pd.read_excel(file)
df = df[df["# Dwgs"] > 0]
df["activated"] = df["Activation Date"].apply(is_date)
df = df[df.activated == True]

for index, row in df.iterrows():
    team_a = ["Andy", "Ashwini", "Cody", "Rick"]
    project = Project(row["Task Name"], 
            row["# Dwgs"], 
            row["# units"], 
            row["Activation Date"].date(), 
            team_a)
            #row["Assigned To"] )
    project.report()
    print()
    print("******************************")
    print()
# Out:
# Report Date:      2019-06-13 12:31:56.445995
# Project:          100 Hudson (need samples)
# Drawings:         44.0
# Units:            533.0
#
# There will be 1 submittals of plus or minus 44 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 09, 2019     100 Hudson (need samples) Activation
# May 24, 2019     Submittal Number 1
# Jun 11, 2019     Expected Approval Date
# Jun 13, 2019     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 11 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.446995
# Project:          114 Fifth Ave (Redesigning and Req. 2 courses of samples, accept CO winter work)
# Drawings:         6.0
# Units:            35.0
#
# There will be 1 submittals of plus or minus 6 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 13, 2019     114 Fifth Ave (Redesigning and Req. 2 courses of samples, accept CO winter work) Activation
# Feb 20, 2019     Submittal Number 1
# Mar 06, 2019     Expected Approval Date
# Mar 08, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.446995
# Project:          11941 S Parnell Drawings
# Drawings:         20.0
# Units:            57.0
#
# There will be 1 submittals of plus or minus 20 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Sep 06, 2018     11941 S Parnell Drawings Activation
# Sep 17, 2018     Submittal Number 1
# Oct 01, 2018     Expected Approval Date
# Oct 03, 2018     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.447995
# Project:          11941 S Parnell Ave CO1 (Need Approval)
# Drawings:         1.0
# Units:            1.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 14, 2019     11941 S Parnell Ave CO1 (Need Approval) Activation
# May 21, 2019     Submittal Number 1
# Jun 06, 2019     Expected Approval Date
# Jun 10, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.448995
# Project:          140 S Dearborn Street (Friday 3/8)
# Drawings:         4.0
# Units:            60.0
#
# There will be 1 submittals of plus or minus 4 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 15, 2019     140 S Dearborn Street (Friday 3/8) Activation
# Feb 22, 2019     Submittal Number 1
# Mar 08, 2019     Expected Approval Date
# Mar 12, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.449995
# Project:          145 E 39th CO1 Columns and Copings
# Drawings:         26.0
# Units:            56.0
#
# There will be 1 submittals of plus or minus 26 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Sep 18, 2018     145 E 39th CO1 Columns and Copings Activation
# Sep 28, 2018     Submittal Number 1
# Oct 12, 2018     Expected Approval Date
# Oct 16, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 8 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.450995
# Project:          145 E 39th CO2
# Drawings:         13.0
# Units:            56.0
#
# There will be 1 submittals of plus or minus 13 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 15, 2019     145 E 39th CO2 Activation
# Feb 25, 2019     Submittal Number 1
# Mar 11, 2019     Expected Approval Date
# Mar 13, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.451995
# Project:          145 E 39th Base
# Drawings:         48.0
# Units:            297.0
#
# There will be 1 submittals of plus or minus 48 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 11, 2018     145 E 39th Base Activation
# May 28, 2018     Submittal Number 1
# Jun 11, 2018     Expected Approval Date
# Jun 13, 2018     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 11 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.452995
# Project:          147 Dempster Street
# Drawings:         7.0
# Units:            2.0
#
# There will be 1 submittals of plus or minus 7 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 18, 2019     147 Dempster Street Activation
# Apr 25, 2019     Submittal Number 1
# May 09, 2019     Expected Approval Date
# May 13, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.453995
# Project:          2211 Woodward Ave - Fox Theater (Samples Here)
# Drawings:         7.0
# Units:            137.0
#
# There will be 1 submittals of plus or minus 7 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 24, 2019     2211 Woodward Ave - Fox Theater (Samples Here) Activation
# Jun 03, 2019     Submittal Number 1
# Jun 18, 2019     Expected Approval Date
# Jun 20, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.454995
# Project:          230 Park (winter work)
# Drawings:         10.0
# Units:            448.0
#
# There will be 1 submittals of plus or minus 10 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 29, 2019     230 Park (winter work) Activation
# Feb 06, 2019     Submittal Number 1
# Feb 20, 2019     Expected Approval Date
# Feb 22, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.454995
# Project:          240 CPS (winter work)
# Drawings:         8.0
# Units:            50.0
#
# There will be 1 submittals of plus or minus 8 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 02, 2019     240 CPS (winter work) Activation
# Jan 09, 2019     Submittal Number 1
# Jan 23, 2019     Expected Approval Date
# Jan 25, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.455995
# Project:          25 Tudor City Place
# Drawings:         6.0
# Units:            4.0
#
# There will be 1 submittals of plus or minus 6 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Nov 08, 2018     25 Tudor City Place Activation
# Nov 15, 2018     Submittal Number 1
# Nov 29, 2018     Expected Approval Date
# Dec 03, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.455995
# Project:          250 West Street
# Drawings:         14.0
# Units:            36.0
#
# There will be 1 submittals of plus or minus 14 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Dec 20, 2018     250 West Street Activation
# Dec 28, 2018     Submittal Number 1
# Jan 14, 2019     Expected Approval Date
# Jan 16, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.456995
# Project:          251 W 71st
# Drawings:         1.0
# Units:            1.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Dec 17, 2018     251 W 71st Activation
# Dec 24, 2018     Submittal Number 1
# Jan 08, 2019     Expected Approval Date
# Jan 10, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.456995
# Project:          2 Queen Street
# Drawings:         25.0
# Units:            384.0
#
# There will be 1 submittals of plus or minus 25 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 05, 2019     2 Queen Street Activation
# Mar 15, 2019     Submittal Number 1
# Mar 29, 2019     Expected Approval Date
# Apr 02, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 8 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.457995
# Project:          310-320 West 86th Street (Scope needs to be fixed, samples received, )
# Drawings:         54.0
# Units:            73.0
#
# There will be 1 submittals of plus or minus 54 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 07, 2019     310-320 West 86th Street (Scope needs to be fixed, samples received, ) Activation
# Mar 25, 2019     Submittal Number 1
# Apr 08, 2019     Expected Approval Date
# Apr 10, 2019     Expected Book Release Date
#
# There are 3 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 12 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.457995
# Project:          320 E 41nd Street (Digisculpt Gargoyle)
# Drawings:         4.0
# Units:            4.0
#
# There will be 1 submittals of plus or minus 4 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 14, 2019     320 E 41nd Street (Digisculpt Gargoyle) Activation
# Mar 21, 2019     Submittal Number 1
# Apr 04, 2019     Expected Approval Date
# Apr 08, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.458995
# Project:          35 E Wacker CO14
# Drawings:         54.0
# Units:            nan
#
# There will be 1 submittals of plus or minus 54 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 22, 2019     35 E Wacker CO14 Activation
# Jun 11, 2019     Submittal Number 1
# Jun 25, 2019     Expected Approval Date
# Jun 27, 2019     Expected Book Release Date
#
# There are 3 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 12 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.459995
# Project:          444 River Lofts CO2 -- have sample with Sharon, check profile AH
# Drawings:         1.0
# Units:            35.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 24, 2019     444 River Lofts CO2 -- have sample with Sharon, check profile AH Activation
# Jan 31, 2019     Submittal Number 1
# Feb 14, 2019     Expected Approval Date
# Feb 18, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.459995
# Project:          51 W 81st Street -- CO3
# Drawings:         16.0
# Units:            25.0
#
# There will be 1 submittals of plus or minus 16 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 17, 2018     51 W 81st Street -- CO3 Activation
# May 25, 2018     Submittal Number 1
# Jun 08, 2018     Expected Approval Date
# Jun 12, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.460995
# Project:          55 Liberty Street (needs samples)
# Drawings:         16.0
# Units:            180.0
#
# There will be 1 submittals of plus or minus 16 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 17, 2019     55 Liberty Street (needs samples) Activation
# May 28, 2019     Submittal Number 1
# Jun 12, 2019     Expected Approval Date
# Jun 14, 2019     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.461995
# Project:          59 Bleecker -- CO1
# Drawings:         24.0
# Units:            72.0
#
# There will be 1 submittals of plus or minus 24 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Nov 09, 2018     59 Bleecker -- CO1 Activation
# Nov 20, 2018     Submittal Number 1
# Dec 04, 2018     Expected Approval Date
# Dec 06, 2018     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.461995
# Project:          59 Bleecker CO5 (RFI to contractor
# )
# Drawings:         3.0
# Units:            17.0
#
# There will be 1 submittals of plus or minus 3 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 29, 2019     59 Bleecker CO5 (RFI to contractor
# ) Activation
# May 06, 2019     Submittal Number 1
# May 20, 2019     Expected Approval Date
# May 22, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.462995
# Project:          701 Superior Street
# Drawings:         1.0
# Units:            7.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 14, 2019     701 Superior Street Activation
# Jan 21, 2019     Submittal Number 1
# Feb 04, 2019     Expected Approval Date
# Feb 06, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.462995
# Project:          Battersea (3 samples scanned)
# Drawings:         22.0
# Units:            nan
#
# There will be 1 submittals of plus or minus 22 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 10, 2019     Battersea (3 samples scanned) Activation
# Apr 19, 2019     Submittal Number 1
# May 03, 2019     Expected Approval Date
# May 07, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.463995
# Project:          Blessed Trinity Church -- needs books, wait for Color approval per ALP
# Drawings:         3.0
# Units:            600.0
#
# There will be 1 submittals of plus or minus 3 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 10, 2019     Blessed Trinity Church -- needs books, wait for Color approval per ALP Activation
# Jan 17, 2019     Submittal Number 1
# Jan 31, 2019     Expected Approval Date
# Feb 04, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.463995
# Project:          Cathedral Church of Saint John the Divine (Alternate #3) -- CO3
# Drawings:         4.0
# Units:            6.0
#
# There will be 1 submittals of plus or minus 4 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Nov 08, 2018     Cathedral Church of Saint John the Divine (Alternate #3) -- CO3 Activation
# Nov 15, 2018     Submittal Number 1
# Nov 29, 2018     Expected Approval Date
# Dec 03, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.464995
# Project:          314 West 72nd St. (Chatsworth Apartments) - Priority 3
# Drawings:         5.0
# Units:            nan
#
# There will be 1 submittals of plus or minus 5 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Oct 10, 2017     314 West 72nd St. (Chatsworth Apartments) - Priority 3 Activation
# Oct 17, 2017     Submittal Number 1
# Oct 31, 2017     Expected Approval Date
# Nov 02, 2017     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.464995
# Project:          Dallas County Records Building (original turned into samples, samples drawn only, 1 prototype signed)
# Drawings:         70.0
# Units:            nan
#
# There will be 2 submittals of plus or minus 35 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Oct 17, 2018     Dallas County Records Building (original turned into samples, samples drawn only, 1 prototype signed) Activation
# Oct 29, 2018     Submittal Number 1
# Nov 08, 2018     Submittal Number 2
# Nov 22, 2018     Expected Approval Date
# Nov 26, 2018     Expected Book Release Date
#
# There are 3 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 16 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.465995
# Project:          Dallas County Samples (18 dwg)(our proto just finished)
# Drawings:         26.0
# Units:            66.0
#
# There will be 1 submittals of plus or minus 26 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Oct 17, 2018     Dallas County Samples (18 dwg)(our proto just finished) Activation
# Oct 29, 2018     Submittal Number 1
# Nov 12, 2018     Expected Approval Date
# Nov 14, 2018     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 8 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.465995
# Project:          DELETED Toledo Collins Park WTP
# Drawings:         12.0
# Units:            600.0
#
# There will be 1 submittals of plus or minus 12 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 15, 2019     DELETED Toledo Collins Park WTP Activation
# Jan 23, 2019     Submittal Number 1
# Feb 06, 2019     Expected Approval Date
# Feb 08, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.466995
# Project:          First Baptist Church
# Drawings:         12.0
# Units:            41.0
#
# There will be 1 submittals of plus or minus 12 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 18, 2019     First Baptist Church Activation
# Apr 26, 2019     Submittal Number 1
# May 10, 2019     Expected Approval Date
# May 14, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.467995
# Project:          First Baptist Church CO1
# Drawings:         2.0
# Units:            2.0
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 30, 2019     First Baptist Church CO1 Activation
# Jun 07, 2019     Submittal Number 1
# Jun 21, 2019     Expected Approval Date
# Jun 25, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.467995
# Project:          FCOCS - CO2
# Drawings:         2.0
# Units:            nan
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 07, 2019     FCOCS - CO2 Activation
# Feb 14, 2019     Submittal Number 1
# Feb 28, 2019     Expected Approval Date
# Mar 04, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.468995
# Project:          First Church of Christ Scientists - North Entry Dormer
# Drawings:         12.0
# Units:            0.0
#
# There will be 1 submittals of plus or minus 12 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 30, 2017     First Church of Christ Scientists - North Entry Dormer Activation
# Jun 07, 2017     Submittal Number 1
# Jun 21, 2017     Expected Approval Date
# Jun 23, 2017     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.469995
# Project:          First Church of Christ Scientists - North Semi-Dome
# Drawings:         131.0
# Units:            nan
#
# There will be 3 submittals of plus or minus 44 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 30, 2017     First Church of Christ Scientists - North Semi-Dome Activation
# Jun 13, 2017     Submittal Number 1
# Jun 27, 2017     Submittal Number 2
# Jul 11, 2017     Submittal Number 3
# Jul 25, 2017     Expected Approval Date
# Jul 27, 2017     Expected Book Release Date
#
# There are 6 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 28 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.469995
# Project:          First Church of Christ Scientists - South Partial Dome
# Drawings:         131.0
# Units:            1325.0
#
# There will be 3 submittals of plus or minus 44 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 30, 2017     First Church of Christ Scientists - South Partial Dome Activation
# Jun 13, 2017     Submittal Number 1
# Jun 27, 2017     Submittal Number 2
# Jul 11, 2017     Submittal Number 3
# Jul 25, 2017     Expected Approval Date
# Jul 27, 2017     Expected Book Release Date
#
# There are 6 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 28 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.470995
# Project:          Forsyth High School (Scheduling Survey, need samples)
# Drawings:         16.0
# Units:            28.0
#
# There will be 1 submittals of plus or minus 16 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 24, 2019     Forsyth High School (Scheduling Survey, need samples) Activation
# Jun 05, 2019     Submittal Number 1
# Jun 19, 2019     Expected Approval Date
# Jun 21, 2019     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.470995
# Project:          Fulton County Courthouse (not signed)
# Drawings:         150.0
# Units:            nan
#
# There will be 3 submittals of plus or minus 50 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 03, 2019     Fulton County Courthouse (not signed) Activation
# Jun 19, 2019     Submittal Number 1
# Jul 04, 2019     Submittal Number 2
# Jul 19, 2019     Submittal Number 3
# Aug 02, 2019     Expected Approval Date
# Aug 06, 2019     Expected Book Release Date
#
# There are 7 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 32 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.471995
# Project:          Hoboken Train Terminal (need glaze)
# Drawings:         18.0
# Units:            1529.0
#
# There will be 1 submittals of plus or minus 18 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Dec 07, 2018     Hoboken Train Terminal (need glaze) Activation
# Dec 18, 2018     Submittal Number 1
# Jan 02, 2019     Expected Approval Date
# Jan 04, 2019     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.471995
# Project:          IS 7R drawings
# Drawings:         2.0
# Units:            1324.0
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 05, 2019     IS 7R drawings Activation
# Mar 12, 2019     Submittal Number 1
# Mar 26, 2019     Expected Approval Date
# Mar 28, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.472995
# Project:          May Company Building
# Drawings:         107.0
# Units:            1190.0
#
# There will be 2 submittals of plus or minus 54 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jul 12, 2018     May Company Building Activation
# Jul 30, 2018     Submittal Number 1
# Aug 15, 2018     Submittal Number 2
# Aug 29, 2018     Expected Approval Date
# Aug 31, 2018     Expected Book Release Date
#
# There are 5 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 24 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.472995
# Project:          May Co CO 5
# Drawings:         37.0
# Units:            391.0
#
# There will be 1 submittals of plus or minus 37 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 23, 2019     May Co CO 5 Activation
# May 07, 2019     Submittal Number 1
# May 21, 2019     Expected Approval Date
# May 23, 2019     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 10 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.473995
# Project:          May Co CO3
# Drawings:         4.0
# Units:            57.0
#
# There will be 1 submittals of plus or minus 4 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 05, 2019     May Co CO3 Activation
# Feb 12, 2019     Submittal Number 1
# Feb 26, 2019     Expected Approval Date
# Feb 28, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.473995
# Project:          May Co CO4 (North)
# Drawings:         2.0
# Units:            128.0
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 20, 2019     May Co CO4 (North) Activation
# Feb 27, 2019     Submittal Number 1
# Mar 13, 2019     Expected Approval Date
# Mar 15, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.474995
# Project:          May Co. 54 shops/CO1 Pediment
# Drawings:         28.0
# Units:            244.0
#
# There will be 1 submittals of plus or minus 28 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Nov 20, 2018     May Co. 54 shops/CO1 Pediment Activation
# Nov 30, 2018     Submittal Number 1
# Dec 14, 2018     Expected Approval Date
# Dec 18, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 8 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.474995
# Project:          May Company Building CO7
# Drawings:         3.0
# Units:            33.0
#
# There will be 1 submittals of plus or minus 3 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 30, 2019     May Company Building CO7 Activation
# Jun 07, 2019     Submittal Number 1
# Jun 21, 2019     Expected Approval Date
# Jun 25, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.475995
# Project:          Moynihan II CO 17
# Drawings:         15.0
# Units:            0.0
#
# There will be 1 submittals of plus or minus 15 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 15, 2019     Moynihan II CO 17 Activation
# May 23, 2019     Submittal Number 1
# Jun 10, 2019     Expected Approval Date
# Jun 12, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.476995
# Project:          Moynihan II CO19
# Drawings:         1.0
# Units:            0.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 15, 2019     Moynihan II CO19 Activation
# May 22, 2019     Submittal Number 1
# Jun 07, 2019     Expected Approval Date
# Jun 11, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.476995
# Project:          Moynihan II Cheneau (need BCA survey plus CO)
# Drawings:         17.0
# Units:            0.0
#
# There will be 1 submittals of plus or minus 17 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jan 30, 2018     Moynihan II Cheneau (need BCA survey plus CO) Activation
# Feb 08, 2018     Submittal Number 1
# Feb 22, 2018     Expected Approval Date
# Feb 26, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.477995
# Project:          MTA ESI pack 4 CO4
# Drawings:         4.0
# Units:            13.0
#
# There will be 1 submittals of plus or minus 4 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 07, 2019     MTA ESI pack 4 CO4 Activation
# Feb 14, 2019     Submittal Number 1
# Feb 28, 2019     Expected Approval Date
# Mar 04, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.477995
# Project:          Orpheum Theater CO1
# Drawings:         1.0
# Units:            -6.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 29, 2019     Orpheum Theater CO1 Activation
# May 06, 2019     Submittal Number 1
# May 20, 2019     Expected Approval Date
# May 22, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.478995
# Project:          Orpheum Theatre (CW fixing model/already submitted)
# Drawings:         3.0
# Units:            nan
#
# There will be 1 submittals of plus or minus 3 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 18, 2019     Orpheum Theatre (CW fixing model/already submitted) Activation
# Mar 25, 2019     Submittal Number 1
# Apr 08, 2019     Expected Approval Date
# Apr 10, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.529995
# Project:          PS 171 (M) (Need missing samples)
# Drawings:         157.0
# Units:            973.0
#
# There will be 3 submittals of plus or minus 53 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 07, 2019     PS 171 (M) (Need missing samples) Activation
# Mar 22, 2019     Submittal Number 1
# Apr 08, 2019     Submittal Number 2
# Apr 23, 2019     Submittal Number 3
# May 07, 2019     Expected Approval Date
# May 09, 2019     Expected Book Release Date
#
# There are 7 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 33 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.530995
# Project:          Rookery Building (samples here)
# Drawings:         8.0
# Units:            14.0
#
# There will be 1 submittals of plus or minus 8 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 29, 2019     Rookery Building (samples here) Activation
# Jun 06, 2019     Submittal Number 1
# Jun 20, 2019     Expected Approval Date
# Jun 24, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.531995
# Project:          Shell House Building - Base
# Drawings:         135.0
# Units:            nan
#
# There will be 3 submittals of plus or minus 45 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 14, 2018     Shell House Building - Base Activation
# Jun 28, 2018     Submittal Number 1
# Jul 12, 2018     Submittal Number 2
# Jul 26, 2018     Submittal Number 3
# Aug 09, 2018     Expected Approval Date
# Aug 13, 2018     Expected Book Release Date
#
# There are 6 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 29 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.531995
# Project:          Shell House Building -- CO6
# Drawings:         25.0
# Units:            -277.0
#
# There will be 1 submittals of plus or minus 25 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Sep 25, 2018     Shell House Building -- CO6 Activation
# Oct 05, 2018     Submittal Number 1
# Oct 19, 2018     Expected Approval Date
# Oct 23, 2018     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 8 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.532995
# Project:          Shell House Building CO8
# Drawings:         100.0
# Units:            242.0
#
# There will be 2 submittals of plus or minus 50 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 22, 2019     Shell House Building CO8 Activation
# Jun 10, 2019     Submittal Number 1
# Jun 25, 2019     Submittal Number 2
# Jul 09, 2019     Expected Approval Date
# Jul 11, 2019     Expected Book Release Date
#
# There are 5 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 21 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.532995
# Project:          Sullivan Center - 1 South State Street (samples received)
# Drawings:         24.0
# Units:            413.0
#
# There will be 1 submittals of plus or minus 24 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 03, 2019     Sullivan Center - 1 South State Street (samples received) Activation
# Jun 13, 2019     Submittal Number 1
# Jun 27, 2019     Expected Approval Date
# Jul 01, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.533995
# Project:          University of Guelph (No Samples)
# Drawings:         10.0
# Units:            21.0
#
# There will be 1 submittals of plus or minus 10 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Apr 18, 2019     University of Guelph (No Samples) Activation
# Apr 26, 2019     Submittal Number 1
# May 10, 2019     Expected Approval Date
# May 14, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 6 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.533995
# Project:          UPenn Museum (client needs to finish their dwgs)
# Drawings:         2.0
# Units:            2292.0
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Feb 08, 2019     UPenn Museum (client needs to finish their dwgs) Activation
# Feb 15, 2019     Submittal Number 1
# Mar 01, 2019     Expected Approval Date
# Mar 05, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.534995
# Project:          US Naval Academy (need color + qty) (need confirmation on styles)
# Drawings:         2.0
# Units:            24.0
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Mar 19, 2019     US Naval Academy (need color + qty) (need confirmation on styles) Activation
# Mar 26, 2019     Submittal Number 1
# Apr 09, 2019     Expected Approval Date
# Apr 11, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.534995
# Project:          Wolford Apartments (need missing samples)
# Drawings:         36.0
# Units:            118.0
#
# There will be 1 submittals of plus or minus 36 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 09, 2019     Wolford Apartments (need missing samples) Activation
# May 23, 2019     Submittal Number 1
# Jun 10, 2019     Expected Approval Date
# Jun 12, 2019     Expected Book Release Date
#
# There are 2 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 10 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.535995
# Project:          May Company Building CO6
# Drawings:         1.0
# Units:            6.0
#
# There will be 1 submittals of plus or minus 1 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 04, 2019     May Company Building CO6 Activation
# Jun 11, 2019     Submittal Number 1
# Jun 25, 2019     Expected Approval Date
# Jun 27, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.536995
# Project:          Michigan Central Station (Samples here)
# Drawings:         3.0
# Units:            6000.0
#
# There will be 1 submittals of plus or minus 3 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 07, 2019     Michigan Central Station (Samples here) Activation
# Jun 14, 2019     Submittal Number 1
# Jun 28, 2019     Expected Approval Date
# Jul 02, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.536995
# Project:          310-320 W 86th Street -- CO2
# Drawings:         52.0
# Units:            151.0
#
# There will be 1 submittals of plus or minus 52 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 06, 2019     310-320 W 86th Street -- CO2 Activation
# Jun 24, 2019     Submittal Number 1
# Jul 08, 2019     Expected Approval Date
# Jul 10, 2019     Expected Book Release Date
#
# There are 3 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 12 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.537995
# Project:          310-320 W 86th Street -- CO3
# Drawings:         2.0
# Units:            8.0
#
# There will be 1 submittals of plus or minus 2 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 06, 2019     310-320 W 86th Street -- CO3 Activation
# Jun 13, 2019     Submittal Number 1
# Jun 27, 2019     Expected Approval Date
# Jul 01, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 5 drawings per work week and 1 drawings per work day to hit their goal
# There are 5 work days for these drawings
#
# ******************************
#
# Report Date:      2019-06-13 12:31:56.537995
# Project:          May Company Building CO8
# Drawings:         18.0
# Units:            186.0
#
# There will be 1 submittals of plus or minus 18 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# Jun 12, 2019     May Company Building CO8 Activation
# Jun 21, 2019     Submittal Number 1
# Jul 05, 2019     Expected Approval Date
# Jul 09, 2019     Expected Book Release Date
#
# There are 1 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# ******************************

# %%
class Sequence():
    def __init__(self):
        self.projects = []
        self.team = None
        self.start = None
        self.finish = None
    
    def calc_sequence(self):
        start = None
        last_sub = None
        count = 0
        for p in self.projects:
            count += 1
            if count == 1:
                start = p.activation_date
                last_sub = p.calc_last_sub()
                p.report()
            else:
                start = last_sub
                p.calc_submittals(start = start)
                last_sub = p.calc_last_sub()
                p.report()
            print()
            print("*****************************")
            print()
        
team_a = ["Andy", "Ashwini", "Cody", "Rick"]

a1 = Project("PS 171", 157, 973, datetime.date(2019,5,6), team_a )
a2 = Project("100 Hudson", 157, 973, datetime.date(2019,5,12), team_a )
a3 = Project("123 Main st", 200, 50, datetime.date(2019,6,1), team_a )

s1 = Sequence()
s1.projects = [a1,a2,a3]
s1.calc_sequence()

team_b = ["Brian", "Carrie"]

b1 = Project("FCOCS", 100, 300, datetime.date(2019,5,6), team_b )
b2 = Project("Moynihan", 20, 973, datetime.date(2019,6,12), team_b )
b3 = Project("Sicily Towers", 12, 50, datetime.date(2019,4,13), team_b )

s2 = Sequence()
s2.projects = [b1,b2,b3]
s2.calc_sequence()
# Out:
# Report Date:      2019-06-13 12:31:56.545995
# Project:          PS 171
# Drawings:         157
# Units:            973
#
# There will be 3 submittals of plus or minus 53 Drawings
# The work will be split between Andy, Ashwini, Cody, and Rick
#
# Timeline:
# May 06, 2019     PS 171 Activation
# May 21, 2019     Submittal Number 1
# Jun 07, 2019     Submittal Number 2
# Jun 24, 2019     Submittal Number 3
# Jul 08, 2019     Expected Approval Date
# Jul 10, 2019     Expected Book Release Date
#
# There are 7 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 33 work days for these drawings
#
# *****************************
#
# Report Date:      2019-06-13 12:31:56.545995
# Project:          100 Hudson
# Drawings:         157
# Units:            973
#
# There will be 3 submittals of plus or minus 53 Drawings
# The work will be split between Andy, Ashwini, Cody, and and Rick
#
# Timeline:
# May 12, 2019     100 Hudson Activation
# Jul 09, 2019     Submittal Number 1
# Jul 24, 2019     Submittal Number 2
# Aug 08, 2019     Submittal Number 3
# Aug 22, 2019     Expected Approval Date
# Aug 26, 2019     Expected Book Release Date
#
# There are 13 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 33 work days for these drawings
#
# *****************************
#
# Report Date:      2019-06-13 12:31:56.546995
# Project:          123 Main st
# Drawings:         200
# Units:            50
#
# There will be 4 submittals of plus or minus 50 Drawings
# The work will be split between Andy, Ashwini, Cody, and and and Rick
#
# Timeline:
# Jun 01, 2019     123 Main st Activation
# Aug 23, 2019     Submittal Number 1
# Sep 10, 2019     Submittal Number 2
# Sep 25, 2019     Submittal Number 3
# Oct 10, 2019     Submittal Number 4
# Oct 24, 2019     Expected Approval Date
# Oct 28, 2019     Expected Book Release Date
#
# There are 19 calendar weeks between activation to the expected final submittal
# The team should target 25 drawings per work week and 5 drawings per work day to hit their goal
# There are 41 work days for these drawings
#
# *****************************
#
# Report Date:      2019-06-13 12:31:56.547995
# Project:          FCOCS
# Drawings:         100
# Units:            300
#
# There will be 2 submittals of plus or minus 50 Drawings
# The work will be split between Brian, and Carrie
#
# Timeline:
# May 06, 2019     FCOCS Activation
# May 30, 2019     Submittal Number 1
# Jun 25, 2019     Submittal Number 2
# Jul 09, 2019     Expected Approval Date
# Jul 11, 2019     Expected Book Release Date
#
# There are 7 calendar weeks between activation to the expected final submittal
# The team should target 20 drawings per work week and 4 drawings per work day to hit their goal
# There are 33 work days for these drawings
#
# *****************************
#
# Report Date:      2019-06-13 12:31:56.547995
# Project:          Moynihan
# Drawings:         20
# Units:            973
#
# There will be 1 submittals of plus or minus 20 Drawings
# The work will be split between Brian, and and Carrie
#
# Timeline:
# Jun 12, 2019     Moynihan Activation
# Jul 08, 2019     Submittal Number 1
# Jul 22, 2019     Expected Approval Date
# Jul 24, 2019     Expected Book Release Date
#
# There are 4 calendar weeks between activation to the expected final submittal
# The team should target 15 drawings per work week and 3 drawings per work day to hit their goal
# There are 9 work days for these drawings
#
# *****************************
#
# Report Date:      2019-06-13 12:31:56.547995
# Project:          Sicily Towers
# Drawings:         12
# Units:            50
#
# There will be 1 submittals of plus or minus 12 Drawings
# The work will be split between Brian, and and and Carrie
#
# Timeline:
# Apr 13, 2019     Sicily Towers Activation
# Jul 17, 2019     Submittal Number 1
# Jul 31, 2019     Expected Approval Date
# Aug 02, 2019     Expected Book Release Date
#
# There are 14 calendar weeks between activation to the expected final submittal
# The team should target 10 drawings per work week and 2 drawings per work day to hit their goal
# There are 7 work days for these drawings
#
# *****************************
