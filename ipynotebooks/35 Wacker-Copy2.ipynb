# %%
import pandas as pd

path = r"C:\Users\mkreidler\Desktop\rhinoexport.xlsx"
df = pd.read_excel(path)

df.head()
# Out:
#                  layer name  \
# 0  Survey::FULL SURVEY    X
# 1  Survey::FULL SURVEY    X
# 2  Survey::FULL SURVEY    X
# 3  Survey::FULL SURVEY    X
# 4  Survey::FULL SURVEY    X
#
#                                                zones  \
# 0  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2  ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3  ['FLOOR 18'// 'EAST ELEVATION'// 'DROP E1'// '...
# 4  ['FLOOR 14'// 'EAST ELEVATION'// 'DROP E1'// '...
#
#                                    guid            x             y  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d  7709.188631 -2.442491e-15
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86  7716.379834 -2.442491e-15
# 2  c6711728-4457-4145-887d-e279e427ab85  1910.845628  0.000000e+00
# 3  62a66fae-aec3-4186-971f-0c2f01912b41  2160.327813  0.000000e+00
# 4  646eed2e-8458-46a1-b05d-5b13f9f0370d  1992.537782  0.000000e+00
#
#              z
# 0 -1917.500451
# 1 -1905.275405
# 2   417.218475
# 3   147.913267
# 4  -370.767680

# %%
import re
df["new"] = ""

df.new = df.layer.apply(lambda x: "NEW" in str(x))
df.head()
# Out:
#                  layer name  \
# 0  Survey::FULL SURVEY    X
# 1  Survey::FULL SURVEY    X
# 2  Survey::FULL SURVEY    X
# 3  Survey::FULL SURVEY    X
# 4  Survey::FULL SURVEY    X
#
#                                                zones  \
# 0  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2  ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3  ['FLOOR 18'// 'EAST ELEVATION'// 'DROP E1'// '...
# 4  ['FLOOR 14'// 'EAST ELEVATION'// 'DROP E1'// '...
#
#                                    guid            x             y  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d  7709.188631 -2.442491e-15
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86  7716.379834 -2.442491e-15
# 2  c6711728-4457-4145-887d-e279e427ab85  1910.845628  0.000000e+00
# 3  62a66fae-aec3-4186-971f-0c2f01912b41  2160.327813  0.000000e+00
# 4  646eed2e-8458-46a1-b05d-5b13f9f0370d  1992.537782  0.000000e+00
#
#              z    new
# 0 -1917.500451  False
# 1 -1905.275405  False
# 2   417.218475  False
# 3   147.913267  False
# 4  -370.767680  False

# %%
df["co"] = ""

def find_co(x):
    pat = r"CO([0-9]+)"
    result = re.search(pat, str(x))
    if result:
        return result.group(1)

    

df.co = df.layer.apply(find_co)
df.head()
# Out:
#                  layer name  \
# 0  Survey::FULL SURVEY    X
# 1  Survey::FULL SURVEY    X
# 2  Survey::FULL SURVEY    X
# 3  Survey::FULL SURVEY    X
# 4  Survey::FULL SURVEY    X
#
#                                                zones  \
# 0  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2  ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3  ['FLOOR 18'// 'EAST ELEVATION'// 'DROP E1'// '...
# 4  ['FLOOR 14'// 'EAST ELEVATION'// 'DROP E1'// '...
#
#                                    guid            x             y  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d  7709.188631 -2.442491e-15
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86  7716.379834 -2.442491e-15
# 2  c6711728-4457-4145-887d-e279e427ab85  1910.845628  0.000000e+00
# 3  62a66fae-aec3-4186-971f-0c2f01912b41  2160.327813  0.000000e+00
# 4  646eed2e-8458-46a1-b05d-5b13f9f0370d  1992.537782  0.000000e+00
#
#              z    new    co
# 0 -1917.500451  False  None
# 1 -1905.275405  False  None
# 2   417.218475  False  None
# 3   147.913267  False  None
# 4  -370.767680  False  None

# %%
df["priority"] = ""

def find_priority(x):
    pat = r"P([0-9]+)"
    result = re.search(pat, str(x))
    if result:
        return result.group(1)

    

df.priority = df.layer.apply(find_priority)
df.head()
# Out:
#                  layer name  \
# 0  Survey::FULL SURVEY    X
# 1  Survey::FULL SURVEY    X
# 2  Survey::FULL SURVEY    X
# 3  Survey::FULL SURVEY    X
# 4  Survey::FULL SURVEY    X
#
#                                                zones  \
# 0  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2  ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3  ['FLOOR 18'// 'EAST ELEVATION'// 'DROP E1'// '...
# 4  ['FLOOR 14'// 'EAST ELEVATION'// 'DROP E1'// '...
#
#                                    guid            x             y  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d  7709.188631 -2.442491e-15
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86  7716.379834 -2.442491e-15
# 2  c6711728-4457-4145-887d-e279e427ab85  1910.845628  0.000000e+00
# 3  62a66fae-aec3-4186-971f-0c2f01912b41  2160.327813  0.000000e+00
# 4  646eed2e-8458-46a1-b05d-5b13f9f0370d  1992.537782  0.000000e+00
#
#              z    new    co priority
# 0 -1917.500451  False  None     None
# 1 -1905.275405  False  None     None
# 2   417.218475  False  None     None
# 3   147.913267  False  None     None
# 4  -370.767680  False  None     None

# %%
df["swing_drop"] = ""
def get_drop(x):

    pat = r"drop\s*([a-z]*\d*)"
    match = re.search(pat, str(x), flags=re.IGNORECASE)

    if match:
        #print("Found Match")
        return match.group(1)
    else:
        #print("Not Found")
        return None

df.swing_drop = df.zones.apply(get_drop)

df
# Out:
#                    layer  name  \
# 0    Survey::FULL SURVEY     X
# 1    Survey::FULL SURVEY     X
# 2    Survey::FULL SURVEY     X
# 3    Survey::FULL SURVEY     X
# 4    Survey::FULL SURVEY     X
# 5    Survey::FULL SURVEY     X
# 6    Survey::FULL SURVEY     X
# 7    Survey::FULL SURVEY     X
# 8    Survey::FULL SURVEY     X
# 9    Survey::FULL SURVEY     X
# 10   Survey::FULL SURVEY     X
# 11   Survey::FULL SURVEY     X
# 12   Survey::FULL SURVEY     X
# 13   Survey::FULL SURVEY     X
# 14        Survey::VERIFY     ?
# 15        Survey::VERIFY     ?
# 16        Survey::VERIFY     ?
# 17        Survey::VERIFY   9C1
# 18        Survey::VERIFY   B23
# 19        Survey::VERIFY  A104
# 20        Survey::VERIFY    W2
# 21        Survey::VERIFY   4A8
# 22        Survey::VERIFY   4A7
# 23        Survey::VERIFY    S2
# 24        Survey::VERIFY    S2
# 25        Survey::VERIFY    S2
# 26        Survey::VERIFY  S2??
# 27        Survey::VERIFY     ?
# 28        Survey::VERIFY     ?
# 29        Survey::VERIFY     ?
# ..                   ...   ...
# 919  Survey::FULL SURVEY     X
# 920  Survey::FULL SURVEY     X
# 921  Survey::FULL SURVEY     X
# 922  Survey::FULL SURVEY     X
# 923  Survey::FULL SURVEY     X
# 924  Survey::FULL SURVEY     X
# 925  Survey::FULL SURVEY     X
# 926  Survey::FULL SURVEY     X
# 927  Survey::FULL SURVEY     X
# 928  Survey::FULL SURVEY     X
# 929  Survey::FULL SURVEY     X
# 930  Survey::FULL SURVEY     X
# 931  Survey::FULL SURVEY     X
# 932  Survey::FULL SURVEY     X
# 933  Survey::FULL SURVEY     X
# 934  Survey::FULL SURVEY     X
# 935  Survey::FULL SURVEY     X
# 936  Survey::FULL SURVEY     X
# 937  Survey::FULL SURVEY     X
# 938  Survey::FULL SURVEY     X
# 939  Survey::FULL SURVEY     X
# 940  Survey::FULL SURVEY     X
# 941  Survey::FULL SURVEY     X
# 942  Survey::FULL SURVEY     X
# 943  Survey::FULL SURVEY     X
# 944  Survey::FULL SURVEY     X
# 945  Survey::FULL SURVEY     X
# 946  Survey::FULL SURVEY     X
# 947  Survey::FULL SURVEY     X
# 948  Survey::FULL SURVEY     X
#
#                                                  zones  \
# 0    ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1    ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2    ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3    ['FLOOR 18'// 'EAST ELEVATION'// 'DROP E1'// '...
# 4    ['FLOOR 14'// 'EAST ELEVATION'// 'DROP E1'// '...
# 5    ['FLOOR 11'// 'EAST ELEVATION'// 'DROP E1'// '...
# 6    ['FLOOR 11'// 'EAST ELEVATION'// 'DROP E1'// '...
# 7    ['FLOOR 11'// 'EAST ELEVATION'// 'DROP E1'// '...
# 8    ['FLOOR 9'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 9    ['FLOOR 9'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 10   ['FLOOR 9'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 11   ['FLOOR 7'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 12   ['FLOOR 7'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 13   ['FLOOR 7'// 'EAST ELEVATION'// 'DROP E1'// 'P...
# 14   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 15   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 16   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 17   ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 18   ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 19   ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 20   ['FLOOR 23'// 'SOUTH ELEVATION'// 'DROP S5'// ...
# 21   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 22   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 23   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 24   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 25   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 26   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 27   ['FLOOR 18'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 28   ['FLOOR 19'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# 29   ['FLOOR 16'// 'SOUTH ELEVATION'// 'DROP S4'// ...
# ..                                                 ...
# 919  ['FLOOR 11'// 'SOUTH ELEVATION'// 'DROP S3'// ...
# 920  ['FLOOR 11'// 'SOUTH ELEVATION'// 'DROP S3'// ...
# 921  ['FLOOR 9'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 922  ['FLOOR 8'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 923  ['FLOOR 9'// 'SOUTH ELEVATION'// 'DROP S2'// '...
# 924  ['FLOOR 11'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 925  ['FLOOR 11'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 926  ['FLOOR 13'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 927  ['FLOOR 14'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 928  ['FLOOR 15'// 'SOUTH ELEVATION'// 'DROP S2'// ...
# 929  ['FLOOR 8'// 'SOUTH ELEVATION'// 'DROP S4'// '...
# 930  ['FLOOR 8'// 'SOUTH ELEVATION'// 'DROP S4'// '...
# 931  ['FLOOR 4'// 'SOUTH ELEVATION'// 'DROP S4'// '...
# 932  ['FLOOR 5'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 933  ['FLOOR 5'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 934  ['FLOOR 5'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 935  ['FLOOR 4'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 936  ['FLOOR 3'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 937  ['FLOOR 4'// 'SOUTH ELEVATION'// 'DROP S2'// '...
# 938  ['FLOOR 4'// 'SOUTH ELEVATION'// 'DROP S3'// '...
# 939  ['FLOOR 3'// 'SOUTH ELEVATION'// 'DROP S2'// '...
# 940  ['FLOOR 3'// 'SOUTH ELEVATION'// 'DROP S2'// '...
#
# 11  -1259.975503  False  None     None         E1
# 12  -1258.897211  False  None     None         E1
# 13  -1261.323369  False  None     None         E1
# 14    275.131957  False  None     None         S5
# 15    289.009780  False  None     None         S5
# 16    300.592153  False  None     None         S5
# 17    507.958155  False  None     None         S5
# 18    718.522782  False  None     None         S5
# 19    776.191785  False  None     None         S5
# 20    807.580134  False  None     None         S5
# 21    284.364984  False  None     None         S4
# 22    284.571015  False  None     None         S4
# 23    299.181960  False  None     None         S4
# 24    299.014655  False  None     None         S4
# 25    298.695353  False  None     None         S4
# 26    301.598779  False  None     None         S4
# 27    261.583983  False  None     None         S4
# 28    288.647825  False  None     None         S4
# 29     -0.171983  False  None     None         S4
# ..           ...    ...   ...      ...        ...
# 919  -659.238421  False  None     None         S3
# 920  -769.121724  False  None     None         S3
# 921  -897.551199  False  None     None         S3
# 922 -1029.524957  False  None     None         S3
# 923  -899.925020  False  None     None         S2
# 924  -768.787694  False  None     None         S2
# 925  -669.692173  False  None     None         S2
# 926  -383.020530  False  None     None         S2
# 927  -258.025585  False  None     None         S2
# 928  -128.313850  False  None     None         S2
# 929 -1083.852740  False  None     None         S4
# 930 -1092.281536  False  None     None         S4
# 931 -1570.325333  False  None     None         S4
# 932 -1539.296716  False  None     None         S3
# 933 -1540.251867  False  None     None         S3
# 934 -1542.162167  False  None     None         S3
# 935 -1641.426046  False  None     None         S3
# 936 -1689.991723  False  None     None         S3
# 937 -1550.772359  False  None     None         S2
# 938 -1551.946280  False  None     None         S3
# 939 -1691.561095  False  None     None         S2
# 940 -1689.423681  False  None     None         S2
# 941 -1690.398225  False  None     None         S1
# 942 -1826.155024  False  None     None         S3
# 943 -1077.867303  False  None     None         S2
# 944 -1198.560063  False  None     None         S2
# 945 -1165.125181  False  None     None         S2
# 946 -1286.882696  False  None     None         S2
# 947 -1321.976437  False  None     None         S2
# 948   616.582613  False  None     None         S2
#
# [949 rows x 11 columns]

# %%
block_ct = df[["name", "guid"]].groupby("name").count()

block_ct.head()
# Out:
#       guid
# name
# 2B1      2
# 3B1      1
# 3B11     3
# 3B4      1
# 4A2      1

# %%
df.new[df.new == True].count()
# Out:
# 0

# %%
df.new[df.new == False].count()
# Out:
# 949

# %%
df[["name", "swing_drop"]].groupby("swing_drop").count()
# Out:
#             name
# swing_drop
# E1           339
# S1            29
# S2           117
# S3           105
# S4           100
# S5            81
# W             15
# W1            51
# W2            50
# W3            62

# %%
unique_names = set(df.name.tolist())

# %%
len(unique_names)
# Out:
# 129

# %%
df.groupby("swing_drop").nunique() ###gives the number of unique values
# Out:
#             layer  name  zones  guid    x  y    z  new  co  priority  \
# swing_drop
# E1              2    52     20   339  232  2  290    1   0         0
# S1              2     6     12    29   29  4   29    1   0         0
# S2              2     7     21   117  116  2  110    1   0         0
# S3              2     6     19   105   92  1   96    1   0         0
# S4              2    12     21   100   96  1   95    1   0         0
# S5              2    29     20    81   77  1   78    1   0         0
# W               1     6      5    15   12  1   15    1   0         0
# W1              2    28     15    51   47  1   43    1   0         0
# W2              2    18     15    50   46  1   43    1   0         0
# W3              2    23     14    62   50  1   55    1   0         0
#
#             swing_drop
# swing_drop
# E1                   1
# S1                   1
# S2                   1
# S3                   1
# S4                   1
# S5                   1
# W                    1
# W1                   1
# W2                   1
# W3                   1

# %%
df.groupby("co").nunique()
# Out:
# Empty DataFrame
# Columns: [layer, name, zones, guid, x, y, z, new, co, priority, swing_drop]
# Index: []

# %%
len(df)
# Out:
# 949

# %%
new_blocks = df[df.new ==True]
new_blocks.nunique()
# Out:
# Empty DataFrame
# Columns: [layer, name, zones, guid, x, y, z, new, co, priority, swing_drop]
# Index: []

# %%
df["faulty"] = ""
df["remediation"] = ""
df["deduct"] = ""
df["floor"] = ""
df["elevation"] = ""
df["project"] = ""


def find_faulty(x):
    pat = r"faulty"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return "x"

df.faulty = df.layer.apply(find_faulty)
#df[df.faulty.notnull()]

def find_remediation(x):
    pat = r"remediation"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return "x"

df.remediation = df.layer.apply(find_remediation) 


def find_deduct(x):
    pat = r"deduct"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return "x"

df.deduct = df.layer.apply(find_deduct) 

def find_floor(x):
    pat = r"floor\s*(\d*)"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)

df.floor = df.zones.apply(find_floor)
#df[df.floor.notna()]

def find_elevation(x):
    pat = r"([a-zA-Z]*)\s*ELEVATION"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)

df.elevation = df.zones.apply(find_elevation)
#df[df.elevation.notna()]    


def find_project(x):
    pat = r"'project\s+(.*)'"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)
    else:
        print("not in project")
        
df.project = df.zones.apply(find_project)
df[df.project.notna()].head()
# Out:
#                  layer name  \
# 0  Survey::FULL SURVEY    X
# 1  Survey::FULL SURVEY    X
# 2  Survey::FULL SURVEY    X
# 3  Survey::FULL SURVEY    X
# 4  Survey::FULL SURVEY    X
#
#                                                zones  \
# 0  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2  ['FLOOR 20'// 'EAST ELEVATION'// 'DROP E1'// '...
# 3  ['FLOOR 18'// 'EAST ELEVATION'// 'DROP E1'// '...
# 4  ['FLOOR 14'// 'EAST ELEVATION'// 'DROP E1'// '...
#
#                                    guid            x             y  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d  7709.188631 -2.442491e-15
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86  7716.379834 -2.442491e-15
# 2  c6711728-4457-4145-887d-e279e427ab85  1910.845628  0.000000e+00
# 3  62a66fae-aec3-4186-971f-0c2f01912b41  2160.327813  0.000000e+00
# 4  646eed2e-8458-46a1-b05d-5b13f9f0370d  1992.537782  0.000000e+00
#
#              z    new    co priority swing_drop faulty remediation deduct  \
# 0 -1917.500451  False  None     None         S1   None        None   None
# 1 -1905.275405  False  None     None         S1   None        None   None
# 2   417.218475  False  None     None         E1   None        None   None
# 3   147.913267  False  None     None         E1   None        None   None
# 4  -370.767680  False  None     None         E1   None        None   None
#
#   floor elevation      project
# 0     2     SOUTH  35 E WACKER
# 1     2     SOUTH  35 E WACKER
# 2    20      EAST  35 E WACKER
# 3    18      EAST  35 E WACKER
# 4    14      EAST  35 E WACKER

# %%
#df.to_excel(r"C:\Users\mkreidler\Desktop\SurveyScopeProcessed.xlsx")

# %%
test = "['FLOOR 16'// 'SOUTH ELEVATION'// 'DROP S1'// 'PROJECT 35 E WACKER']"



def find_floor(x):
    pat = r"([a-zA-Z]*)\s*ELEVATION"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)
    
def find_project(x):
    pat = r"'project\s+(.*)'"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)
    else:
        print("fail")
    
    
find_project(test)
# Out:
# '35 E WACKER'

# %%
#file = r"C:\Users\mkreidler\Desktop\textpt.xlsx"

#dd = pd.read_excel(file)

#dd.head()

# %%
#combined = dd.merge(df, on="guid")

#combined.head()

# %%
#len(combined)

# %%
c = df[["guid", "z", "swing_drop"]]

class Order():
    def __init__(self):
        self.swing_drop = None
        self.priority = None
        self.sort = None

def create_order():
    drops = ["W3", "S1", "E1", "W2", "S5", "W1", "S2", "S3","S4"]
    priority = [1, 1, 1, 2, 2, 2, 3, 3, 3]
    order = []
    for i in range(9):
        j = i + 1
        k = Order()
        k.swing_drop = drops[i]
        k.priority = priority[i]
        k.sort = j
        order.append(k)
        
    return order
        

o = create_order()

order = pd.DataFrame([vars(f) for f in o])
order
c.head()
# Out:
#                                    guid            z swing_drop
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d -1917.500451         S1
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86 -1905.275405         S1
# 2  c6711728-4457-4145-887d-e279e427ab85   417.218475         E1
# 3  62a66fae-aec3-4186-971f-0c2f01912b41   147.913267         E1
# 4  646eed2e-8458-46a1-b05d-5b13f9f0370d  -370.767680         E1

# %%
c = c.merge(order, on="swing_drop")
c.head()
# Out:
#                                    guid            z swing_drop  priority  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d -1917.500451         S1         1
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86 -1905.275405         S1         1
# 2  53625bf9-2195-4cf0-b6a0-72bb778a14dc   695.354125         S1         1
# 3  15a6746c-6118-4265-a58c-b477642411e0   695.424013         S1         1
# 4  e7d35544-50f3-4c03-940a-649aed294712   452.505060         S1         1
#
#    sort
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2

# %%
#len(c)

# %%
c.head()
# Out:
#                                    guid            z swing_drop  priority  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d -1917.500451         S1         1
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86 -1905.275405         S1         1
# 2  53625bf9-2195-4cf0-b6a0-72bb778a14dc   695.354125         S1         1
# 3  15a6746c-6118-4265-a58c-b477642411e0   695.424013         S1         1
# 4  e7d35544-50f3-4c03-940a-649aed294712   452.505060         S1         1
#
#    sort
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2

# %%
c = c.sort_values(by=["sort", "z"], ascending=[True, True])


#this sorted list is the order by which we will survey

# %%
c.head()
# Out:
#                                      guid            z swing_drop  priority  \
# 895  1e1e4386-9a76-4098-8f31-d57081899f30 -1920.141814         W3         1
# 901  bcb9360f-0869-4ed7-9aff-099d88f2768b -1907.035564         W3         1
# 881  0edf2f5a-3621-4cb7-86fa-c444a952d46b -1900.051020         W3         1
# 882  099ace80-b5c6-4548-b795-daa96b2f6606 -1887.969619         W3         1
# 904  83bd03ab-98e9-4ff8-9677-7a091522998f -1881.565365         W3         1
#
#      sort
# 895     1
# 901     1
# 881     1
# 882     1
# 904     1

# %%
c["qty"] = 1

# %%
c["survey_order"] = c.qty.cumsum()
c.head()
# Out:
#                                      guid            z swing_drop  priority  \
# 895  1e1e4386-9a76-4098-8f31-d57081899f30 -1920.141814         W3         1
# 901  bcb9360f-0869-4ed7-9aff-099d88f2768b -1907.035564         W3         1
# 881  0edf2f5a-3621-4cb7-86fa-c444a952d46b -1900.051020         W3         1
# 882  099ace80-b5c6-4548-b795-daa96b2f6606 -1887.969619         W3         1
# 904  83bd03ab-98e9-4ff8-9677-7a091522998f -1881.565365         W3         1
#
#      sort  qty  survey_order
# 895     1    1             1
# 901     1    1             2
# 881     1    1             3
# 882     1    1             4
# 904     1    1             5

# %%
d = c[["guid", "survey_order"]]
d.head()
# Out:
#                                      guid  survey_order
# 895  1e1e4386-9a76-4098-8f31-d57081899f30             1
# 901  bcb9360f-0869-4ed7-9aff-099d88f2768b             2
# 881  0edf2f5a-3621-4cb7-86fa-c444a952d46b             3
# 882  099ace80-b5c6-4548-b795-daa96b2f6606             4
# 904  83bd03ab-98e9-4ff8-9677-7a091522998f             5

# %%
d.to_csv(r"C:\Users\mkreidler\Desktop\surveyorder5.csv")

# %%
len(d)
# Out:
# 934

# %%
order
# Out:
#    priority  sort swing_drop
# 0         1     1         W3
# 1         1     2         S1
# 2         1     3         E1
# 3         2     4         W2
# 4         2     5         S5
# 5         2     6         W1
# 6         3     7         S2
# 7         3     8         S3
# 8         3     9         S4

# %%
df = df.merge(order, on="swing_drop")

# %%
df.head()
# Out:
#                  layer name  \
# 0  Survey::FULL SURVEY    X
# 1  Survey::FULL SURVEY    X
# 2       Survey::VERIFY  AG2
# 3       Survey::VERIFY  AG3
# 4       Survey::VERIFY    ?
#
#                                                zones  \
# 0  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 1  ['FLOOR 2'// 'SOUTH ELEVATION'// 'DROP S1'// '...
# 2  ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S1'// ...
# 3  ['FLOOR 22'// 'SOUTH ELEVATION'// 'DROP S1'// ...
# 4  ['FLOOR 20'// 'SOUTH ELEVATION'// 'DROP S1'// ...
#
#                                    guid            x             y  \
# 0  59ee227e-2451-43c1-b5d8-4e772ec28a9d  7709.188631 -2.442491e-15
# 1  75f35dd0-d55a-4dc2-b62a-50bdb152ba86  7716.379834 -2.442491e-15
# 2  53625bf9-2195-4cf0-b6a0-72bb778a14dc  7502.239228  0.000000e+00
# 3  15a6746c-6118-4265-a58c-b477642411e0  7481.723527  0.000000e+00
# 4  e7d35544-50f3-4c03-940a-649aed294712  7361.418139  0.000000e+00
#
#              z    new    co priority_x swing_drop faulty remediation deduct  \
# 0 -1917.500451  False  None       None         S1   None        None   None
# 1 -1905.275405  False  None       None         S1   None        None   None
# 2   695.354125  False  None       None         S1   None        None   None
# 3   695.424013  False  None       None         S1   None        None   None
# 4   452.505060  False  None       None         S1   None        None   None
#
#   floor elevation      project  priority_y  sort
# 0     2     SOUTH  35 E WACKER           1     2
# 1     2     SOUTH  35 E WACKER           1     2
# 2    22     SOUTH  35 E WACKER           1     2
# 3    22     SOUTH  35 E WACKER           1     2
# 4    20     SOUTH  35 E WACKER           1     2

# %%
df.to_excel(r"\\192.168.245.8\data\Projects\35 East Wacker\Documents\011019 REMEDIATION MARKUPS\35 E Wacker West Elevation Survey\report\report 2019-02-22.xlsx")
