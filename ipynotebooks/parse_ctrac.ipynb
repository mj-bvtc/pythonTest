# %%
import pandas as pd
import re 
import numpy as np


ct = r"C:\Users\mkreidler\Desktop\35w\ctrac.xlsx"
ct_old = r"C:\Users\mkreidler\Desktop\35w\ctrac_old.xlsx"
ctrac = pd.read_excel(ct)
ctrac_old = pd.read_excel(ct_old)

ctrac = ctrac.groupby("name").sum().reset_index()
ctrac_old = ctrac_old.groupby("name").sum().reset_index()

both = ctrac.merge(ctrac_old, on="name", how="outer").fillna(0)
both.rename(index=str, columns={"quantity_ctrac": "ct_qty_P19-9999", "quantity_old":"ct_qty_P14-0436"})
# Out:
#       name  ct_qty_P19-9999  ct_qty_P14-0436
# 0      2B1              4.0              2.0
# 1     2B10              2.0              1.0
# 2     2B11              1.0              2.0
# 3     2B12              1.0              1.0
# 4     2B13              1.0              1.0
# 5     2B1A              1.0              1.0
# 6      2B2              1.0              1.0
# 7     2B3A              2.0              2.0
# 8      2B4              1.0              1.0
# 9      2B5              1.0              1.0
# 10     2B6              1.0              1.0
# 11     2B7              2.0              2.0
# 12     2B8              1.0              1.0
# 13     2B9              1.0              1.0
# 14     3A1              2.0              2.0
# 15     3A2              1.0              1.0
# 16     3A3              1.0              1.0
# 17     3B1              2.0              1.0
# 18    3B10              1.0              1.0
# 19    3B11              6.0              7.0
# ...

# %%
#rh = rh[["name", "guid"]].groupby("name").count().reset_index()
#merge = rh.merge(ct, on="name", how="outer").fillna(0)
#merge["delta"] = merge.guid - merge.quantity_ctrac
#merge_rpt = merge[merge["delta" ]!= 0]
