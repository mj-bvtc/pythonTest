# %%
import pandas as pd
import numpy as np
import re


rh = r"V:\Projects\PS 171M_P18-1593\TerraCotta\_Preliminary_Models\_archive\PS 171 counts.xlsx"
rhino = pd.read_excel(rh)

rhino.head()
# Out:
#          layer  name                                              zones  \
# 0  SCOPE::Text  J16R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 1  SCOPE::Text  J15R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 2  SCOPE::Text  J14R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 3  SCOPE::Text  J14R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 4  SCOPE::Text  J10R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
#
#                                    guid             x           y  z
# 0  6d2ef18a-ffee-4368-b03a-b5313c789635 -12016.014445  287.315724  0
# 1  e9fb47fd-7dea-4fe5-a931-0c1a6a53de28 -12016.014445  330.675882  0
# 2  1095b115-68a8-492b-97bc-6ab899a885db -12015.855145  309.104968  0
# 3  2215a1c2-e1ab-400e-9858-1f29352d592d -12015.855145  352.340698  0
# 4  018d1b19-bcb4-448a-9142-40b977dc8091 -10216.518438  366.783158  0

# %%
rhino["swing_drop"] = ""
rhino["floor"] = ""
rhino["elevation"] = ""
rhino["project"] = ""
rhino["ct_val"] = 1
rhino["ct_order"] = ""


def get_drop(x):
    pat = r"drop\s*([a-z]*\d*)"
    match = re.search(pat, str(x), flags=re.IGNORECASE)

    if match:
        # print("Found Match")
        return match.group(1)
    else:
        # print("Not Found")
        return None
    

def find_floor(x):
    pat = r"floor\s*(\d*)"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return int(result.group(1))    
    
def find_elevation(x):
    pat = r"ELEVATION\s*([a-zA-Z\s]*)"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)


def find_project(x):
    pat = r"'project\s*([a-zA-Z\s\d\(\)]*)'"
    result = re.search(pat, str(x), flags=re.IGNORECASE)
    if result:
        return result.group(1)
    else:
        print("not in project")
        

rhino.swing_drop = rhino.zones.apply(get_drop)
rhino.floor = rhino.zones.apply(find_floor)
rhino.elevation = rhino.zones.apply(find_elevation)
rhino.project = rhino.zones.apply(find_project)

rhino.floor = pd.to_numeric(rhino.floor)


rhino = rhino.sort_values(["floor", "swing_drop", "name" ], ascending=[True,True,True])
rhino.ct_order = rhino.ct_val.cumsum()

rhino
# Out:
#            layer   name                                              zones  \
# 260  SCOPE::Text  H-A10  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 261  SCOPE::Text  H-A11  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 262  SCOPE::Text  H-A12  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 263  SCOPE::Text  H-A13  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 264  SCOPE::Text  H-A1L  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 280  SCOPE::Text  H-A1R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 281  SCOPE::Text   H-A2  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 282  SCOPE::Text   H-A3  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 283  SCOPE::Text   H-A4  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 274  SCOPE::Text   H-A5  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 273  SCOPE::Text   H-A6  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 272  SCOPE::Text   H-A7  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 269  SCOPE::Text   H-A8  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 265  SCOPE::Text   H-A9  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 259  SCOPE::Text  H-B10  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 258  SCOPE::Text  H-B11  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 257  SCOPE::Text  H-B12  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 256  SCOPE::Text  H-B13  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 255  SCOPE::Text  H-B1L  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 279  SCOPE::Text  H-B1R  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 278  SCOPE::Text   H-B2  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 277  SCOPE::Text   H-B3  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 276  SCOPE::Text   H-B4  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 275  SCOPE::Text   H-B5  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 270  SCOPE::Text   H-B6  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 271  SCOPE::Text   H-B7  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 267  SCOPE::Text   H-B8  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 266  SCOPE::Text   H-B9  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 243  SCOPE::Text  H-C10  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# 242  SCOPE::Text  H-C11  ['PROJECT PS 171 (M)'// 'FLOOR 1'// 'ELEVATION...
# ..           ...    ...                                                ...
# 33   SCOPE::Text    J1R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 34   SCOPE::Text    J1R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 38   SCOPE::Text    J1R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 39   SCOPE::Text    J1R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 31   SCOPE::Text    J2R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 36   SCOPE::Text    J2R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 30   SCOPE::Text    J3R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 32   SCOPE::Text    Q3R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 35   SCOPE::Text    Q3R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 37   SCOPE::Text    Q3R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 29   SCOPE::Text    Q4R  ['PROJECT PS 171 (M)'// 'FLOOR 3'// 'ELEVATION...
# 746  SCOPE::Text     S2  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 747  SCOPE::Text     S2  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 513  SCOPE::Text     S5  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 749  SCOPE::Text     S7  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 835  SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 236  SCOPE::Text     S5  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 979  SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 904  SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 905  SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 27   SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 28   SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 4'// 'ELEVATION...
# 759  SCOPE::Text    J7L  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 760  SCOPE::Text    J8L  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 757  SCOPE::Text    Q5R  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 758  SCOPE::Text    Q6R  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 836  SCOPE::Text    J8R  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 837  SCOPE::Text    J8R  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 850  SCOPE::Text     S3  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
# 136  SCOPE::Text     S1  ['PROJECT PS 171 (M)'// 'FLOOR 5'// 'ELEVATION...
#
#                                      guid             x            y  z  \
# 260  5ea85768-ed78-4161-bbf1-3d1b7f3c17be  -6079.230533   383.270045  0
# 261  5b7119b1-59ca-4392-9071-9f62f4173b24  -6093.166107   383.657144  0
# 262  35330626-3811-42d6-9e4a-f7b7a50c7a95  -6108.908144   383.141012  0
# 263  fc9c90d5-763c-4cf9-8931-c732ff4aaddc  -6122.327586   383.399078  0
# 264  fa4b3102-822b-4a2b-bc55-4d8d2b88371f  -6136.650260   381.850681  0
# 280  67999e7e-a4dd-4174-92d4-964eef75b7fb  -5932.390870   382.624880  0
# 281  38623156-fc4e-48f2-a74c-6a904b4233dd  -5946.455478   383.657144  0
# 282  b27038ca-69ed-470a-a81b-aecb4b62393a  -5960.907184   383.915211  0
# 283  577c20a1-c2e8-4c1a-96a2-3453368b9583  -5975.100825   384.044244  0
# 274  35dca59f-043d-4beb-bb72-93d99a8f6feb  -5990.584796   383.786178  0
# 273  0035d215-c7f4-4604-8a8f-59c83523bd4c  -6004.907470   384.173277  0
# 272  f228fa2b-be14-4aa6-a55d-eb31b1b1d22e  -6020.649507   383.915211  0
# 269  05cbe7d1-63d4-4b1c-a786-6292e85e7bc0  -6048.907755   383.528111  0
# 265  11f51bee-8edd-4a40-94f6-e6331b7a9098  -6065.423991   383.786178  0
# 259  2f2acc94-0fec-4666-bd0e-487b7fa7fb20  -6080.907963   391.657196  0
