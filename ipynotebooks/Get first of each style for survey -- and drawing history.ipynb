# %%
import pandas as pd

file = r"C:\Users\mkreidler\Desktop\get 1st style survey.xlsx"

df = pd.read_excel(file)

unique_names = df.name.unique()

df["instance"] = df.groupby("name").cumcount() + 1
df[["name", "instance"]]

firsts = df.loc[df.instance == 1, "guid"]

df["first"] = 0

df.loc[df.instance==1, "first"] = 1

df.loc[df.instance == 1, ["name", "guid", "survey_name"]]
# Out:
#        name                                  guid      survey_name
# 0         Z  28e21eb7-3d81-42ac-9f86-7c9c2b1a5768        E1-9-Z[1]
# 1        W1  bc59d513-f2dc-4aa3-8602-33e5ae5e9b73       E1-9-W1[2]
# 9       SF2  16ecd1c6-f9c2-4c22-8212-22b44d466559     E1-9-SF2[10]
# 10      SF1  01426caa-676c-46c4-beb5-1d0e80bd209a     E1-9-SF1[11]
# 21       BS  751d6279-a512-4987-9c8f-c337a2af871e      E1-9-BS[22]
# 30     BAC2  7289ff47-49e3-4905-be09-26dbb18e7a98    E1-8-BAC2[31]
# 31      AWV  2211ea80-b101-4191-b1f8-50b8926bfabe     E1-7-AWV[32]
# 32       H5  6b6c7ccd-ae2d-438f-9369-ad3d13a183f7      E1-7-H5[33]
# 34      H20  12f3aad3-1f23-44e5-9442-317fc94b2c30     E1-6-H20[35]
# 35       A2  818f7c1d-717e-4f16-9d13-02525601bc9d      E1-3-A2[36]
# 73      H18  99b0ac22-a333-4f1f-bae7-d35f743a887c     E2-6-H18[74]
# 74      H19  192816e6-01ba-46a4-9235-2536e7a4ffcf     E2-6-H19[75]
# 75      H15  792a7437-4a06-4f98-8aed-c94715851b5e     E2-6-H15[76]
# 76      H16  35847666-a477-4661-96c4-b9826ab02619     E2-6-H16[77]
# 77      H17  a492e80e-d4b1-434d-8194-ccf6485bb746     E2-6-H17[78]
# 84      H14  93ddb185-95a8-4ad5-bc46-c562ed139967     E2-3-H14[85]
# 85      H12  4a742801-defe-48e1-ae85-a6efa093637a     E2-3-H12[86]
# 86      H13  5eda1a38-476f-4801-a102-4a729cb0a5f7     E2-3-H13[87]
# 87      H11  037606a4-366b-4632-8960-70fc68ddcd69     E2-3-H11[88]
# 88      H10  f153b698-7e3f-411e-970d-04af3a302692     E2-3-H10[89]
# 111      JR  b9583538-23ff-4797-846f-a05539e74805     E3-6-JR[112]
# 126   SCB2R  87dd53c0-7730-4532-8c1c-ceb05d41bae7  E3-3-SCB2R[127]
# 127   SC2BL  02180438-27ce-4a11-b90e-e8608a0f5e4e  E3-3-SC2BL[128]
# 128   SCB1R  30d2847f-9545-4f7a-95bb-4af8686e0285  E3-3-SCB1R[129]
# 129   SC1BL  1169f479-23c6-4848-b7a7-58069a0f8563  E3-3-SC1BL[130]
# 240     H21  35fdce94-b07c-4b99-a7f1-e71f10529a82    E6-3-H21[241]
# 241      JL  fdf0d386-811f-457f-824e-92f893d04661     E6-3-JL[242]
# 269      H6  c70e0b12-7e98-43ea-ac6a-5d4e947e0288     E7-7-H6[270]
# 270      H8  ca5b0663-5583-411e-a54f-f5e938c369d2     E7-7-H8[271]
# 271      H7  d4df3dab-2eff-4a35-b6ac-f433876b407c     E7-7-H7[272]
# ...     ...                                   ...              ...
# 299     BK1  23cca1cc-766f-424d-87ba-942b8924a740    N1-9-BK1[300]
# 313      H1  b3f5abc7-79ba-480f-941a-27413ec10cfe     N1-6-H1[314]
# 326      H2  666f24af-e6bb-464a-b81f-6391b7d3127b     N1-4-H2[327]
# 364      JB  236e3383-dd7e-4553-8aaf-6743f86dcaa3     N2-3-JB[365]
# 386      A1  d4cdfa44-d291-46ba-b9b5-f6b852040cfe     N3-8-A1[387]
# 387      Q2  cc30ecfa-98a8-45f4-95d8-cc0d3b1766d8     N3-8-Q2[388]
# 388    BAC3  3246ee60-97bd-4cbd-9236-be36ce6f9a30   N3-8-BAC3[389]
# 411     BK3  abc0d986-534e-471f-bdd5-71b0f81a3260    N4-9-BK3[412]
# 417     BAC  2af7235b-de9f-4bf2-9050-abb693406c87    N4-7-BAC[418]
# 870     CP1  e4314541-8347-48e8-98b2-463b1f8f1f71   S6-10-CP1[871]
# 1018   BAC4  51dc6a04-641d-4a2c-93f3-f1a4a4845879  W1-7-BAC4[1019]
# 1020    H26  1f63841a-e786-44ee-b895-71f1604dec1a   W1-7-H26[1021]
# 1021    H22  da0ebacd-251d-42bf-80d4-052a95801a01   W1-7-H22[1022]
# 1032    H23  736144b4-59fc-46ce-9a0c-39c921f889ac   W1-4-H23[1033]
# 1039   ABS2  32f7b085-b62a-452e-8a97-0b2886d215c0  W1-4-ABS2[1040]
# 1040    H25  89069d4c-da5c-4c0a-826c-377747c6b828   W1-3-H25[1041]
# 1077   ABS1  650fbf55-6fbf-4929-8dd2-806511656361  W2-5-ABS1[1078]
# 1079    H27  d03a7fe3-f67c-47e2-ac64-79c758f0512b   W2-4-H27[1080]
# 1125     JF  9ed174ee-f06e-4aa8-9ca0-1cfee0497233    W3-4-JF[1126]
# 1181   SCSL  7cdecf11-1978-4f47-9180-ec0608c40bf8  W4-4-SCSL[1182]
# 1236    SCS  2414bf66-bad1-404d-8f37-530692b9e340   W5-5-SCS[1237]
# 1254   SCBC  af4256fb-c5e6-4cc3-af91-d7f694fc1f97  W5-3-SCBC[1255]
# 1289   BAC6  0f396069-da2e-4c3a-9c52-c2c8da1c7f4c  W6-7-BAC6[1290]
# 1290   BAC5  634d26af-5ec1-4da9-b9bc-6d3f34c064f4  W6-7-BAC5[1291]
# 1292    H30  dacbf0af-4212-4aff-9726-a2c6d96c2a32   W6-7-H30[1293]
# 1315    H31  8b65c2fc-36f1-4688-a615-98578fd8a222   W6-3-H31[1316]
# 1358    H28  3436198a-d6a0-4213-9287-de7ab50f7518   W7-7-H28[1359]
# 1361   ABS3  815206bd-1544-4d54-938c-62a96334d05c  W7-7-ABS3[1362]
# 1368    H29  990adcab-784e-463a-80dc-d613ef1254bc   W7-5-H29[1369]
# 1370    H32  c11bc448-6f6a-430f-a64e-109292e0134a   W7-5-H32[1371]
#
# [62 rows x 3 columns]

# %%
list(df)
# Out:
# ['elevation',
#  'floor',
#  'guid',
#  'layer',
#  'name',
#  'phase',
#  'point',
#  'priority',
#  'swing_drop',
#  'x',
#  'y',
#  'z',
#  'zones',
#  'group',
#  'drop_sort',
#  'new_order',
#  'survey_name',
#  'instance',
#  'first']

# %%
import datetime
import workdays


class Drawing:
    def __init__(self):
        self.
