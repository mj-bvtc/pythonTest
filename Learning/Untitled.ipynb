# %%
import pint

u = pint.UnitRegistry()

matt_height = 6 * u.foot

# %%
print(matt_height.to(u.inch))
# Out:
# 72.0 inch

# %%
pwd
# Out:
# 'V:\\MeshLab\\_FieldSurvey\\MK\\python\\pythonTest\\Learning'

# %%
ls
# Out:
#  Volume in drive V is ExtData
#  Volume Serial Number is FA98-30B7
#
#  Directory of V:\MeshLab\_FieldSurvey\MK\python\pythonTest\Learning
#
# 08/31/2017  09:19 AM    <DIR>          .
# 08/31/2017  09:19 AM    <DIR>          ..
# 08/15/2017  07:43 AM    <DIR>          .idea
# 08/31/2017  08:53 AM    <DIR>          .ipynb_checkpoints
# 08/15/2017  07:44 AM    <DIR>          __pycache__
# 08/15/2017  07:43 AM    <DIR>          AnacondaProject
# 08/15/2017  07:43 AM    <DIR>          BVTC
# 04/24/2017  12:46 PM                86 chickens.py
# 08/15/2017  07:43 AM    <DIR>          Eggnog
# 08/15/2017  07:43 AM    <DIR>          html
# 08/15/2017  07:43 AM    <DIR>          KIVY
# 08/15/2017  07:43 AM    <DIR>          lambdaTest
# 07/26/2017  05:09 PM            32,348 Least_Squares_Fit.py
# 08/15/2017  07:43 AM    <DIR>          location
# 08/15/2017  07:43 AM    <DIR>          MyPackage
# 05/12/2017  02:37 PM                 0 NewTree.py
# ...

# %%
# Out:
# Host Name:                 DESIGNLAB-MIKE
# OS Name:                   Microsoft Windows 7 Professional
# OS Version:                6.1.7601 Service Pack 1 Build 7601
# OS Manufacturer:           Microsoft Corporation
# OS Configuration:          Member Workstation
# OS Build Type:             Multiprocessor Free
# Registered Owner:          User
# Registered Organization:   Hewlett-Packard Company
# Product ID:                00371-OEM-8992671-00008
# Original Install Date:     11/15/2013, 12:36:34 PM
# System Boot Time:          8/29/2017, 8:08:22 AM
# System Manufacturer:       Hewlett-Packard
# System Model:              HP Z230 SFF Workstation
# System Type:               x64-based PC
# Processor(s):              1 Processor(s) Installed.
#                            [01]: Intel64 Family 6 Model 60 Stepping 3 GenuineIntel ~3401 Mhz
# BIOS Version:              Hewlett-Packard L51 v01.02, 6/25/2013
# Windows Directory:         C:\windows
# ...

# %%
# Out:
# Microsoft Windows [Version 6.1.7601]

# %%
# !ver
# Out:
# Microsoft Windows [Version 6.1.7601]

# %%
# !systeminfo
# Out:
# Host Name:                 DESIGNLAB-MIKE
# OS Name:                   Microsoft Windows 7 Professional
# OS Version:                6.1.7601 Service Pack 1 Build 7601
# OS Manufacturer:           Microsoft Corporation
# OS Configuration:          Member Workstation
# OS Build Type:             Multiprocessor Free
# Registered Owner:          User
# Registered Organization:   Hewlett-Packard Company
# Product ID:                00371-OEM-8992671-00008
# Original Install Date:     11/15/2013, 12:36:34 PM
# System Boot Time:          8/29/2017, 8:08:22 AM
# System Manufacturer:       Hewlett-Packard
# System Model:              HP Z230 SFF Workstation
# System Type:               x64-based PC
# Processor(s):              1 Processor(s) Installed.
#                            [01]: Intel64 Family 6 Model 60 Stepping 3 GenuineIntel ~782 Mhz
# BIOS Version:              Hewlett-Packard L51 v01.02, 6/25/2013
# Windows Directory:         C:\windows
# ...

# %%
pwd
# Out:
# 'V:\\MeshLab\\_FieldSurvey\\MK\\python\\pythonTest\\Learning'

# %%
# %dhist
# Out:
# Directory history (kept in _dh)
# 0: V:\MeshLab\_FieldSurvey\MK\python\pythonTest\Learning
