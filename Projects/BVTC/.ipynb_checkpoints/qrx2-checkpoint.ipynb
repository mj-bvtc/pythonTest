# %%
import datetime
import time
import pandas as pd
import re

class Mold:
    def __init__(self, units=0, inventory=0, log=True):
        self.presses_per_mold = 12
        self.log = log
        self.units_log = []
        self.presses = []
        self.mold_purchases = []
        self.remaining_presses = []
        self.tot_press = []          #amount of presses if you maxed out molds
        self.timestamps = []
        
    def write_log(self, x=None):
        if self.log:
            print(x)
        
    def request_units(self, units):
        self.units_log.append(units)
        self.write_log(f"{units} units requested and added to log")
        self.check_inventory()
        self.buy_molds()
        self.get_remaining_presses()
        now = datetime.datetime.now()
        self.timestamps.append(now)
        
    def get_remaining_presses(self):
        press = sum(self.presses)
        units = sum(self.units_log)
        delta = press - units
        self.remaining_presses.append(delta)
        tot = self.units_log[-1] + (self.remaining_presses[-1])
        self.tot_press.append(tot)

    def check_inventory(self):
        if sum(self.units_log) > sum(self.presses):
            self.write_log("You need to buy mold(s)")
        else:
            diff = sum(self.presses) - sum(self.units_log)
            self.write_log(f"You have {sum(self.presses)} presses and {sum(self.units_log)} units")
            self.write_log(f"You have {diff} presses remaining")
            print()
    
    def buy_molds(self):
        if sum(self.units_log) > sum(self.presses):
            delta = sum(self.units_log) - sum(self.presses)
            buy = self.calculate_molds(delta)
            self.write_log(f"I bought {buy} mold(s)")
            self.write_log()
            self.mold_purchases.append(buy)
            press = buy * self.presses_per_mold
            self.presses.append(press)
        else:
            self.mold_purchases.append(0)
            self.presses.append(0)
            
    
    def calculate_molds(self, units):
        result = ((units - 1)//self.presses_per_mold) + 1
        return result
    
    @property
    def df(self):
        result = None
        try:
            d = {"Requested Units": self.units_log,
                 "Purchased Presses": self.presses,
                 "Purchased Molds": self.mold_purchases,
                 "Leftover Presses": self.remaining_presses,
                 "Total Available Presses": self.tot_press,
                 "DT": self.timestamps}
            df = pd.DataFrame(data=d)
            result = df[["Requested Units", 
                         "Purchased Molds", 
                         "Purchased Presses",
                         "Total Available Presses", 
                         "Leftover Presses"]]
        finally:
            return result

# %%
file = r"C:\Users\mkreidler\Desktop\dump\test.csv"
raw = pd.DataFrame.from_csv(file)
raw.reset_index(inplace=True)
df = raw.copy()


def clean(df):
    #remove dollar signs
    df["Cost Per Model"] = df["Cost Per Model"].str.replace("$", "")
    df["Cost Per Unit"] = df["Cost Per Unit"].str.replace("$", "")
    df["Cost Per Mold"] = df["Cost Per Mold"].str.replace("$", "")

    df["Cost Per Model"] = df["Cost Per Model"].str.replace(",", "")
    df["Cost Per Unit"] = df["Cost Per Unit"].str.replace(",", "")
    df["Cost Per Mold"] = df["Cost Per Mold"].str.replace(",", "")

    #string to numeric
    pd.to_numeric(df["Cost Per Model"])
    pd.to_numeric(df["Cost Per Mold"])
    pd.to_numeric(df["Cost Per Unit"])

    return df

def rename(df):
    #rename columns
    df  = df.rename(columns={ "Estimating ID": "Block ID",
                        "Cost Per Model": "$/Model",
                        "Cost Per Mold": "$/Mold",
                        "Cost Per Unit": "$/Unit"})
    return df

def add_base(df):
    import name_tools as nt

    #add base name
    def fx(x):
        b = nt.Block(x)
        base = b.style + b.style_number
        return base
    
    df["base"] = df["Block ID"].apply(fx)
    df[["Phase", "Block ID", "base"]].head()
    
    return df

def run(df):
    df = clean(df)
    df = rename(df)
    df = add_base(df)
    return df
df = run(df)
col = ["Phase", "Block ID", "base", "# Units"]   
df[col].head()
# Out:
#       Phase Block ID base  # Units
# 0   Add/Alt       A1   A1        1
# 1  Base Bid       A2   A2        1
# 2  Base Bid       A2   A2        1
# 3  Base Bid       A2   A2        1
# 4  Base Bid       A2   A2        1

# %%
#group list
tot = df.groupby(["Phase", "base"]).sum()
tot = tot.drop(["Client ID", "Phase #"], axis=1)
tot.reset_index(inplace=True)
tot = tot.sort_values(["Phase", "base"], ascending=[False, True])     ####TODO this needs to sort reliably base=1, addalt=2, co1, etc
tot = tot.reset_index(drop=True)

#get unique base names
base_list = set(tot["base"].tolist())

#create dictionary of molds per base name
base_dict = {}
for b in base_list:
    k = b
    v = Mold(log=False)     #####set this to False to suppress printing
    base_dict[k] = v
    
base_dict
# Out:
# {'A1': <__main__.Mold at 0x823f048>,
#  'A2': <__main__.Mold at 0x823f668>,
#  'A3': <__main__.Mold at 0x823fef0>,
#  'BK1': <__main__.Mold at 0x823f588>,
#  'C1': <__main__.Mold at 0x823f128>,
#  'C2': <__main__.Mold at 0x823f320>,
#  'CS1': <__main__.Mold at 0x823f748>,
#  'F1': <__main__.Mold at 0x823f4a8>,
#  'F2': <__main__.Mold at 0x823f400>,
#  'H1': <__main__.Mold at 0x823f630>,
#  'H2': <__main__.Mold at 0x823f0b8>,
#  'U1': <__main__.Mold at 0x823ff28>,
#  'W1': <__main__.Mold at 0x823fa20>,
#  'W2': <__main__.Mold at 0x82f9198>}

# %%
tot.head()
# Out:
#       Phase base  # Units
# 0  Base Bid   A2       10
# 1  Base Bid   A3        6
# 2  Base Bid  BK1        9
# 3  Base Bid   C1       19
# 4  Base Bid  CS1        2

# %%
#assign mold number 

def get_mold_num(base, units):
    base_dict[base].request_units(units)    
    result = base_dict[base].mold_purchases[-1]
    #print(base_dict[base].df)
    return result

tot["# Molds"] = tot.apply(lambda x: get_mold_num(x["base"], x["# Units"]), axis=1)
tot.head()
# Out:
#       Phase base  # Units  # Molds
# 0  Base Bid   A2       10        1
# 1  Base Bid   A3        6        1
# 2  Base Bid  BK1        9        1
# 3  Base Bid   C1       19        2
# 4  Base Bid  CS1        2        1

# %%
df.head()
# Out:
#   Project #     Phase  Phase #    Deleted  Client ID Block ID Description  \
# 0  P17-9999   Add/Alt      1.0  Unchecked      123.0       A1  A _Ashlar
# 1  P17-9999  Base Bid      NaN  Unchecked        NaN       A2  A _Ashlar
# 2  P17-9999  Base Bid      NaN  Unchecked        NaN       A2  A _Ashlar
# 3  P17-9999  Base Bid      NaN  Unchecked        NaN       A2  A _Ashlar
# 4  P17-9999  Base Bid      NaN  Unchecked        NaN       A2  A _Ashlar
#
#   Type Ornament   Size             Page Label Form Method  # Units $/Model  \
# 0  NaN     None  Small  SH201-FRONT ELEVATION          HP        1    720
# 1  NaN     None    Med  SH201-FRONT ELEVATION          HP        1    870
# 2  NaN     None    Med  SH201-FRONT ELEVATION          HP        1    870
# 3  NaN     None    Med  SH201-FRONT ELEVATION          HP        1    870
# 4  NaN     None    Med  SH201-FRONT ELEVATION          HP        1    870
#
#   $/Mold $/Unit base
# 0   678    116    A1
# 1   719    144    A2
# 2   719    144    A2
# 3   719    144    A2
# 4   719    144    A2

# %%
#merge with tot
tot = tot[["# Molds", "base"]]
tot.reset_index(inplace=True, drop=True)
tot
#df = df.join(tot, how='left', on="base", lsuffix="left", rsuffix="right")

#col2 = ["Phase", "Block ID", "# Units", "base", "# Molds"]
#df[col2]

def get_base_mold():
    base_mold = {}
    mold = tot["# Molds"].tolist()
    base = tot["base"].tolist()
    for m, b in zip(mold, base):
        base_mold[b] = m
    return base_mold

get_base_mold()



def map_dict(k):
    return get_base_mold()[k]

df["# Molds"] = df["base"].apply(map_dict)
df
# Out:
#    Project #     Phase  Phase #    Deleted  Client ID Block ID    Description  \
# 0   P17-9999   Add/Alt      1.0  Unchecked      123.0       A1     A _Ashlar
# 1   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 2   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 3   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 4   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 5   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 6   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 7   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 8   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 9   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 10  P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 11  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 12  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 13  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 14  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 15  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 16  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 17  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 18  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 19  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 20  P17-9999  Base Bid      NaN  Unchecked        NaN       A3     A _Ashlar
# 21  P17-9999   Add/Alt      1.0  Unchecked        NaN       A3     A _Ashlar
# 22  P17-9999  Base Bid      NaN  Unchecked        NaN      BK1     BK_Bracket
# 23  P17-9999   Add/Alt      1.0  Unchecked        NaN      BK1     BK_Bracket
# 24       NaN   Add/Alt      1.0  Unchecked        NaN      BK1     BK_Bracket
# 25  P17-9999  Base Bid      NaN  Unchecked        NaN       C1      C _Coping
# 26  P17-9999   Add/Alt      1.0  Unchecked        NaN       C1      C _Coping
# 27  P17-9999   Add/Alt      1.0  Unchecked        NaN      C2L      C _Coping
# 28  P17-9999   Add/Alt      1.0  Unchecked        NaN      C2L      C _Coping
# 29       NaN   Add/Alt      1.0  Unchecked        NaN      C2L      C _Coping
# ..       ...       ...      ...        ...        ...      ...            ...
# 65       NaN  Base Bid      NaN  Unchecked        NaN     W1-1  W _Watertable
# 66       NaN  Base Bid      NaN  Unchecked        NaN     W1-1  W _Watertable
# 67       NaN  Base Bid      NaN  Unchecked        NaN     W1-1  W _Watertable
# 68       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 69       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 70       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 71       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 72       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 73       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 74       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 75       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 76       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 77       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 78       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 79       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 80       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 81       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 82       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 83       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 84       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 85       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 86       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 87       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 88       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 89       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 90       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 91       NaN  Base Bid      NaN  Unchecked        NaN      W2L  W _Watertable
# 92       NaN   Add/Alt      1.0  Unchecked        NaN      W2L  W _Watertable
# 93       NaN  Base Bid      NaN  Unchecked        NaN      W2R  W _Watertable
# 94       NaN   Add/Alt      1.0  Unchecked        NaN      W2R  W _Watertable
#
#               Type       Ornament   Size              Page Label Form Method  \
# 0              NaN           None  Small   SH201-FRONT ELEVATION          HP
# 1              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 2              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 3              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 4              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 5              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 6              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 7              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 8              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 9              NaN           None    Med   SH201-FRONT ELEVATION          HP
# 10             NaN           None    Med   SH201-FRONT ELEVATION          HP
# 11             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 12             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 13             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 14             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 15             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 16             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 17             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 18             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 19             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 20             NaN           None    Med   SH201-FRONT ELEVATION          HP
# 21             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 22             NaN           None    Med   SH201-FRONT ELEVATION          HP
# 23             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 24             NaN           None    Med  SH202 - REAR ELEVATION          HP
# 25      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 26      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 27  Outside Corner           None    Med  SH202 - REAR ELEVATION          HP
# 28  Outside Corner           None    Med  SH202 - REAR ELEVATION          HP
# 29  Outside Corner           None    Med  SH202 - REAR ELEVATION          HP
# ..             ...            ...    ...                     ...         ...
# 65      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 66      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 67      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 68      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 69      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 70      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 71      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 72      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 73      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 74      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 75      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 76      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 77      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 78      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 79      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 80      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 81      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 82      Strectcher           None    Med   SH201-FRONT ELEVATION          HP
# 83      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 84      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 85      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 86      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 87      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 88      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 89      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 90      Strectcher           None    Med  SH202 - REAR ELEVATION          HP
# 91  Outside Corner           None    Med   SH201-FRONT ELEVATION          HP
# 92  Outside Corner           None    Med  SH202 - REAR ELEVATION          HP
# 93  Outside Corner  High Isolated    Med   SH201-FRONT ELEVATION          HP
# 94  Outside Corner           None    Med  SH202 - REAR ELEVATION          HP
#
#     # Units $/Model $/Mold $/Unit base  # Molds
# 0         1    720    678    116    A1        1
# 1         1    870    719    144    A2        1
# 2         1    870    719    144    A2        1
# 3         1    870    719    144    A2        1
# 4         1    870    719    144    A2        1
# 5         1    870    719    144    A2        1
# 6         1    870    719    144    A2        1
# 7         1    870    719    144    A2        1
# 8         1    870    719    144    A2        1
# 9         1    870    719    144    A2        1
# 10        1    870    719    144    A2        1
# 11        1    870    719    144    A2        1
# 12        1    870    719    144    A2        1
# 13        1    870    719    144    A2        1
# 14        1    870    719    144    A2        1
# 15        1    870    719    144    A2        1
# 16        1    870    719    144    A2        1
# 17        1    870    719    144    A2        1
# 18        1    870    719    144    A2        1
# 19        1    870    719    144    A2        1
# 20        6    870    719    144    A3        0
# 21        6    870    719    144    A3        0
# 22        9   1020    719    172   BK1        4
# 23       39   1020    899    172   BK1        4
# 24        1   1020    719    172   BK1        4
# 25       19    840    779    138    C1        0
# 26        5    840    719    138    C1        0
# 27        1   1020    719    148    C2        1
# 28        1   1020    719    148    C2        1
# 29        1   1020    719    148    C2        1
# ..      ...     ...    ...    ...  ...      ...
# 65        1   1020    719    172    W1        1
# 66        1   1020    719    172    W1        1
# 67        1   1020    719    172    W1        1
# 68        1   1020    719    172    W1        1
# 69        1   1020    719    172    W1        1
# 70        1   1020    719    172    W1        1
# 71        1   1020    719    172    W1        1
# 72        1   1020    719    172    W1        1
# 73        1   1020    719    172    W1        1
# 74        1   1020    719    172    W1        1
# 75        1   1020    719    172    W1        1
# 76        1   1020    719    172    W1        1
# 77        1   1020    719    172    W1        1
# 78        1   1020    719    172    W1        1
# 79        1   1020    719    172    W1        1
# 80        1   1020    719    172    W1        1
# 81        1   1020    719    172    W1        1
# 82        1   1020    719    172    W1        1
# 83        1   1020    719    172    W1        1
# 84        1   1020    719    172    W1        1
# 85        1   1020    719    172    W1        1
# 86        1   1020    719    172    W1        1
# 87        1   1020    719    172    W1        1
# 88        1   1020    719    172    W1        1
# 89        1   1020    719    172    W1        1
# 90        1   1020    719    172    W1        1
# 91        1   1200    719    182    W2        0
# 92        1   1200    719    182    W2        0
# 93        1   2325    719    395    W2        0
# 94        1   1200    719    182    W2        0
#
# [95 rows x 18 columns]

# %%
class Counter:
    def __init__(self):
        self.library = {}
        
    def add(self, name):
        if name in self.library:
            self.library[name] += 1
        else:
            self.library[name] = 1
    def check(self, name):
        if name not in self.library:
            return 0
        else:
            return self.library[name]

c = Counter()
c.add("a")
c.add("a")
c.add("b")

c.check("D")
c.check("b")
# Out:
# 1

# %%
def combine(phase, base):
    return "_".join([str(phase),str(base)])
df["phase_base"] = df.apply(lambda x: combine(x["Phase"], x["base"]), axis=1 )

c = Counter()
def count(phase_base):
    c.add(phase_base)
    return c.check(phase_base)
    
df["count"] = df["phase_base"].apply(count)
col2.append("count")
df[col2]

def zero_molds(mold, count):
    if count != 1:
        mold = 0
    else:
        mold = mold
    return mold

df["Actual # Molds"] = df.apply(lambda x: zero_molds(x["# Molds"], x["count"]), axis=1)
df
# Out:
#    Project #     Phase  Phase #    Deleted  Client ID Block ID    Description  \
# 0   P17-9999   Add/Alt      1.0  Unchecked      123.0       A1     A _Ashlar
# 1   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 2   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 3   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 4   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 5   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 6   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 7   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 8   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 9   P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 10  P17-9999  Base Bid      NaN  Unchecked        NaN       A2     A _Ashlar
# 11  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 12  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 13  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 14  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 15  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 16  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 17  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 18  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 19  P17-9999   Add/Alt      1.0  Unchecked        NaN       A2     A _Ashlar
# 20  P17-9999  Base Bid      NaN  Unchecked        NaN       A3     A _Ashlar
# 21  P17-9999   Add/Alt      1.0  Unchecked        NaN       A3     A _Ashlar
# 22  P17-9999  Base Bid      NaN  Unchecked        NaN      BK1     BK_Bracket
# 23  P17-9999   Add/Alt      1.0  Unchecked        NaN      BK1     BK_Bracket
# 24       NaN   Add/Alt      1.0  Unchecked        NaN      BK1     BK_Bracket
# 25  P17-9999  Base Bid      NaN  Unchecked        NaN       C1      C _Coping
# 26  P17-9999   Add/Alt      1.0  Unchecked        NaN       C1      C _Coping
# 27  P17-9999   Add/Alt      1.0  Unchecked        NaN      C2L      C _Coping
# 28  P17-9999   Add/Alt      1.0  Unchecked        NaN      C2L      C _Coping
# 29       NaN   Add/Alt      1.0  Unchecked        NaN      C2L      C _Coping
# ..       ...       ...      ...        ...        ...      ...            ...
# 65       NaN  Base Bid      NaN  Unchecked        NaN     W1-1  W _Watertable
# 66       NaN  Base Bid      NaN  Unchecked        NaN     W1-1  W _Watertable
# 67       NaN  Base Bid      NaN  Unchecked        NaN     W1-1  W _Watertable
# 68       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 69       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 70       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 71       NaN   Add/Alt      1.0  Unchecked        NaN     W1-1  W _Watertable
# 72       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 73       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 74       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 75       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 76       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 77       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 78       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 79       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 80       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 81       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 82       NaN  Base Bid      NaN  Unchecked        NaN     W1-2  W _Watertable
# 83       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 84       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 85       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 86       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 87       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 88       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 89       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 90       NaN   Add/Alt      1.0  Unchecked        NaN     W1-2  W _Watertable
# 91       NaN  Base Bid      NaN  Unchecked        NaN      W2L  W _Watertable
# 92       NaN   Add/Alt      1.0  Unchecked        NaN      W2L  W _Watertable
# 93       NaN  Base Bid      NaN  Unchecked        NaN      W2R  W _Watertable
# 94       NaN   Add/Alt      1.0  Unchecked        NaN      W2R  W _Watertable
#
#               Type       Ornament   Size       ...       Form Method # Units  \
# 0              NaN           None  Small       ...                HP       1
# 1              NaN           None    Med       ...                HP       1
# 2              NaN           None    Med       ...                HP       1
# 3              NaN           None    Med       ...                HP       1
# 4              NaN           None    Med       ...                HP       1
# 5              NaN           None    Med       ...                HP       1
# 6              NaN           None    Med       ...                HP       1
# 7              NaN           None    Med       ...                HP       1
# 8              NaN           None    Med       ...                HP       1
# 9              NaN           None    Med       ...                HP       1
# 10             NaN           None    Med       ...                HP       1
# 11             NaN           None    Med       ...                HP       1
# 12             NaN           None    Med       ...                HP       1
# 13             NaN           None    Med       ...                HP       1
# 14             NaN           None    Med       ...                HP       1
# 15             NaN           None    Med       ...                HP       1
# 16             NaN           None    Med       ...                HP       1
# 17             NaN           None    Med       ...                HP       1
# 18             NaN           None    Med       ...                HP       1
# 19             NaN           None    Med       ...                HP       1
# 20             NaN           None    Med       ...                HP       6
# 21             NaN           None    Med       ...                HP       6
# 22             NaN           None    Med       ...                HP       9
# 23             NaN           None    Med       ...                HP      39
# 24             NaN           None    Med       ...                HP       1
# 25      Strectcher           None    Med       ...                HP      19
# 26      Strectcher           None    Med       ...                HP       5
# 27  Outside Corner           None    Med       ...                HP       1
# 28  Outside Corner           None    Med       ...                HP       1
# 29  Outside Corner           None    Med       ...                HP       1
# ..             ...            ...    ...       ...               ...     ...
# 65      Strectcher           None    Med       ...                HP       1
# 66      Strectcher           None    Med       ...                HP       1
# 67      Strectcher           None    Med       ...                HP       1
# 68      Strectcher           None    Med       ...                HP       1
# 69      Strectcher           None    Med       ...                HP       1
# 70      Strectcher           None    Med       ...                HP       1
# 71      Strectcher           None    Med       ...                HP       1
# 72      Strectcher           None    Med       ...                HP       1
# 73      Strectcher           None    Med       ...                HP       1
# 74      Strectcher           None    Med       ...                HP       1
# 75      Strectcher           None    Med       ...                HP       1
# 76      Strectcher           None    Med       ...                HP       1
# 77      Strectcher           None    Med       ...                HP       1
# 78      Strectcher           None    Med       ...                HP       1
# 79      Strectcher           None    Med       ...                HP       1
# 80      Strectcher           None    Med       ...                HP       1
# 81      Strectcher           None    Med       ...                HP       1
# 82      Strectcher           None    Med       ...                HP       1
# 83      Strectcher           None    Med       ...                HP       1
# 84      Strectcher           None    Med       ...                HP       1
# 85      Strectcher           None    Med       ...                HP       1
# 86      Strectcher           None    Med       ...                HP       1
# 87      Strectcher           None    Med       ...                HP       1
# 88      Strectcher           None    Med       ...                HP       1
# 89      Strectcher           None    Med       ...                HP       1
# 90      Strectcher           None    Med       ...                HP       1
# 91  Outside Corner           None    Med       ...                HP       1
# 92  Outside Corner           None    Med       ...                HP       1
# 93  Outside Corner  High Isolated    Med       ...                HP       1
# 94  Outside Corner           None    Med       ...                HP       1
#
#     $/Model $/Mold $/Unit base # Molds    phase_base count  Actual # Molds
# 0      720    678    116    A1       1    Add/Alt_A1     1               1
# 1      870    719    144    A2       1   Base Bid_A2     1               1
# 2      870    719    144    A2       1   Base Bid_A2     2               0
# 3      870    719    144    A2       1   Base Bid_A2     3               0
# 4      870    719    144    A2       1   Base Bid_A2     4               0
# 5      870    719    144    A2       1   Base Bid_A2     5               0
# 6      870    719    144    A2       1   Base Bid_A2     6               0
# 7      870    719    144    A2       1   Base Bid_A2     7               0
# 8      870    719    144    A2       1   Base Bid_A2     8               0
# 9      870    719    144    A2       1   Base Bid_A2     9               0
# 10     870    719    144    A2       1   Base Bid_A2    10               0
# 11     870    719    144    A2       1    Add/Alt_A2     1               1
# 12     870    719    144    A2       1    Add/Alt_A2     2               0
# 13     870    719    144    A2       1    Add/Alt_A2     3               0
# 14     870    719    144    A2       1    Add/Alt_A2     4               0
# 15     870    719    144    A2       1    Add/Alt_A2     5               0
# 16     870    719    144    A2       1    Add/Alt_A2     6               0
# 17     870    719    144    A2       1    Add/Alt_A2     7               0
# 18     870    719    144    A2       1    Add/Alt_A2     8               0
# 19     870    719    144    A2       1    Add/Alt_A2     9               0
# 20     870    719    144    A3       0   Base Bid_A3     1               0
# 21     870    719    144    A3       0    Add/Alt_A3     1               0
# 22    1020    719    172   BK1       4  Base Bid_BK1     1               4
# 23    1020    899    172   BK1       4   Add/Alt_BK1     1               4
# 24    1020    719    172   BK1       4   Add/Alt_BK1     2               0
# 25     840    779    138    C1       0   Base Bid_C1     1               0
# 26     840    719    138    C1       0    Add/Alt_C1     1               0
# 27    1020    719    148    C2       1    Add/Alt_C2     1               1
# 28    1020    719    148    C2       1    Add/Alt_C2     2               0
# 29    1020    719    148    C2       1    Add/Alt_C2     3               0
# ..      ...    ...    ...  ...     ...           ...   ...             ...
# 65    1020    719    172    W1       1   Base Bid_W1     8               0
# 66    1020    719    172    W1       1   Base Bid_W1     9               0
# 67    1020    719    172    W1       1   Base Bid_W1    10               0
# 68    1020    719    172    W1       1    Add/Alt_W1     1               1
# 69    1020    719    172    W1       1    Add/Alt_W1     2               0
# 70    1020    719    172    W1       1    Add/Alt_W1     3               0
# 71    1020    719    172    W1       1    Add/Alt_W1     4               0
# 72    1020    719    172    W1       1   Base Bid_W1    11               0
# 73    1020    719    172    W1       1   Base Bid_W1    12               0
# 74    1020    719    172    W1       1   Base Bid_W1    13               0
# 75    1020    719    172    W1       1   Base Bid_W1    14               0
# 76    1020    719    172    W1       1   Base Bid_W1    15               0
# 77    1020    719    172    W1       1   Base Bid_W1    16               0
# 78    1020    719    172    W1       1   Base Bid_W1    17               0
# 79    1020    719    172    W1       1   Base Bid_W1    18               0
# 80    1020    719    172    W1       1   Base Bid_W1    19               0
# 81    1020    719    172    W1       1   Base Bid_W1    20               0
# 82    1020    719    172    W1       1   Base Bid_W1    21               0
# 83    1020    719    172    W1       1    Add/Alt_W1     5               0
# 84    1020    719    172    W1       1    Add/Alt_W1     6               0
# 85    1020    719    172    W1       1    Add/Alt_W1     7               0
# 86    1020    719    172    W1       1    Add/Alt_W1     8               0
# 87    1020    719    172    W1       1    Add/Alt_W1     9               0
# 88    1020    719    172    W1       1    Add/Alt_W1    10               0
# 89    1020    719    172    W1       1    Add/Alt_W1    11               0
# 90    1020    719    172    W1       1    Add/Alt_W1    12               0
# 91    1200    719    182    W2       0   Base Bid_W2     1               0
# 92    1200    719    182    W2       0    Add/Alt_W2     1               0
# 93    2325    719    395    W2       0   Base Bid_W2     2               0
# 94    1200    719    182    W2       0    Add/Alt_W2     2               0
#
# [95 rows x 21 columns]
